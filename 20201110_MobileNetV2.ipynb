# %%
import os
import os.path as pth
import json
import shutil
import numpy as np
import pandas as pd
from tqdm import tqdm
import tensorflow as tf
import tensorflow.keras as keras

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
np.array([540,960]) * 6/10
# Out:
# array([324., 576.])

# %%
BASE_MODEL_NAME = 'MobileNetV2-for-upload'
my_model_base = keras.applications.mobilenet_v2
my_model = my_model_base.MobileNetV2

config = {
    'is_zscore':True,
    
    # 'input_shape': (540, 960, 3),
    'aug': {
        #'resize': (270, 480),
        'resize': (297, 528),
    },
    # 'input_shape': (224, 360, 3),
    #'input_shape': (270, 480, 3),
    'input_shape': (270, 480, 3),

    'output_activation': 'softmax',
    'num_class': 1049,
    'output_size': 1049,
    
    'conv':{
        'conv_num': (0), # (3,5,3),
        'base_channel': 0, # 4,
        'kernel_size': 0, # 3,
        'padding':'same',
        'stride':'X'
    },
    'pool':{
        'type':'X',
        'size':'X',
        'stride':'X',
        'padding':'same'
    },
    'fc':{
        'fc_num': 0,
     },
    
    'activation':'relu',
    
    'between_type': 'avg',
    
    'is_batchnorm': True,
    'is_dropout': False,
    'dropout_rate': 0.5,
    
    'batch_size': 32,
    'buffer_size': 256,
    'loss': 'CategoricalCrossentropy',
    
    'num_epoch': 10000,
    'learning_rate': 1e-3,
    
    'random_state': 7777
}

# %%
image_feature_description = {
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    'randmark_id': tf.io.FixedLenFeature([], tf.int64),
    # 'id': tf.io.FixedLenFeature([], tf.string),
}

def _parse_image_function(example_proto):
    return tf.io.parse_single_example(example_proto, image_feature_description)

def map_func(target_record):
    img = target_record['image_raw']
    label = target_record['randmark_id']
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.dtypes.cast(img, tf.float32)
    return img, label

def resize_and_crop_func(image, label):
    result_image = tf.image.resize(image, config['aug']['resize'])
    result_image = tf.image.random_crop(image, size=config['input_shape'], seed=7777)  # crop revived.
    return result_image, label

def image_aug_func(image, label):
    pass
    return image, label

def post_process_func(image, label):
    # result_image = result_image / 255
    result_image = my_model_base.preprocess_input(image)
    onehot_label = tf.one_hot(label, depth=config['num_class'])
    return result_image, onehot_label

# %%
data_base_path = pth.join('data', 'public') 
os.makedirs(data_base_path, exist_ok=True)

# %%
category_csv_name = 'category.csv'
category_json_name = 'category.json'
submission_csv_name = 'sample_submisstion.csv'
train_csv_name = 'train.csv'

# train_zip_name = 'train.zip'
train_tfrecord_name = 'all_train.tfrecords'
train_tfrecord_path = pth.join(data_base_path, train_tfrecord_name)
val_tfrecord_name = 'all_val.tfrecords'
val_tfrecord_path = pth.join(data_base_path, val_tfrecord_name)
# test_zip_name = 'test.zip'
test_tfrecord_name = 'test.tfrecords'
test_tfrecord_path = pth.join(data_base_path, test_tfrecord_name)

# %%
train_csv_path = pth.join(data_base_path, train_csv_name)
train_df = pd.read_csv(train_csv_path)
train_dict = {k:v for k, v in train_df.values}

submission_csv_path = pth.join(data_base_path, submission_csv_name)
submission_df = pd.read_csv(submission_csv_path)
# submission_df.head()

category_csv_path = pth.join(data_base_path, category_csv_name)
category_df = pd.read_csv(category_csv_path)
category_dict = {k:v for k, v in category_df.values}
# category_df.head()

# %%
train_tfrecord_path
# Out:
# 'data/public/all_train.tfrecords'

# %% [markdown]
# ### Model

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import cv2

import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split, KFold, RepeatedKFold, GroupKFold, RepeatedStratifiedKFold
from sklearn.utils import shuffle

import numpy as np
import pandas as pd
import os
import os.path as pth
import shutil
import time
from tqdm import tqdm

import itertools
from itertools import product, combinations

import numpy as np
from PIL import Image

from IPython.display import clear_output

from multiprocessing import Process, Queue
import datetime

import tensorflow.keras as keras

from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras.layers import Input, Dense, Activation, BatchNormalization, \
                                    Flatten, Conv3D, AveragePooling3D, MaxPooling3D, Dropout, \
                                    Concatenate, GlobalMaxPool3D, GlobalAvgPool3D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint,LearningRateScheduler, \
                                        EarlyStopping
from tensorflow.keras.losses import mean_squared_error, mean_absolute_error
from tensorflow.keras import backend as K
from tensorflow.keras.constraints import max_norm

# %%
conv_comb_list = []
conv_comb_list += [(0,)]

base_channel_list = [0]

fc_list = [0] # 128, 0

# between_type_list = [None, 'avg', 'max']
between_type_list = ['avg']

batch_size_list = [80]

activation_list = ['relu']

# len(conv_comb_list), conv_comb_list

# %%
def build_cnn(config):
    input_layer = Input(shape=config['input_shape'], name='input_layer')
    pret_model = my_model(
        input_tensor=input_layer, include_top=False, weights='imagenet', 
        input_shape=config['input_shape'], pooling=config['between_type'], 
        classes=config['output_size']
    )

    pret_model.trainable = False
    
    x = pret_model.output
    
    if config['between_type'] == None:
        x = Flatten(name='flatten_layer')(x)
        
    if config['is_dropout']:
        x = Dropout(config['dropout_rate'], name='output_dropout')(x)    
            
    x = Dense(config['output_size'], activation=config['output_activation'], 
          name='output_fc')(x)
#     x = Activation(activation=config['output_activation'], name='output_activation')(x)
    model = Model(inputs=input_layer, outputs=x, name='{}'.format(BASE_MODEL_NAME))

    return model

# %%
model = build_cnn(config)
model.summary(line_length=150)
del model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "MobileNetV2-for-upload"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_layer (InputLayer)                         [(None, 270, 480, 3)]            0
# ______________________________________________________________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)                        (None, 271, 481, 3)              0                 input_layer[0][0]
# ______________________________________________________________________________________________________________________________________________________
# Conv1 (Conv2D)                                   (None, 135, 240, 32)             864               Conv1_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)                    (None, 135, 240, 32)             128               Conv1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# Conv1_relu (ReLU)                                (None, 135, 240, 32)             0                 bn_Conv1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_depthwise (DepthwiseConv2D)        (None, 135, 240, 32)             288               Conv1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_depthwise_BN (BatchNormalization)  (None, 135, 240, 32)             128               expanded_conv_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_depthwise_relu (ReLU)              (None, 135, 240, 32)             0                 expanded_conv_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_project (Conv2D)                   (None, 135, 240, 16)             512               expanded_conv_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_project_BN (BatchNormalization)    (None, 135, 240, 16)             64                expanded_conv_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_expand (Conv2D)                          (None, 135, 240, 96)             1536              expanded_conv_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_expand_BN (BatchNormalization)           (None, 135, 240, 96)             384               block_1_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_expand_relu (ReLU)                       (None, 135, 240, 96)             0                 block_1_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)                      (None, 137, 241, 96)             0                 block_1_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_depthwise (DepthwiseConv2D)              (None, 68, 120, 96)              864               block_1_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNormalization)        (None, 68, 120, 96)              384               block_1_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)                    (None, 68, 120, 96)              0                 block_1_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_project (Conv2D)                         (None, 68, 120, 24)              2304              block_1_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_project_BN (BatchNormalization)          (None, 68, 120, 24)              96                block_1_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_expand (Conv2D)                          (None, 68, 120, 144)             3456              block_1_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_expand_BN (BatchNormalization)           (None, 68, 120, 144)             576               block_2_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_expand_relu (ReLU)                       (None, 68, 120, 144)             0                 block_2_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_depthwise (DepthwiseConv2D)              (None, 68, 120, 144)             1296              block_2_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNormalization)        (None, 68, 120, 144)             576               block_2_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)                    (None, 68, 120, 144)             0                 block_2_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_project (Conv2D)                         (None, 68, 120, 24)              3456              block_2_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_project_BN (BatchNormalization)          (None, 68, 120, 24)              96                block_2_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_add (Add)                                (None, 68, 120, 24)              0                 block_1_project_BN[0][0]
#                                                                                                     block_2_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_expand (Conv2D)                          (None, 68, 120, 144)             3456              block_2_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_expand_BN (BatchNormalization)           (None, 68, 120, 144)             576               block_3_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_expand_relu (ReLU)                       (None, 68, 120, 144)             0                 block_3_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)                      (None, 69, 121, 144)             0                 block_3_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_depthwise (DepthwiseConv2D)              (None, 34, 60, 144)              1296              block_3_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNormalization)        (None, 34, 60, 144)              576               block_3_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)                    (None, 34, 60, 144)              0                 block_3_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_project (Conv2D)                         (None, 34, 60, 32)               4608              block_3_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_project_BN (BatchNormalization)          (None, 34, 60, 32)               128               block_3_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_expand (Conv2D)                          (None, 34, 60, 192)              6144              block_3_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_expand_BN (BatchNormalization)           (None, 34, 60, 192)              768               block_4_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_expand_relu (ReLU)                       (None, 34, 60, 192)              0                 block_4_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_depthwise (DepthwiseConv2D)              (None, 34, 60, 192)              1728              block_4_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNormalization)        (None, 34, 60, 192)              768               block_4_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)                    (None, 34, 60, 192)              0                 block_4_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_project (Conv2D)                         (None, 34, 60, 32)               6144              block_4_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_project_BN (BatchNormalization)          (None, 34, 60, 32)               128               block_4_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_add (Add)                                (None, 34, 60, 32)               0                 block_3_project_BN[0][0]
#                                                                                                     block_4_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_expand (Conv2D)                          (None, 34, 60, 192)              6144              block_4_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_expand_BN (BatchNormalization)           (None, 34, 60, 192)              768               block_5_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_expand_relu (ReLU)                       (None, 34, 60, 192)              0                 block_5_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_depthwise (DepthwiseConv2D)              (None, 34, 60, 192)              1728              block_5_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNormalization)        (None, 34, 60, 192)              768               block_5_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)                    (None, 34, 60, 192)              0                 block_5_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_project (Conv2D)                         (None, 34, 60, 32)               6144              block_5_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_project_BN (BatchNormalization)          (None, 34, 60, 32)               128               block_5_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_add (Add)                                (None, 34, 60, 32)               0                 block_4_add[0][0]
#                                                                                                     block_5_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_expand (Conv2D)                          (None, 34, 60, 192)              6144              block_5_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_expand_BN (BatchNormalization)           (None, 34, 60, 192)              768               block_6_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_expand_relu (ReLU)                       (None, 34, 60, 192)              0                 block_6_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)                      (None, 35, 61, 192)              0                 block_6_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_depthwise (DepthwiseConv2D)              (None, 17, 30, 192)              1728              block_6_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNormalization)        (None, 17, 30, 192)              768               block_6_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)                    (None, 17, 30, 192)              0                 block_6_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_project (Conv2D)                         (None, 17, 30, 64)               12288             block_6_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_project_BN (BatchNormalization)          (None, 17, 30, 64)               256               block_6_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_expand (Conv2D)                          (None, 17, 30, 384)              24576             block_6_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_expand_BN (BatchNormalization)           (None, 17, 30, 384)              1536              block_7_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_expand_relu (ReLU)                       (None, 17, 30, 384)              0                 block_7_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_depthwise (DepthwiseConv2D)              (None, 17, 30, 384)              3456              block_7_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNormalization)        (None, 17, 30, 384)              1536              block_7_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)                    (None, 17, 30, 384)              0                 block_7_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_project (Conv2D)                         (None, 17, 30, 64)               24576             block_7_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_project_BN (BatchNormalization)          (None, 17, 30, 64)               256               block_7_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_add (Add)                                (None, 17, 30, 64)               0                 block_6_project_BN[0][0]
#                                                                                                     block_7_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_expand (Conv2D)                          (None, 17, 30, 384)              24576             block_7_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_expand_BN (BatchNormalization)           (None, 17, 30, 384)              1536              block_8_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_expand_relu (ReLU)                       (None, 17, 30, 384)              0                 block_8_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_depthwise (DepthwiseConv2D)              (None, 17, 30, 384)              3456              block_8_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNormalization)        (None, 17, 30, 384)              1536              block_8_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)                    (None, 17, 30, 384)              0                 block_8_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_project (Conv2D)                         (None, 17, 30, 64)               24576             block_8_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_project_BN (BatchNormalization)          (None, 17, 30, 64)               256               block_8_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_add (Add)                                (None, 17, 30, 64)               0                 block_7_add[0][0]
#                                                                                                     block_8_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_expand (Conv2D)                          (None, 17, 30, 384)              24576             block_8_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_expand_BN (BatchNormalization)           (None, 17, 30, 384)              1536              block_9_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_expand_relu (ReLU)                       (None, 17, 30, 384)              0                 block_9_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_depthwise (DepthwiseConv2D)              (None, 17, 30, 384)              3456              block_9_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNormalization)        (None, 17, 30, 384)              1536              block_9_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)                    (None, 17, 30, 384)              0                 block_9_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_project (Conv2D)                         (None, 17, 30, 64)               24576             block_9_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_project_BN (BatchNormalization)          (None, 17, 30, 64)               256               block_9_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_add (Add)                                (None, 17, 30, 64)               0                 block_8_add[0][0]
#                                                                                                     block_9_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_expand (Conv2D)                         (None, 17, 30, 384)              24576             block_9_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_expand_BN (BatchNormalization)          (None, 17, 30, 384)              1536              block_10_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_expand_relu (ReLU)                      (None, 17, 30, 384)              0                 block_10_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_depthwise (DepthwiseConv2D)             (None, 17, 30, 384)              3456              block_10_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNormalization)       (None, 17, 30, 384)              1536              block_10_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)                   (None, 17, 30, 384)              0                 block_10_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_project (Conv2D)                        (None, 17, 30, 96)               36864             block_10_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_project_BN (BatchNormalization)         (None, 17, 30, 96)               384               block_10_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_expand (Conv2D)                         (None, 17, 30, 576)              55296             block_10_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_expand_BN (BatchNormalization)          (None, 17, 30, 576)              2304              block_11_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_expand_relu (ReLU)                      (None, 17, 30, 576)              0                 block_11_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_depthwise (DepthwiseConv2D)             (None, 17, 30, 576)              5184              block_11_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNormalization)       (None, 17, 30, 576)              2304              block_11_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)                   (None, 17, 30, 576)              0                 block_11_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_project (Conv2D)                        (None, 17, 30, 96)               55296             block_11_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_project_BN (BatchNormalization)         (None, 17, 30, 96)               384               block_11_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_add (Add)                               (None, 17, 30, 96)               0                 block_10_project_BN[0][0]
#                                                                                                     block_11_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_expand (Conv2D)                         (None, 17, 30, 576)              55296             block_11_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_expand_BN (BatchNormalization)          (None, 17, 30, 576)              2304              block_12_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_expand_relu (ReLU)                      (None, 17, 30, 576)              0                 block_12_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_depthwise (DepthwiseConv2D)             (None, 17, 30, 576)              5184              block_12_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNormalization)       (None, 17, 30, 576)              2304              block_12_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)                   (None, 17, 30, 576)              0                 block_12_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_project (Conv2D)                        (None, 17, 30, 96)               55296             block_12_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_project_BN (BatchNormalization)         (None, 17, 30, 96)               384               block_12_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_add (Add)                               (None, 17, 30, 96)               0                 block_11_add[0][0]
#                                                                                                     block_12_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_expand (Conv2D)                         (None, 17, 30, 576)              55296             block_12_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_expand_BN (BatchNormalization)          (None, 17, 30, 576)              2304              block_13_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_expand_relu (ReLU)                      (None, 17, 30, 576)              0                 block_13_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)                     (None, 19, 31, 576)              0                 block_13_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_depthwise (DepthwiseConv2D)             (None, 9, 15, 576)               5184              block_13_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNormalization)       (None, 9, 15, 576)               2304              block_13_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)                   (None, 9, 15, 576)               0                 block_13_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_project (Conv2D)                        (None, 9, 15, 160)               92160             block_13_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_project_BN (BatchNormalization)         (None, 9, 15, 160)               640               block_13_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_expand (Conv2D)                         (None, 9, 15, 960)               153600            block_13_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_expand_BN (BatchNormalization)          (None, 9, 15, 960)               3840              block_14_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_expand_relu (ReLU)                      (None, 9, 15, 960)               0                 block_14_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_depthwise (DepthwiseConv2D)             (None, 9, 15, 960)               8640              block_14_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNormalization)       (None, 9, 15, 960)               3840              block_14_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)                   (None, 9, 15, 960)               0                 block_14_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_project (Conv2D)                        (None, 9, 15, 160)               153600            block_14_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_project_BN (BatchNormalization)         (None, 9, 15, 160)               640               block_14_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_add (Add)                               (None, 9, 15, 160)               0                 block_13_project_BN[0][0]
#                                                                                                     block_14_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_expand (Conv2D)                         (None, 9, 15, 960)               153600            block_14_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_expand_BN (BatchNormalization)          (None, 9, 15, 960)               3840              block_15_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_expand_relu (ReLU)                      (None, 9, 15, 960)               0                 block_15_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_depthwise (DepthwiseConv2D)             (None, 9, 15, 960)               8640              block_15_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNormalization)       (None, 9, 15, 960)               3840              block_15_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)                   (None, 9, 15, 960)               0                 block_15_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_project (Conv2D)                        (None, 9, 15, 160)               153600            block_15_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_project_BN (BatchNormalization)         (None, 9, 15, 160)               640               block_15_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_add (Add)                               (None, 9, 15, 160)               0                 block_14_add[0][0]
#                                                                                                     block_15_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_expand (Conv2D)                         (None, 9, 15, 960)               153600            block_15_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_expand_BN (BatchNormalization)          (None, 9, 15, 960)               3840              block_16_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_expand_relu (ReLU)                      (None, 9, 15, 960)               0                 block_16_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_depthwise (DepthwiseConv2D)             (None, 9, 15, 960)               8640              block_16_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNormalization)       (None, 9, 15, 960)               3840              block_16_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)                   (None, 9, 15, 960)               0                 block_16_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_project (Conv2D)                        (None, 9, 15, 320)               307200            block_16_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_project_BN (BatchNormalization)         (None, 9, 15, 320)               1280              block_16_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# Conv_1 (Conv2D)                                  (None, 9, 15, 1280)              409600            block_16_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)                   (None, 9, 15, 1280)              5120              Conv_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# out_relu (ReLU)                                  (None, 9, 15, 1280)              0                 Conv_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# global_average_pooling2d (GlobalAveragePooling2D (None, 1280)                     0                 out_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# output_fc (Dense)                                (None, 1049)                     1343769           global_average_pooling2d[0][0]
# ======================================================================================================================================================
# Total params: 3,601,753
# Trainable params: 1,343,769
# Non-trainable params: 2,257,984
# ______________________________________________________________________________________________________________________________________________________

# %%
origin_train_len = len(train_df) / 5 * 4
origin_val_len = len(train_df) / 5 * 1

train_num_steps = int(np.ceil((origin_train_len)/config['batch_size']))
val_num_steps = int(np.ceil((origin_val_len)/config['batch_size']))

# %%
model_base_path = data_base_path
model_checkpoint_path = pth.join(model_base_path, 'checkpoint')

# %%
def get_lr_callback():
    lr_start   = 0.000001*10*0.5
    lr_max     = 0.0000005 * config['batch_size'] * 10*0.5
    lr_min     = 0.000001 * 10*0.5
    lr_ramp_ep = 5
    lr_sus_ep  = 0
    lr_decay   = 0.8
   
     
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start   
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max    
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min    
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose = False)
    return lr_callback

# %%
for conv_comb, activation, base_channel, \
    between_type, fc_num, batch_size \
        in itertools.product(conv_comb_list, activation_list,
                              base_channel_list, between_type_list, fc_list,
                              batch_size_list):
    config['conv']['conv_num'] = conv_comb
    config['conv']['base_channel'] = base_channel
    config['activation'] = activation
    config['between_type'] = between_type
    config['fc']['fc_num'] = fc_num
    config['batch_size'] = batch_size

    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])
    base += '_input_{}'.format(config['input_shape'][0])
    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print(model_name)

    ### Define dataset
    dataset = tf.data.TFRecordDataset(train_tfrecord_path, compression_type='GZIP')
    dataset = dataset.map(_parse_image_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # dataset = dataset.cache()
    dataset = dataset.map(map_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.map(resize_and_crop_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.map(image_aug_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(config['buffer_size'])
    dataset = dataset.batch(config['batch_size'])
    dataset = dataset.map(post_process_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    val_dataset = tf.data.TFRecordDataset(val_tfrecord_path, compression_type='GZIP')
    val_dataset = val_dataset.map(_parse_image_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    val_dataset = val_dataset.map(map_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    val_dataset = val_dataset.map(resize_and_crop_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.map(image_aug_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.shuffle(config['buffer_size'])
    val_dataset = val_dataset.batch(config['batch_size'])
    val_dataset = val_dataset.map(post_process_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.cache()
    val_dataset = val_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
#     model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
#                   metrics=['acc', 'Precision', 'Recall', 'AUC'])
    initial_epoch = 0

    if pth.isdir(model_path) and len([_ for _ in os.listdir(model_path) if _.endswith('hdf5')]) >= 1:
        model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])

        model_chk_name = sorted(os.listdir(model_path))[-1]
        initial_epoch = int(model_chk_name.split('-')[0])
        model.load_weights(pth.join(model_path, model_chk_name))
    else:
        model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
                     metrics=['acc', 'Precision', 'Recall', 'AUC'])
        
        PRE_TRAIN_EPOCH = 6
        model.fit(
            x=dataset, epochs=PRE_TRAIN_EPOCH, # train only top layers for just a few epochs.
            validation_data=val_dataset, shuffle=True,
            #callbacks = [checkpointer, es], #batch_size=config['batch_size']
            initial_epoch=initial_epoch,
            # steps_per_epoch=train_num_steps, validation_steps=val_num_steps,
            verbose=1)
        
        for i, layer in enumerate(model.layers):
            print(i, layer.name)
        
        for layer in model.layers[:135]:
            layer.trainable = False
        for layer in model.layers[135:]:
            layer.trainable = True
        
        model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
        
        initial_epoch=PRE_TRAIN_EPOCH
            
    # ### Freeze first layer
    # conv_list = [layer for layer in model.layers if isinstance(layer, keras.layers.Conv2D)]
    # conv_list[0].trainable = False
    # # conv_list[1].trainable = False

    os.makedirs(model_path, exist_ok=True)
    model_filename = pth.join(model_path, '{epoch:06d}-{val_loss:0.6f}-{loss:0.6f}.hdf5')
    checkpointer = ModelCheckpoint(
        filepath=model_filename, verbose=1, 
        period=1, save_best_only=True, 
        monitor='val_loss'
    )
    es = EarlyStopping(monitor='val_loss', verbose=1, patience=10)

    hist = model.fit(
        x=dataset, epochs=config['num_epoch'], 
        validation_data=val_dataset, shuffle=True,
        callbacks = [get_lr_callback(), checkpointer, es], #batch_size=config['batch_size']
        initial_epoch=initial_epoch,
        # steps_per_epoch=train_num_steps, validation_steps=val_num_steps,
        verbose=1
    )

    model_analysis_path = model_path.replace('checkpoint', 'analysis')
    visualization_path = pth.join(model_analysis_path,'visualization')
    os.makedirs(visualization_path, exist_ok=True)
    
    print()
    # clear_output()        
    for each_label in ['loss', 'acc', 'precision', 'recall', 'auc']:
        fig, ax = plt.subplots()
        ax.plot(hist.history[each_label], 'g', label='train_{}'.format(each_label))
        ax.plot(hist.history['val_{}'.format(each_label)], 'r', label='val_{}'.format(each_label))
        ax.set_xlabel('epoch')
        ax.set_ylabel('loss')
        ax.legend(loc='upper left')
        if not each_label == 'loss':
            plt.ylim(0, 1)
        plt.show()
        filename = 'learning_curve_{}'.format(each_label)
#             fig.savefig(pth.join(visualization_path, filename), transparent=True)
        plt.cla()
        plt.clf()
        plt.close('all')

    np.savez_compressed(pth.join(visualization_path, 'learning_curve'), 
                        loss=hist.history['loss'], 
                        val_loss=hist.history['val_loss'],
                        acc=hist.history['acc'], 
                        val_acc=hist.history['val_acc'],
                        precision=hist.history['precision'], 
                        vaval_precisionl_mae=hist.history['val_precision'],  
                        recall=hist.history['recall'],
                        val_recall=hist.history['val_recall'],
                        auc=hist.history['auc'],
                        val_auc=hist.history['val_auc']
                        )

    model.save(pth.join(model_path, '000000_last.hdf5'))
    K.clear_session()
    del(model)
    
    model_analysis_base_path = pth.join(model_base_path, 'analysis', model_name) 
    with open(pth.join(model_analysis_base_path, 'config.json'), 'w') as f:
        json.dump(config, f)

    chk_name_list = sorted([name for name in os.listdir(model_path) if name != '000000_last.hdf5'])
    for chk_name in chk_name_list[:-5]:
        os.remove(pth.join(model_path, chk_name))
    # clear_output()
# Out:
# MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/6
# 882/882 [==============================] - 261s 296ms/step - loss: 3.0830 - acc: 0.5121 - precision: 0.9682 - recall: 0.2381 - auc: 0.8892 - val_loss: 1.5710 - val_acc: 0.7090 - val_precision: 0.9598 - val_recall: 0.5087 - val_auc: 0.9640
# Epoch 2/6
# 882/882 [==============================] - 260s 295ms/step - loss: 1.1399 - acc: 0.7766 - precision: 0.9538 - recall: 0.6407 - auc: 0.9755 - val_loss: 1.1713 - val_acc: 0.7671 - val_precision: 0.9361 - val_recall: 0.6659 - val_auc: 0.9698
# Epoch 3/6
# 882/882 [==============================] - 260s 295ms/step - loss: 0.8273 - acc: 0.8272 - precision: 0.9443 - recall: 0.7518 - auc: 0.9810 - val_loss: 1.0412 - val_acc: 0.7914 - val_precision: 0.9236 - val_recall: 0.7180 - val_auc: 0.9709
# Epoch 4/6
# 882/882 [==============================] - 261s 296ms/step - loss: 0.6998 - acc: 0.8502 - precision: 0.9371 - recall: 0.7974 - auc: 0.9830 - val_loss: 0.9728 - val_acc: 0.8059 - val_precision: 0.9165 - val_recall: 0.7489 - val_auc: 0.9718
# Epoch 5/6
# 882/882 [==============================] - 260s 295ms/step - loss: 0.6147 - acc: 0.8666 - precision: 0.9366 - recall: 0.8252 - auc: 0.9846 - val_loss: 0.9448 - val_acc: 0.8078 - val_precision: 0.9088 - val_recall: 0.7641 - val_auc: 0.9719
# Epoch 6/6
# 882/882 [==============================] - 260s 295ms/step - loss: 0.5540 - acc: 0.8787 - precision: 0.9357 - recall: 0.8466 - auc: 0.9863 - val_loss: 0.9130 - val_acc: 0.8133 - val_precision: 0.9064 - val_recall: 0.7750 - val_auc: 0.9730
# 0 input_layer
# 1 Conv1_pad
# 2 Conv1
# 3 bn_Conv1
# 4 Conv1_relu
# 5 expanded_conv_depthwise
# 6 expanded_conv_depthwise_BN
# 7 expanded_conv_depthwise_relu
# 8 expanded_conv_project
# 9 expanded_conv_project_BN
# 10 block_1_expand
# 11 block_1_expand_BN
# 12 block_1_expand_relu
# 13 block_1_pad
# 14 block_1_depthwise
# 15 block_1_depthwise_BN
# 16 block_1_depthwise_relu
# 17 block_1_project
# 18 block_1_project_BN
# 19 block_2_expand
# 20 block_2_expand_BN
# 21 block_2_expand_relu
# 22 block_2_depthwise
# 23 block_2_depthwise_BN
# 24 block_2_depthwise_relu
# 25 block_2_project
# 26 block_2_project_BN
# 27 block_2_add
# 28 block_3_expand
# 29 block_3_expand_BN
# 30 block_3_expand_relu
# 31 block_3_pad
# 32 block_3_depthwise
# 33 block_3_depthwise_BN
# 34 block_3_depthwise_relu
# 35 block_3_project
# 36 block_3_project_BN
# 37 block_4_expand
# 38 block_4_expand_BN
# 39 block_4_expand_relu
# 40 block_4_depthwise
# 41 block_4_depthwise_BN
# 42 block_4_depthwise_relu
# 43 block_4_project
# 44 block_4_project_BN
# 45 block_4_add
# 46 block_5_expand
# 47 block_5_expand_BN
# 48 block_5_expand_relu
# 49 block_5_depthwise
# 50 block_5_depthwise_BN
# 51 block_5_depthwise_relu
# 52 block_5_project
# 53 block_5_project_BN
# 54 block_5_add
# 55 block_6_expand
# 56 block_6_expand_BN
# 57 block_6_expand_relu
# 58 block_6_pad
# 59 block_6_depthwise
# 60 block_6_depthwise_BN
# 61 block_6_depthwise_relu
# 62 block_6_project
# 63 block_6_project_BN
# 64 block_7_expand
# 65 block_7_expand_BN
# 66 block_7_expand_relu
# 67 block_7_depthwise
# 68 block_7_depthwise_BN
# 69 block_7_depthwise_relu
# 70 block_7_project
# 71 block_7_project_BN
# 72 block_7_add
# 73 block_8_expand
# 74 block_8_expand_BN
# 75 block_8_expand_relu
# 76 block_8_depthwise
# 77 block_8_depthwise_BN
# 78 block_8_depthwise_relu
# 79 block_8_project
# 80 block_8_project_BN
# 81 block_8_add
# 82 block_9_expand
# 83 block_9_expand_BN
# 84 block_9_expand_relu
# 85 block_9_depthwise
# 86 block_9_depthwise_BN
# 87 block_9_depthwise_relu
# 88 block_9_project
# 89 block_9_project_BN
# 90 block_9_add
# 91 block_10_expand
# 92 block_10_expand_BN
# 93 block_10_expand_relu
# 94 block_10_depthwise
# 95 block_10_depthwise_BN
# 96 block_10_depthwise_relu
# 97 block_10_project
# 98 block_10_project_BN
# 99 block_11_expand
# 100 block_11_expand_BN
# 101 block_11_expand_relu
# 102 block_11_depthwise
# 103 block_11_depthwise_BN
# 104 block_11_depthwise_relu
# 105 block_11_project
# 106 block_11_project_BN
# 107 block_11_add
# 108 block_12_expand
# 109 block_12_expand_BN
# 110 block_12_expand_relu
# 111 block_12_depthwise
# 112 block_12_depthwise_BN
# 113 block_12_depthwise_relu
# 114 block_12_project
# 115 block_12_project_BN
# 116 block_12_add
# 117 block_13_expand
# 118 block_13_expand_BN
# 119 block_13_expand_relu
# 120 block_13_pad
# 121 block_13_depthwise
# 122 block_13_depthwise_BN
# 123 block_13_depthwise_relu
# 124 block_13_project
# 125 block_13_project_BN
# 126 block_14_expand
# 127 block_14_expand_BN
# 128 block_14_expand_relu
# 129 block_14_depthwise
# 130 block_14_depthwise_BN
# 131 block_14_depthwise_relu
# 132 block_14_project
# 133 block_14_project_BN
# 134 block_14_add
# 135 block_15_expand
# 136 block_15_expand_BN
# 137 block_15_expand_relu
# 138 block_15_depthwise
# 139 block_15_depthwise_BN
# 140 block_15_depthwise_relu
# 141 block_15_project
# 142 block_15_project_BN
# 143 block_15_add
# 144 block_16_expand
# 145 block_16_expand_BN
# 146 block_16_expand_relu
# 147 block_16_depthwise
# 148 block_16_depthwise_BN
# 149 block_16_depthwise_relu
# 150 block_16_project
# 151 block_16_project_BN
# 152 Conv_1
# 153 Conv_1_bn
# 154 out_relu
# 155 global_average_pooling2d_1
# 156 output_fc
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 7/10000
#     882/Unknown - 246s 279ms/step - loss: 0.5064 - acc: 0.8866 - precision: 0.9534 - recall: 0.8462 - auc: 0.9891
# Epoch 00007: val_loss improved from inf to 1.33983, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000007-1.339834-0.506408.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.5064 - acc: 0.8866 - precision: 0.9534 - recall: 0.8462 - auc: 0.9891 - val_loss: 1.3398 - val_acc: 0.7537 - val_precision: 0.8199 - val_recall: 0.7273 - val_auc: 0.9535
# Epoch 8/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.2291 - acc: 0.9477 - precision: 0.9781 - recall: 0.9246 - auc: 0.9962
# Epoch 00008: val_loss improved from 1.33983 to 0.68934, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000008-0.689335-0.229245.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.2292 - acc: 0.9477 - precision: 0.9781 - recall: 0.9246 - auc: 0.9962 - val_loss: 0.6893 - val_acc: 0.8517 - val_precision: 0.9077 - val_recall: 0.8275 - val_auc: 0.9797
# Epoch 9/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1539 - acc: 0.9656 - precision: 0.9855 - recall: 0.9492 - auc: 0.9980
# Epoch 00009: val_loss improved from 0.68934 to 0.58965, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000009-0.589647-0.154099.hdf5
# 882/882 [==============================] - 298s 338ms/step - loss: 0.1541 - acc: 0.9656 - precision: 0.9855 - recall: 0.9492 - auc: 0.9980 - val_loss: 0.5896 - val_acc: 0.8700 - val_precision: 0.9312 - val_recall: 0.8426 - val_auc: 0.9841
# Epoch 10/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1149 - acc: 0.9754 - precision: 0.9897 - recall: 0.9634 - auc: 0.9986
# Epoch 00010: val_loss improved from 0.58965 to 0.51530, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000010-0.515305-0.115087.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.1151 - acc: 0.9754 - precision: 0.9897 - recall: 0.9634 - auc: 0.9985 - val_loss: 0.5153 - val_acc: 0.8857 - val_precision: 0.9368 - val_recall: 0.8619 - val_auc: 0.9856
# Epoch 11/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0886 - acc: 0.9812 - precision: 0.9920 - recall: 0.9729 - auc: 0.9990
# Epoch 00011: val_loss improved from 0.51530 to 0.48085, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000011-0.480851-0.088731.hdf5
# 882/882 [==============================] - 298s 337ms/step - loss: 0.0887 - acc: 0.9811 - precision: 0.9920 - recall: 0.9729 - auc: 0.9990 - val_loss: 0.4809 - val_acc: 0.8954 - val_precision: 0.9420 - val_recall: 0.8742 - val_auc: 0.9865
# Epoch 12/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0756 - acc: 0.9846 - precision: 0.9932 - recall: 0.9778 - auc: 0.9990
# Epoch 00012: val_loss improved from 0.48085 to 0.43959, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000012-0.439588-0.075797.hdf5
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0758 - acc: 0.9846 - precision: 0.9932 - recall: 0.9777 - auc: 0.9990 - val_loss: 0.4396 - val_acc: 0.9011 - val_precision: 0.9493 - val_recall: 0.8815 - val_auc: 0.9882
# Epoch 13/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0662 - acc: 0.9865 - precision: 0.9938 - recall: 0.9808 - auc: 0.9993
# Epoch 00013: val_loss improved from 0.43959 to 0.42371, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000013-0.423708-0.066299.hdf5
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0663 - acc: 0.9865 - precision: 0.9938 - recall: 0.9808 - auc: 0.9993 - val_loss: 0.4237 - val_acc: 0.9069 - val_precision: 0.9502 - val_recall: 0.8863 - val_auc: 0.9883
# Epoch 14/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0577 - acc: 0.9889 - precision: 0.9953 - recall: 0.9836 - auc: 0.9994
# Epoch 00014: val_loss improved from 0.42371 to 0.39525, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000014-0.395246-0.057826.hdf5
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0578 - acc: 0.9889 - precision: 0.9953 - recall: 0.9836 - auc: 0.9994 - val_loss: 0.3952 - val_acc: 0.9127 - val_precision: 0.9556 - val_recall: 0.8906 - val_auc: 0.9898
# Epoch 15/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0534 - acc: 0.9894 - precision: 0.9952 - recall: 0.9844 - auc: 0.9994
# Epoch 00015: val_loss did not improve from 0.39525
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0536 - acc: 0.9894 - precision: 0.9952 - recall: 0.9844 - auc: 0.9994 - val_loss: 0.4051 - val_acc: 0.9107 - val_precision: 0.9528 - val_recall: 0.8919 - val_auc: 0.9892
# Epoch 16/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0484 - acc: 0.9905 - precision: 0.9960 - recall: 0.9867 - auc: 0.9994
# Epoch 00016: val_loss improved from 0.39525 to 0.38820, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000016-0.388204-0.048463.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0485 - acc: 0.9905 - precision: 0.9960 - recall: 0.9867 - auc: 0.9994 - val_loss: 0.3882 - val_acc: 0.9149 - val_precision: 0.9564 - val_recall: 0.8972 - val_auc: 0.9898
# Epoch 17/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0422 - acc: 0.9916 - precision: 0.9963 - recall: 0.9880 - auc: 0.9996
# Epoch 00017: val_loss improved from 0.38820 to 0.38392, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000017-0.383917-0.042281.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0423 - acc: 0.9916 - precision: 0.9963 - recall: 0.9880 - auc: 0.9996 - val_loss: 0.3839 - val_acc: 0.9149 - val_precision: 0.9551 - val_recall: 0.8979 - val_auc: 0.9896
# Epoch 18/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0424 - acc: 0.9918 - precision: 0.9963 - recall: 0.9876 - auc: 0.9996
# Epoch 00018: val_loss improved from 0.38392 to 0.37905, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000018-0.379047-0.042504.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0425 - acc: 0.9918 - precision: 0.9963 - recall: 0.9876 - auc: 0.9996 - val_loss: 0.3790 - val_acc: 0.9165 - val_precision: 0.9567 - val_recall: 0.8993 - val_auc: 0.9898
# Epoch 19/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0382 - acc: 0.9927 - precision: 0.9968 - recall: 0.9893 - auc: 0.9996
# Epoch 00019: val_loss did not improve from 0.37905
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0383 - acc: 0.9927 - precision: 0.9968 - recall: 0.9892 - auc: 0.9996 - val_loss: 0.3791 - val_acc: 0.9170 - val_precision: 0.9567 - val_recall: 0.9018 - val_auc: 0.9894
# Epoch 20/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0385 - acc: 0.9925 - precision: 0.9968 - recall: 0.9893 - auc: 0.9996
# Epoch 00020: val_loss improved from 0.37905 to 0.37392, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000020-0.373925-0.038573.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0386 - acc: 0.9925 - precision: 0.9968 - recall: 0.9893 - auc: 0.9996 - val_loss: 0.3739 - val_acc: 0.9177 - val_precision: 0.9559 - val_recall: 0.9020 - val_auc: 0.9900
# Epoch 21/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0367 - acc: 0.9931 - precision: 0.9969 - recall: 0.9900 - auc: 0.9996
# Epoch 00021: val_loss did not improve from 0.37392
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0368 - acc: 0.9931 - precision: 0.9969 - recall: 0.9900 - auc: 0.9996 - val_loss: 0.3762 - val_acc: 0.9168 - val_precision: 0.9554 - val_recall: 0.9028 - val_auc: 0.9898
# Epoch 22/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0366 - acc: 0.9935 - precision: 0.9971 - recall: 0.9903 - auc: 0.9995
# Epoch 00022: val_loss improved from 0.37392 to 0.36651, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000022-0.366513-0.036717.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0367 - acc: 0.9935 - precision: 0.9971 - recall: 0.9903 - auc: 0.9995 - val_loss: 0.3665 - val_acc: 0.9195 - val_precision: 0.9587 - val_recall: 0.9036 - val_auc: 0.9903
# Epoch 23/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0338 - acc: 0.9936 - precision: 0.9971 - recall: 0.9906 - auc: 0.9997
# Epoch 00023: val_loss did not improve from 0.36651
# 882/882 [==============================] - 298s 337ms/step - loss: 0.0339 - acc: 0.9935 - precision: 0.9971 - recall: 0.9906 - auc: 0.9996 - val_loss: 0.3709 - val_acc: 0.9197 - val_precision: 0.9547 - val_recall: 0.9051 - val_auc: 0.9897
# Epoch 24/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0311 - acc: 0.9941 - precision: 0.9975 - recall: 0.9915 - auc: 0.9997
# Epoch 00024: val_loss did not improve from 0.36651
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0313 - acc: 0.9941 - precision: 0.9975 - recall: 0.9914 - auc: 0.9997 - val_loss: 0.3681 - val_acc: 0.9201 - val_precision: 0.9572 - val_recall: 0.9039 - val_auc: 0.9899
# Epoch 25/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0324 - acc: 0.9940 - precision: 0.9975 - recall: 0.9910 - auc: 0.9996
# Epoch 00025: val_loss improved from 0.36651 to 0.36574, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000025-0.365735-0.032545.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0325 - acc: 0.9940 - precision: 0.9975 - recall: 0.9910 - auc: 0.9996 - val_loss: 0.3657 - val_acc: 0.9210 - val_precision: 0.9586 - val_recall: 0.9056 - val_auc: 0.9895
# Epoch 26/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0326 - acc: 0.9937 - precision: 0.9973 - recall: 0.9912 - auc: 0.9996
# Epoch 00026: val_loss did not improve from 0.36574
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0328 - acc: 0.9937 - precision: 0.9973 - recall: 0.9912 - auc: 0.9996 - val_loss: 0.3665 - val_acc: 0.9188 - val_precision: 0.9562 - val_recall: 0.9047 - val_auc: 0.9897
# Epoch 27/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0311 - acc: 0.9941 - precision: 0.9974 - recall: 0.9912 - auc: 0.9997
# Epoch 00027: val_loss did not improve from 0.36574
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0312 - acc: 0.9940 - precision: 0.9974 - recall: 0.9911 - auc: 0.9997 - val_loss: 0.3660 - val_acc: 0.9171 - val_precision: 0.9560 - val_recall: 0.9032 - val_auc: 0.9901
# Epoch 28/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0298 - acc: 0.9945 - precision: 0.9976 - recall: 0.9916 - auc: 0.9998
# Epoch 00028: val_loss improved from 0.36574 to 0.36114, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000028-0.361142-0.029878.hdf5
# 882/882 [==============================] - 298s 337ms/step - loss: 0.0299 - acc: 0.9945 - precision: 0.9976 - recall: 0.9915 - auc: 0.9998 - val_loss: 0.3611 - val_acc: 0.9211 - val_precision: 0.9579 - val_recall: 0.9049 - val_auc: 0.9905
# Epoch 29/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0290 - acc: 0.9947 - precision: 0.9977 - recall: 0.9921 - auc: 0.9998
# Epoch 00029: val_loss did not improve from 0.36114
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0290 - acc: 0.9947 - precision: 0.9977 - recall: 0.9921 - auc: 0.9998 - val_loss: 0.3705 - val_acc: 0.9212 - val_precision: 0.9575 - val_recall: 0.9061 - val_auc: 0.9900
# Epoch 30/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0300 - acc: 0.9943 - precision: 0.9976 - recall: 0.9919 - auc: 0.9997
# Epoch 00030: val_loss did not improve from 0.36114
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0301 - acc: 0.9943 - precision: 0.9976 - recall: 0.9919 - auc: 0.9997 - val_loss: 0.3615 - val_acc: 0.9222 - val_precision: 0.9576 - val_recall: 0.9076 - val_auc: 0.9898
# Epoch 31/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0295 - acc: 0.9946 - precision: 0.9975 - recall: 0.9925 - auc: 0.9997
# Epoch 00031: val_loss improved from 0.36114 to 0.35465, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000031-0.354650-0.029633.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0296 - acc: 0.9946 - precision: 0.9975 - recall: 0.9925 - auc: 0.9997 - val_loss: 0.3547 - val_acc: 0.9230 - val_precision: 0.9583 - val_recall: 0.9077 - val_auc: 0.9905
# Epoch 32/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0279 - acc: 0.9950 - precision: 0.9980 - recall: 0.9924 - auc: 0.9997
# Epoch 00032: val_loss did not improve from 0.35465
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0280 - acc: 0.9950 - precision: 0.9980 - recall: 0.9923 - auc: 0.9997 - val_loss: 0.3644 - val_acc: 0.9201 - val_precision: 0.9566 - val_recall: 0.9062 - val_auc: 0.9900
# Epoch 33/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0264 - acc: 0.9953 - precision: 0.9981 - recall: 0.9929 - auc: 0.9998
# Epoch 00033: val_loss did not improve from 0.35465
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0266 - acc: 0.9953 - precision: 0.9981 - recall: 0.9929 - auc: 0.9998 - val_loss: 0.3600 - val_acc: 0.9213 - val_precision: 0.9569 - val_recall: 0.9073 - val_auc: 0.9899
# Epoch 34/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0266 - acc: 0.9953 - precision: 0.9979 - recall: 0.9928 - auc: 0.9998
# Epoch 00034: val_loss did not improve from 0.35465
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0267 - acc: 0.9953 - precision: 0.9979 - recall: 0.9927 - auc: 0.9997 - val_loss: 0.3574 - val_acc: 0.9226 - val_precision: 0.9567 - val_recall: 0.9072 - val_auc: 0.9903
# Epoch 35/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0275 - acc: 0.9950 - precision: 0.9979 - recall: 0.9924 - auc: 0.9997
# Epoch 00035: val_loss did not improve from 0.35465
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0277 - acc: 0.9950 - precision: 0.9979 - recall: 0.9924 - auc: 0.9997 - val_loss: 0.3608 - val_acc: 0.9203 - val_precision: 0.9580 - val_recall: 0.9056 - val_auc: 0.9900
# Epoch 36/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0266 - acc: 0.9950 - precision: 0.9980 - recall: 0.9926 - auc: 0.9998
# Epoch 00036: val_loss did not improve from 0.35465
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0267 - acc: 0.9950 - precision: 0.9980 - recall: 0.9925 - auc: 0.9998 - val_loss: 0.3570 - val_acc: 0.9230 - val_precision: 0.9581 - val_recall: 0.9081 - val_auc: 0.9906
# Epoch 37/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0271 - acc: 0.9951 - precision: 0.9979 - recall: 0.9925 - auc: 0.9998
# Epoch 00037: val_loss did not improve from 0.35465
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0272 - acc: 0.9951 - precision: 0.9979 - recall: 0.9925 - auc: 0.9998 - val_loss: 0.3635 - val_acc: 0.9203 - val_precision: 0.9562 - val_recall: 0.9067 - val_auc: 0.9900
# Epoch 38/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0258 - acc: 0.9956 - precision: 0.9983 - recall: 0.9932 - auc: 0.9998
# Epoch 00038: val_loss did not improve from 0.35465
# 882/882 [==============================] - 298s 337ms/step - loss: 0.0259 - acc: 0.9956 - precision: 0.9983 - recall: 0.9932 - auc: 0.9998 - val_loss: 0.3714 - val_acc: 0.9194 - val_precision: 0.9555 - val_recall: 0.9048 - val_auc: 0.9895
# Epoch 39/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0262 - acc: 0.9955 - precision: 0.9981 - recall: 0.9931 - auc: 0.9997
# Epoch 00039: val_loss did not improve from 0.35465
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0264 - acc: 0.9955 - precision: 0.9981 - recall: 0.9931 - auc: 0.9997 - val_loss: 0.3603 - val_acc: 0.9214 - val_precision: 0.9571 - val_recall: 0.9061 - val_auc: 0.9901
# Epoch 40/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0257 - acc: 0.9955 - precision: 0.9982 - recall: 0.9933 - auc: 0.9997
# Epoch 00040: val_loss improved from 0.35465 to 0.35178, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000040-0.351775-0.025734.hdf5
# 882/882 [==============================] - 298s 338ms/step - loss: 0.0257 - acc: 0.9955 - precision: 0.9982 - recall: 0.9933 - auc: 0.9997 - val_loss: 0.3518 - val_acc: 0.9225 - val_precision: 0.9576 - val_recall: 0.9085 - val_auc: 0.9905
# Epoch 41/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0270 - acc: 0.9951 - precision: 0.9981 - recall: 0.9930 - auc: 0.9998
# Epoch 00041: val_loss did not improve from 0.35178
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0271 - acc: 0.9950 - precision: 0.9981 - recall: 0.9930 - auc: 0.9998 - val_loss: 0.3552 - val_acc: 0.9207 - val_precision: 0.9573 - val_recall: 0.9064 - val_auc: 0.9900
# Epoch 42/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0251 - acc: 0.9956 - precision: 0.9981 - recall: 0.9931 - auc: 0.9998
# Epoch 00042: val_loss did not improve from 0.35178
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0253 - acc: 0.9956 - precision: 0.9981 - recall: 0.9931 - auc: 0.9998 - val_loss: 0.3565 - val_acc: 0.9213 - val_precision: 0.9571 - val_recall: 0.9071 - val_auc: 0.9901
# Epoch 43/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0238 - acc: 0.9960 - precision: 0.9982 - recall: 0.9939 - auc: 0.9998
# Epoch 00043: val_loss did not improve from 0.35178
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0239 - acc: 0.9960 - precision: 0.9982 - recall: 0.9939 - auc: 0.9998 - val_loss: 0.3549 - val_acc: 0.9223 - val_precision: 0.9583 - val_recall: 0.9077 - val_auc: 0.9901
# Epoch 44/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0243 - acc: 0.9956 - precision: 0.9980 - recall: 0.9933 - auc: 0.9998
# Epoch 00044: val_loss did not improve from 0.35178
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0244 - acc: 0.9956 - precision: 0.9980 - recall: 0.9933 - auc: 0.9998 - val_loss: 0.3610 - val_acc: 0.9216 - val_precision: 0.9570 - val_recall: 0.9072 - val_auc: 0.9897
# Epoch 45/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0235 - acc: 0.9959 - precision: 0.9983 - recall: 0.9939 - auc: 0.9998
# Epoch 00045: val_loss improved from 0.35178 to 0.34841, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000045-0.348410-0.023616.hdf5
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0236 - acc: 0.9959 - precision: 0.9983 - recall: 0.9939 - auc: 0.9998 - val_loss: 0.3484 - val_acc: 0.9238 - val_precision: 0.9575 - val_recall: 0.9097 - val_auc: 0.9903
# Epoch 46/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0221 - acc: 0.9962 - precision: 0.9983 - recall: 0.9937 - auc: 0.9999
# Epoch 00046: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0222 - acc: 0.9962 - precision: 0.9983 - recall: 0.9936 - auc: 0.9999 - val_loss: 0.3489 - val_acc: 0.9239 - val_precision: 0.9583 - val_recall: 0.9101 - val_auc: 0.9903
# Epoch 47/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0239 - acc: 0.9960 - precision: 0.9983 - recall: 0.9938 - auc: 0.9998
# Epoch 00047: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0240 - acc: 0.9960 - precision: 0.9983 - recall: 0.9938 - auc: 0.9998 - val_loss: 0.3599 - val_acc: 0.9216 - val_precision: 0.9571 - val_recall: 0.9079 - val_auc: 0.9899
# Epoch 48/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0229 - acc: 0.9961 - precision: 0.9984 - recall: 0.9942 - auc: 0.9998
# Epoch 00048: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0231 - acc: 0.9961 - precision: 0.9984 - recall: 0.9941 - auc: 0.9998 - val_loss: 0.3564 - val_acc: 0.9233 - val_precision: 0.9577 - val_recall: 0.9092 - val_auc: 0.9900
# Epoch 49/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0229 - acc: 0.9960 - precision: 0.9983 - recall: 0.9937 - auc: 0.9999
# Epoch 00049: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0230 - acc: 0.9960 - precision: 0.9983 - recall: 0.9937 - auc: 0.9998 - val_loss: 0.3554 - val_acc: 0.9230 - val_precision: 0.9568 - val_recall: 0.9078 - val_auc: 0.9901
# Epoch 50/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0232 - acc: 0.9959 - precision: 0.9983 - recall: 0.9938 - auc: 0.9998
# Epoch 00050: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0234 - acc: 0.9959 - precision: 0.9983 - recall: 0.9937 - auc: 0.9998 - val_loss: 0.3618 - val_acc: 0.9227 - val_precision: 0.9566 - val_recall: 0.9074 - val_auc: 0.9898
# Epoch 51/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0228 - acc: 0.9960 - precision: 0.9985 - recall: 0.9938 - auc: 0.9998
# Epoch 00051: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0231 - acc: 0.9960 - precision: 0.9985 - recall: 0.9938 - auc: 0.9998 - val_loss: 0.3534 - val_acc: 0.9241 - val_precision: 0.9567 - val_recall: 0.9101 - val_auc: 0.9902
# Epoch 52/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0232 - acc: 0.9960 - precision: 0.9984 - recall: 0.9939 - auc: 0.9998
# Epoch 00052: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 336ms/step - loss: 0.0233 - acc: 0.9960 - precision: 0.9984 - recall: 0.9939 - auc: 0.9998 - val_loss: 0.3583 - val_acc: 0.9230 - val_precision: 0.9556 - val_recall: 0.9087 - val_auc: 0.9903
# Epoch 53/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0223 - acc: 0.9958 - precision: 0.9982 - recall: 0.9939 - auc: 0.9998
# Epoch 00053: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0224 - acc: 0.9958 - precision: 0.9982 - recall: 0.9939 - auc: 0.9998 - val_loss: 0.3608 - val_acc: 0.9220 - val_precision: 0.9563 - val_recall: 0.9080 - val_auc: 0.9899
# Epoch 54/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0236 - acc: 0.9959 - precision: 0.9984 - recall: 0.9934 - auc: 0.9998
# Epoch 00054: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0237 - acc: 0.9959 - precision: 0.9984 - recall: 0.9934 - auc: 0.9998 - val_loss: 0.3575 - val_acc: 0.9233 - val_precision: 0.9569 - val_recall: 0.9093 - val_auc: 0.9896
# Epoch 55/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0210 - acc: 0.9965 - precision: 0.9986 - recall: 0.9946 - auc: 0.9998
# Epoch 00055: val_loss did not improve from 0.34841
# 882/882 [==============================] - 297s 337ms/step - loss: 0.0211 - acc: 0.9965 - precision: 0.9986 - recall: 0.9946 - auc: 0.9998 - val_loss: 0.3588 - val_acc: 0.9222 - val_precision: 0.9559 - val_recall: 0.9071 - val_auc: 0.9898
# Epoch 00055: early stopping

# %% [markdown]
# ### Inference

# %%
image_feature_description_for_test = {
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    # 'randmark_id': tf.io.FixedLenFeature([], tf.int64),
    # 'id': tf.io.FixedLenFeature([], tf.string),
}

def _parse_image_function_for_test(example_proto):
    return tf.io.parse_single_example(example_proto, image_feature_description_for_test)

def map_func_for_test(target_record):
    img = target_record['image_raw']
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.dtypes.cast(img, tf.float32)
    return img

def resize_and_crop_func_for_test(image):
    result_image = tf.image.resize(image, config['aug']['resize'])
    result_image = tf.image.random_crop(image, size=config['input_shape'], seed=7777)  # revive
    return result_image

def post_process_func_for_test(image):
    # result_image = result_image / 255
    result_image = my_model_base.preprocess_input(image)
    return result_image

# %%
submission_base_path = pth.join(data_base_path, 'submission')
os.makedirs(submission_base_path, exist_ok=True)

# %%
preds = []
for conv_comb, activation, base_channel, \
    between_type, fc_num, batch_size \
        in itertools.product(conv_comb_list, activation_list,
                              base_channel_list, between_type_list, fc_list,
                              batch_size_list):
    config['conv']['conv_num'] = conv_comb
    config['conv']['base_channel'] = base_channel
    config['activation'] = activation
    config['between_type'] = between_type
    config['fc']['fc_num'] = fc_num
    config['batch_size'] = batch_size

    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])
    base += '_input_{}'.format(config['input_shape'][0])
    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print(model_name)

    ### Define dataset
    test_dataset = tf.data.TFRecordDataset(test_tfrecord_path, compression_type='GZIP')
    test_dataset = test_dataset.map(_parse_image_function_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(map_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(resize_and_crop_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.batch(config['batch_size'])
    test_dataset = test_dataset.map(post_process_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
    model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
    initial_epoch = 0

    model_chk_name = sorted(os.listdir(model_path))[-1]
    initial_epoch = int(model_chk_name.split('-')[0])
    model.load_weights(pth.join(model_path, model_chk_name))

    preds = model.predict(test_dataset, verbose=1)
    
    #pred_labels = np.argmax(preds, axis=1)
    #pred_probs = np.array([pred[indice] for pred, indice in zip(preds, pred_labels)])
    
    # argmax --> top3
    pred_labels = np.argsort(-preds)
    
    submission_csv_path = pth.join(data_base_path, submission_csv_name)
    submission_df = pd.read_csv(submission_csv_path)
    
    merged_df = []
    
    RANK_TO_SAVE = 5
    for i in range(RANK_TO_SAVE):
        tmp_df = submission_df.copy()
        
        tmp_labels = pred_labels[:, i]
        tmp_df['landmark_id'] = tmp_labels
        tmp_df['conf'] = np.array([pred[indice] for pred, indice in zip(preds, tmp_labels)])
        merged_df.append(tmp_df)
    
    submission_df = pd.concat(merged_df)
    
    #submission_df['landmark_id'] = pred_labels
    #submission_df['conf'] = pred_probs

    today_str = datetime.date.today().strftime('%Y%m%d')
    result_filename = '{}.csv'.format(model_name)
    submission_csv_fileaname = pth.join(submission_base_path, '_'.join([today_str, result_filename]))
    submission_df.to_csv(submission_csv_fileaname, index=False)
# Out:
# MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#       1/Unknown - 0s 52us/stepWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0134s vs `on_predict_batch_end` time: 0.1903s). Check your callbacks.
# 475/475 [==============================] - 103s 217ms/step

# %%
######## Trashes

# %%
preds = []
for conv_comb, activation, base_channel, \
    between_type, fc_num, batch_size \
        in itertools.product(conv_comb_list, activation_list,
                              base_channel_list, between_type_list, fc_list,
                              batch_size_list):
    config['conv']['conv_num'] = conv_comb
    config['conv']['base_channel'] = base_channel
    config['activation'] = activation
    config['between_type'] = between_type
    config['fc']['fc_num'] = fc_num
    config['batch_size'] = batch_size

    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])
    base += '_input_{}'.format(config['input_shape'][0])
    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print(model_name)

    ### Define dataset
    test_dataset = tf.data.TFRecordDataset(test_tfrecord_path, compression_type='GZIP')
    test_dataset = test_dataset.map(_parse_image_function_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(map_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(resize_and_crop_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.batch(config['batch_size'])
    test_dataset = test_dataset.map(post_process_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
    model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
    initial_epoch = 0

    model_chk_name = sorted(os.listdir(model_path))[-1]
    initial_epoch = int(model_chk_name.split('-')[0])
    model.load_weights(pth.join(model_path, model_chk_name))

    preds = model.predict(test_dataset, verbose=1)
    pred_labels = np.argmax(preds, axis=1)
    pred_probs = np.array([pred[indice] for pred, indice in zip(preds, pred_labels)])

    submission_csv_path = pth.join(data_base_path, submission_csv_name)
    submission_df = pd.read_csv(submission_csv_path)

    submission_df['landmark_id'] = pred_labels
    submission_df['conf'] = pred_probs

    today_str = datetime.date.today().strftime('%Y%m%d')
    result_filename = '{}.csv'.format(model_name)
    submission_csv_fileaname = pth.join(submission_base_path, '_'.join([today_str, result_filename]))
    submission_df.to_csv(submission_csv_fileaname, index=False)
# Out:
# MobileNetV2-for-upload_resize_297_input_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#       1/Unknown - 0s 67us/stepWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0127s vs `on_predict_batch_end` time: 0.1893s). Check your callbacks.
#      98/Unknown - 20s 209ms/step
