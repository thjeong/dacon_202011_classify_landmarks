# %%
import os
import os.path as pth
import json
import shutil
import pandas as pd
from tqdm import tqdm
import tensorflow as tf
import tensorflow.keras as keras

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
BASE_MODEL_NAME = 'InceptionV3-for-upload'
my_model_base = keras.applications.inception_v3
my_model = my_model_base.InceptionV3

config = {
    'is_zscore':True,
    
    # 'input_shape': (540, 960, 3),
    'aug': {
        'resize': (270, 480),
    },
    # 'input_shape': (224, 360, 3),
    'input_shape': (270, 480, 3),

    'output_activation': 'softmax',
    'num_class': 1049,
    'output_size': 1049,
    
    'conv':{
        'conv_num': (0), # (3,5,3),
        'base_channel': 0, # 4,
        'kernel_size': 0, # 3,
        'padding':'same',
        'stride':'X'
    },
    'pool':{
        'type':'X',
        'size':'X',
        'stride':'X',
        'padding':'same'
    },
    'fc':{
        'fc_num': 0,
     },
    
    'activation':'relu',
    
    'between_type': 'avg',
    
    'is_batchnorm': True,
    'is_dropout': False,
    'dropout_rate': 0.5,
    
    'add_dense':True,
    'dense_size': 4096,
    
    'batch_size': 64, #64,
    'buffer_size': 256, #256,
    'loss': 'CategoricalCrossentropy',
    
    'num_epoch': 10000,
    'learning_rate': 1e-3,
    
    'random_state': 7777
}

# %%
image_feature_description = {
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    'randmark_id': tf.io.FixedLenFeature([], tf.int64),
    # 'id': tf.io.FixedLenFeature([], tf.string),
}

def _parse_image_function(example_proto):
    return tf.io.parse_single_example(example_proto, image_feature_description)

def map_func(target_record):
    img = target_record['image_raw']
    label = target_record['randmark_id']
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.dtypes.cast(img, tf.float32)
    return img, label

def resize_and_crop_func(image, label):
    result_image = tf.image.resize(image, config['aug']['resize'])
    # result_image = tf.image.random_crop(image, size=config['input_shape'], seed=7777)
    return result_image, label

def image_aug_func(image, label):
    pass
    return image, label

def post_process_func(image, label):
    # result_image = result_image / 255
    result_image = my_model_base.preprocess_input(image)
    onehot_label = tf.one_hot(label, depth=config['num_class'])
    return result_image, onehot_label

# %%
data_base_path = pth.join('data', 'public')  
os.makedirs(data_base_path, exist_ok=True)

# %%
category_csv_name = 'category.csv'
category_json_name = 'category.json'
submission_csv_name = 'sample_submisstion.csv'
train_csv_name = 'train.csv'

# train_zip_name = 'train.zip'
train_tfrecord_name = 'all_train.tfrecords'
train_tfrecord_path = pth.join(data_base_path, train_tfrecord_name)
val_tfrecord_name = 'all_val.tfrecords'
val_tfrecord_path = pth.join(data_base_path, val_tfrecord_name)
# test_zip_name = 'test.zip'
test_tfrecord_name = 'test.tfrecords'
test_tfrecord_path = pth.join(data_base_path, test_tfrecord_name)

# %%
train_csv_path = pth.join(data_base_path, train_csv_name)
train_df = pd.read_csv(train_csv_path)
train_dict = {k:v for k, v in train_df.values}

submission_csv_path = pth.join(data_base_path, submission_csv_name)
submission_df = pd.read_csv(submission_csv_path)
# submission_df.head()

category_csv_path = pth.join(data_base_path, category_csv_name)
category_df = pd.read_csv(category_csv_path)
category_dict = {k:v for k, v in category_df.values}
# category_df.head()

# %%
train_tfrecord_path
# Out:
# 'data/public/all_train.tfrecords'

# %% [markdown]
# ### Model

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import cv2

import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split, KFold, RepeatedKFold, GroupKFold, RepeatedStratifiedKFold
from sklearn.utils import shuffle

import numpy as np
import pandas as pd
import os
import os.path as pth
import shutil
import time
from tqdm import tqdm

import itertools
from itertools import product, combinations

import numpy as np
from PIL import Image

from IPython.display import clear_output

from multiprocessing import Process, Queue
import datetime

import tensorflow.keras as keras

from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras.layers import Input, Dense, Activation, BatchNormalization, \
                                    Flatten, Conv3D, AveragePooling3D, MaxPooling3D, Dropout, \
                                    Concatenate, GlobalMaxPool3D, GlobalAvgPool3D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint,LearningRateScheduler, \
                                        EarlyStopping
from tensorflow.keras.losses import mean_squared_error, mean_absolute_error
from tensorflow.keras import backend as K
from tensorflow.keras.constraints import max_norm

# %%
conv_comb_list = []
conv_comb_list += [(0,)]

base_channel_list = [0]

fc_list = [0] # 128, 0

# between_type_list = [None, 'avg', 'max']
between_type_list = ['avg']

batch_size_list = [80]

activation_list = ['relu']

# len(conv_comb_list), conv_comb_list

# %%
def build_cnn(config):
    input_layer = Input(shape=config['input_shape'], name='input_layer')
    pret_model = my_model(
        input_tensor=input_layer, include_top=False, weights='imagenet', 
        input_shape=config['input_shape'], pooling=config['between_type'], 
        classes=config['output_size']
    )

    pret_model.trainable = False
    
    x = pret_model.output
    
    if config['between_type'] == None:
        x = Flatten(name='flatten_layer')(x)
        
    if config['is_dropout']:
        x = Dropout(config['dropout_rate'], name='output_dropout')(x)    

    if config['add_dense']:
        x = Dense(config['dense_size'], activation=config['activation'],
                    name='dense_layer')(x)

    x = Dense(config['output_size'], activation=config['output_activation'], 
          name='output_fc')(x)
#     x = Activation(activation=config['output_activation'], name='output_activation')(x)
    model = Model(inputs=input_layer, outputs=x, name='{}'.format(BASE_MODEL_NAME))

    return model

# %%
model = build_cnn(config)
model.summary(line_length=150)
del model
# Out:
# Model: "InceptionV2-for-upload"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_layer (InputLayer)                         [(None, 270, 480, 3)]            0
# ______________________________________________________________________________________________________________________________________________________
# conv2d (Conv2D)                                  (None, 134, 239, 32)             864               input_layer[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization (BatchNormalization)         (None, 134, 239, 32)             96                conv2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation (Activation)                          (None, 134, 239, 32)             0                 batch_normalization[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_1 (Conv2D)                                (None, 132, 237, 32)             9216              activation[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_1 (BatchNormalization)       (None, 132, 237, 32)             96                conv2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_1 (Activation)                        (None, 132, 237, 32)             0                 batch_normalization_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_2 (Conv2D)                                (None, 132, 237, 64)             18432             activation_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_2 (BatchNormalization)       (None, 132, 237, 64)             192               conv2d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_2 (Activation)                        (None, 132, 237, 64)             0                 batch_normalization_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                     (None, 65, 118, 64)              0                 activation_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_3 (Conv2D)                                (None, 65, 118, 80)              5120              max_pooling2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_3 (BatchNormalization)       (None, 65, 118, 80)              240               conv2d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_3 (Activation)                        (None, 65, 118, 80)              0                 batch_normalization_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_4 (Conv2D)                                (None, 63, 116, 192)             138240            activation_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_4 (BatchNormalization)       (None, 63, 116, 192)             576               conv2d_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_4 (Activation)                        (None, 63, 116, 192)             0                 batch_normalization_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)                   (None, 31, 57, 192)              0                 activation_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_8 (Conv2D)                                (None, 31, 57, 64)               12288             max_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_8 (BatchNormalization)       (None, 31, 57, 64)               192               conv2d_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_8 (Activation)                        (None, 31, 57, 64)               0                 batch_normalization_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_6 (Conv2D)                                (None, 31, 57, 48)               9216              max_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_9 (Conv2D)                                (None, 31, 57, 96)               55296             activation_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_6 (BatchNormalization)       (None, 31, 57, 48)               144               conv2d_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_9 (BatchNormalization)       (None, 31, 57, 96)               288               conv2d_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_6 (Activation)                        (None, 31, 57, 48)               0                 batch_normalization_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_9 (Activation)                        (None, 31, 57, 96)               0                 batch_normalization_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d (AveragePooling2D)             (None, 31, 57, 192)              0                 max_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_5 (Conv2D)                                (None, 31, 57, 64)               12288             max_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_7 (Conv2D)                                (None, 31, 57, 64)               76800             activation_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_10 (Conv2D)                               (None, 31, 57, 96)               82944             activation_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_11 (Conv2D)                               (None, 31, 57, 32)               6144              average_pooling2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_5 (BatchNormalization)       (None, 31, 57, 64)               192               conv2d_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_7 (BatchNormalization)       (None, 31, 57, 64)               192               conv2d_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_10 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_11 (BatchNormalization)      (None, 31, 57, 32)               96                conv2d_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_5 (Activation)                        (None, 31, 57, 64)               0                 batch_normalization_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_7 (Activation)                        (None, 31, 57, 64)               0                 batch_normalization_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_10 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_11 (Activation)                       (None, 31, 57, 32)               0                 batch_normalization_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed0 (Concatenate)                             (None, 31, 57, 256)              0                 activation_5[0][0]
#                                                                                                     activation_7[0][0]
#                                                                                                     activation_10[0][0]
#                                                                                                     activation_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_15 (Conv2D)                               (None, 31, 57, 64)               16384             mixed0[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_15 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_15 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_13 (Conv2D)                               (None, 31, 57, 48)               12288             mixed0[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_16 (Conv2D)                               (None, 31, 57, 96)               55296             activation_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_13 (BatchNormalization)      (None, 31, 57, 48)               144               conv2d_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_16 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_13 (Activation)                       (None, 31, 57, 48)               0                 batch_normalization_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_16 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d_1 (AveragePooling2D)           (None, 31, 57, 256)              0                 mixed0[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_12 (Conv2D)                               (None, 31, 57, 64)               16384             mixed0[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_14 (Conv2D)                               (None, 31, 57, 64)               76800             activation_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_17 (Conv2D)                               (None, 31, 57, 96)               82944             activation_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_18 (Conv2D)                               (None, 31, 57, 64)               16384             average_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_12 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_14 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_17 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_18 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_12 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_14 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_17 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_18 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed1 (Concatenate)                             (None, 31, 57, 288)              0                 activation_12[0][0]
#                                                                                                     activation_14[0][0]
#                                                                                                     activation_17[0][0]
#                                                                                                     activation_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_22 (Conv2D)                               (None, 31, 57, 64)               18432             mixed1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_22 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_22 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_20 (Conv2D)                               (None, 31, 57, 48)               13824             mixed1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_23 (Conv2D)                               (None, 31, 57, 96)               55296             activation_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_20 (BatchNormalization)      (None, 31, 57, 48)               144               conv2d_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_23 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_20 (Activation)                       (None, 31, 57, 48)               0                 batch_normalization_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_23 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d_2 (AveragePooling2D)           (None, 31, 57, 288)              0                 mixed1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_19 (Conv2D)                               (None, 31, 57, 64)               18432             mixed1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_21 (Conv2D)                               (None, 31, 57, 64)               76800             activation_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_24 (Conv2D)                               (None, 31, 57, 96)               82944             activation_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_25 (Conv2D)                               (None, 31, 57, 64)               18432             average_pooling2d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_19 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_21 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_24 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_25 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_19 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_21 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_24 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_25 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed2 (Concatenate)                             (None, 31, 57, 288)              0                 activation_19[0][0]
#                                                                                                     activation_21[0][0]
#                                                                                                     activation_24[0][0]
#                                                                                                     activation_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_27 (Conv2D)                               (None, 31, 57, 64)               18432             mixed2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_27 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_27 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_28 (Conv2D)                               (None, 31, 57, 96)               55296             activation_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_28 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_28 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_26 (Conv2D)                               (None, 15, 28, 384)              995328            mixed2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_29 (Conv2D)                               (None, 15, 28, 96)               82944             activation_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_26 (BatchNormalization)      (None, 15, 28, 384)              1152              conv2d_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_29 (BatchNormalization)      (None, 15, 28, 96)               288               conv2d_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_26 (Activation)                       (None, 15, 28, 384)              0                 batch_normalization_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_29 (Activation)                       (None, 15, 28, 96)               0                 batch_normalization_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)                   (None, 15, 28, 288)              0                 mixed2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed3 (Concatenate)                             (None, 15, 28, 768)              0                 activation_26[0][0]
#                                                                                                     activation_29[0][0]
#                                                                                                     max_pooling2d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_34 (Conv2D)                               (None, 15, 28, 128)              98304             mixed3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_34 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_34[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_34 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_34[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_35 (Conv2D)                               (None, 15, 28, 128)              114688            activation_34[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_35 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_35[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_35 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_35[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_31 (Conv2D)                               (None, 15, 28, 128)              98304             mixed3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_36 (Conv2D)                               (None, 15, 28, 128)              114688            activation_35[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_31 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_31[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_36 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_36[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_31 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_31[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_36 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_36[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_32 (Conv2D)                               (None, 15, 28, 128)              114688            activation_31[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_37 (Conv2D)                               (None, 15, 28, 128)              114688            activation_36[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_32 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_32[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_37 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_37[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_32 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_32[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_37 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_37[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d_3 (AveragePooling2D)           (None, 15, 28, 768)              0                 mixed3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_30 (Conv2D)                               (None, 15, 28, 192)              147456            mixed3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_33 (Conv2D)                               (None, 15, 28, 192)              172032            activation_32[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_38 (Conv2D)                               (None, 15, 28, 192)              172032            activation_37[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_39 (Conv2D)                               (None, 15, 28, 192)              147456            average_pooling2d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_30 (BatchNormalization)      (None, 15, 28, 192)              576               conv2d_30[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_33 (BatchNormalization)      (None, 15, 28, 192)              576               conv2d_33[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_38 (BatchNormalization)      (None, 15, 28, 192)              576               conv2d_38[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_39 (BatchNormalization)      (None, 15, 28, 192)              576               conv2d_39[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_30 (Activation)                       (None, 15, 28, 192)              0                 batch_normalization_30[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_33 (Activation)                       (None, 15, 28, 192)              0                 batch_normalization_33[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_38 (Activation)                       (None, 15, 28, 192)              0                 batch_normalization_38[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_39 (Activation)                       (None, 15, 28, 192)              0                 batch_normalization_39[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed4 (Concatenate)                             (None, 15, 28, 768)              0                 activation_30[0][0]
#                                                                                                     activation_33[0][0]
#                                                                                                     activation_38[0][0]
#                                                                                                     activation_39[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_44 (Conv2D)                               (None, 15, 28, 160)              122880            mixed4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_44 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_44[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_44 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_44[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_45 (Conv2D)                               (None, 15, 28, 160)              179200            activation_44[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_45 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_45[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_45 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_45[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_41 (Conv2D)                               (None, 15, 28, 160)              122880            mixed4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_46 (Conv2D)                               (None, 15, 28, 160)              179200            activation_45[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_41 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_41[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_46 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_46[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_41 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_41[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_46 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_46[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_42 (Conv2D)                               (None, 15, 28, 160)              179200            activation_41[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_47 (Conv2D)                               (None, 15, 28, 160)              179200            activation_46[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_42 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_42[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_47 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_47[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_42 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_42[0][0]
# ______________________________________________________________________________________________________________________________________________________
# ...
# batch_normalization_83 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_83[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_84 (Conv2D)                               (None, 7, 13, 192)               245760            average_pooling2d_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_76 (BatchNormalization)      (None, 7, 13, 320)               960               conv2d_76[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_78 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_78[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_79 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_79[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_82 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_82[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_83 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_83[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_84 (BatchNormalization)      (None, 7, 13, 192)               576               conv2d_84[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_76 (Activation)                       (None, 7, 13, 320)               0                 batch_normalization_76[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed9_0 (Concatenate)                           (None, 7, 13, 768)               0                 activation_78[0][0]
#                                                                                                     activation_79[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate (Concatenate)                        (None, 7, 13, 768)               0                 activation_82[0][0]
#                                                                                                     activation_83[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_84 (Activation)                       (None, 7, 13, 192)               0                 batch_normalization_84[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed9 (Concatenate)                             (None, 7, 13, 2048)              0                 activation_76[0][0]
#                                                                                                     mixed9_0[0][0]
#                                                                                                     concatenate[0][0]
#                                                                                                     activation_84[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_89 (Conv2D)                               (None, 7, 13, 448)               917504            mixed9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_89 (BatchNormalization)      (None, 7, 13, 448)               1344              conv2d_89[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_89 (Activation)                       (None, 7, 13, 448)               0                 batch_normalization_89[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_86 (Conv2D)                               (None, 7, 13, 384)               786432            mixed9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_90 (Conv2D)                               (None, 7, 13, 384)               1548288           activation_89[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_86 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_86[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_90 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_90[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_86 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_86[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_90 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_90[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_87 (Conv2D)                               (None, 7, 13, 384)               442368            activation_86[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_88 (Conv2D)                               (None, 7, 13, 384)               442368            activation_86[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_91 (Conv2D)                               (None, 7, 13, 384)               442368            activation_90[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_92 (Conv2D)                               (None, 7, 13, 384)               442368            activation_90[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d_8 (AveragePooling2D)           (None, 7, 13, 2048)              0                 mixed9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_85 (Conv2D)                               (None, 7, 13, 320)               655360            mixed9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_87 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_87[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_88 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_88[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_91 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_91[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_92 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_92[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_93 (Conv2D)                               (None, 7, 13, 192)               393216            average_pooling2d_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_85 (BatchNormalization)      (None, 7, 13, 320)               960               conv2d_85[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_87 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_87[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_88 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_88[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_91 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_91[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_92 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_92[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_93 (BatchNormalization)      (None, 7, 13, 192)               576               conv2d_93[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_85 (Activation)                       (None, 7, 13, 320)               0                 batch_normalization_85[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed9_1 (Concatenate)                           (None, 7, 13, 768)               0                 activation_87[0][0]
#                                                                                                     activation_88[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_1 (Concatenate)                      (None, 7, 13, 768)               0                 activation_91[0][0]
#                                                                                                     activation_92[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_93 (Activation)                       (None, 7, 13, 192)               0                 batch_normalization_93[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed10 (Concatenate)                            (None, 7, 13, 2048)              0                 activation_85[0][0]
#                                                                                                     mixed9_1[0][0]
#                                                                                                     concatenate_1[0][0]
#                                                                                                     activation_93[0][0]
# ______________________________________________________________________________________________________________________________________________________
# global_average_pooling2d (GlobalAveragePooling2D (None, 2048)                     0                 mixed10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# dense_layer (Dense)                              (None, 4096)                     8392704           global_average_pooling2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# output_fc (Dense)                                (None, 1049)                     4297753           dense_layer[0][0]
# ======================================================================================================================================================
# Total params: 34,493,241
# Trainable params: 12,690,457
# Non-trainable params: 21,802,784
# ______________________________________________________________________________________________________________________________________________________

# %%
origin_train_len = len(train_df) / 5 * 4
origin_val_len = len(train_df) / 5 * 1

train_num_steps = int(np.ceil((origin_train_len)/config['batch_size']))
val_num_steps = int(np.ceil((origin_val_len)/config['batch_size']))

print(train_num_steps, val_num_steps)
# Out:
# 1102 276

# %%
model_base_path = data_base_path
model_checkpoint_path = pth.join(model_base_path, 'checkpoint')

# %%
for conv_comb, activation, base_channel, \
    between_type, fc_num, batch_size \
        in itertools.product(conv_comb_list, activation_list,
                              base_channel_list, between_type_list, fc_list,
                              batch_size_list):
    config['conv']['conv_num'] = conv_comb
    config['conv']['base_channel'] = base_channel
    config['activation'] = activation
    config['between_type'] = between_type
    config['fc']['fc_num'] = fc_num
    config['batch_size'] = batch_size

    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])

    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print(model_name)

    ### Define dataset
    dataset = tf.data.TFRecordDataset(train_tfrecord_path, compression_type='GZIP')
    dataset = dataset.map(_parse_image_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # dataset = dataset.cache()
    dataset = dataset.map(map_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.map(resize_and_crop_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.map(image_aug_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(config['buffer_size'])
    dataset = dataset.batch(config['batch_size'])
    dataset = dataset.map(post_process_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    val_dataset = tf.data.TFRecordDataset(val_tfrecord_path, compression_type='GZIP')
    val_dataset = val_dataset.map(_parse_image_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    val_dataset = val_dataset.map(map_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    val_dataset = val_dataset.map(resize_and_crop_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.map(image_aug_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.shuffle(config['buffer_size'])
    val_dataset = val_dataset.batch(config['batch_size'])
    val_dataset = val_dataset.map(post_process_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.cache()
    val_dataset = val_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
    
    initial_epoch = 0

    if pth.isdir(model_path) and len([_ for _ in os.listdir(model_path) if _.endswith('hdf5')]) >= 1:
        model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
        
        model_chk_name = sorted(os.listdir(model_path))[-1]
        initial_epoch = int(model_chk_name.split('-')[0])
        model.load_weights(pth.join(model_path, model_chk_name))
    else:
        # first: train only the top layers (which were randomly initialized)
        # i.e. freeze all convolutional InceptionV3 layers
        model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
                     metrics=['acc', 'Precision', 'Recall', 'AUC'])
        
        model.fit(
            x=dataset, epochs=1, # train only top layers for just a few epochs.
            validation_data=val_dataset, shuffle=True,
            #callbacks = [checkpointer, es], #batch_size=config['batch_size']
            initial_epoch=initial_epoch,
            # steps_per_epoch=train_num_steps, validation_steps=val_num_steps,
            verbose=1)
        
        # at this point, the top layers are well trained and we can start fine-tuning
        # convolutional layers from inception V3. We will freeze the bottom N layers
        # and train the remaining top layers.
        
        # let's visualize layer names and layer indices to see how many layers
        # we should freeze:
        for i, layer in enumerate(model.layers):
           print(i, layer.name)
        
        # we chose to train the top 2 inception blocks, i.e. we will freeze
        # the first 249 layers and unfreeze the rest:
        for layer in model.layers[:249]:
           layer.trainable = False
        for layer in model.layers[249:]:
           layer.trainable = True
        
        # we need to recompile the model for these modifications to take effect
        # we use Adam with a low learning rate
        model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
            metrics=['acc', 'Precision', 'Recall', 'AUC'])

        
    # IGNORE 4 lines below in InceptionV3 
    # ### Freeze first layer
    # conv_list = [layer for layer in model.layers if isinstance(layer, keras.layers.Conv2D)]
    # conv_list[0].trainable = False
    # # conv_list[1].trainable = False

    os.makedirs(model_path, exist_ok=True)
    model_filename = pth.join(model_path, '{epoch:06d}-{val_loss:0.6f}-{loss:0.6f}.hdf5')
    checkpointer = ModelCheckpoint(
        filepath=model_filename, verbose=1, 
        period=1, save_best_only=True, 
        monitor='val_loss'
    )
    es = EarlyStopping(monitor='val_loss', verbose=1, patience=10)

    hist = model.fit(
        x=dataset, epochs=config['num_epoch'], 
        validation_data=val_dataset, shuffle=True,
        callbacks = [checkpointer, es], #batch_size=config['batch_size']
        initial_epoch=initial_epoch,
        # steps_per_epoch=train_num_steps, validation_steps=val_num_steps,
        verbose=1
    )

    model_analysis_path = model_path.replace('checkpoint', 'analysis')
    visualization_path = pth.join(model_analysis_path,'visualization')
    os.makedirs(visualization_path, exist_ok=True)
    
    print()
    # clear_output()        
    for each_label in ['loss', 'acc', 'precision', 'recall', 'auc']:
        fig, ax = plt.subplots()
        ax.plot(hist.history[each_label], 'g', label='train_{}'.format(each_label))
        ax.plot(hist.history['val_{}'.format(each_label)], 'r', label='val_{}'.format(each_label))
        ax.set_xlabel('epoch')
        ax.set_ylabel('loss')
        ax.legend(loc='upper left')
        if not each_label == 'loss':
            plt.ylim(0, 1)
        plt.show()
        filename = 'learning_curve_{}'.format(each_label)
#             fig.savefig(pth.join(visualization_path, filename), transparent=True)
        plt.cla()
        plt.clf()
        plt.close('all')

    np.savez_compressed(pth.join(visualization_path, 'learning_curve'), 
                        loss=hist.history['loss'], 
                        val_loss=hist.history['val_loss'],
                        acc=hist.history['acc'], 
                        val_acc=hist.history['val_acc'],
                        precision=hist.history['precision'], 
                        vaval_precisionl_mae=hist.history['val_precision'],  
                        recall=hist.history['recall'],
                        val_recall=hist.history['val_recall'],
                        auc=hist.history['auc'],
                        val_auc=hist.history['val_auc']
                        )

    model.save(pth.join(model_path, '000000_last.hdf5'))
    K.clear_session()
    del(model)
    
    model_analysis_base_path = pth.join(model_base_path, 'analysis', model_name) 
    with open(pth.join(model_analysis_base_path, 'config.json'), 'w') as f:
        json.dump(config, f)

    chk_name_list = sorted([name for name in os.listdir(model_path) if name != '000000_last.hdf5'])
    for chk_name in chk_name_list[:-2]:
        os.remove(pth.join(model_path, chk_name))
    # clear_output()
# Out:
# InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
# 882/882 [==============================] - 594s 674ms/step - loss: 3.5010 - acc: 0.3786 - precision: 0.9006 - recall: 0.2030 - auc: 0.8491 - val_loss: 3.0224 - val_acc: 0.4000 - val_precision: 0.4831 - val_recall: 0.3009 - val_auc: 0.8931
# 0 input_layer
# 1 conv2d_94
# 2 batch_normalization_94
# 3 activation_94
# 4 conv2d_95
# 5 batch_normalization_95
# 6 activation_95
# 7 conv2d_96
# 8 batch_normalization_96
# 9 activation_96
# 10 max_pooling2d_4
# 11 conv2d_97
# 12 batch_normalization_97
# 13 activation_97
# 14 conv2d_98
# 15 batch_normalization_98
# 16 activation_98
# 17 max_pooling2d_5
# 18 conv2d_102
# 19 batch_normalization_102
# 20 activation_102
# 21 conv2d_100
# 22 conv2d_103
# 23 batch_normalization_100
# 24 batch_normalization_103
# 25 activation_100
# 26 activation_103
# 27 average_pooling2d_9
# 28 conv2d_99
# 29 conv2d_101
# 30 conv2d_104
# 31 conv2d_105
# 32 batch_normalization_99
# 33 batch_normalization_101
# 34 batch_normalization_104
# 35 batch_normalization_105
# 36 activation_99
# 37 activation_101
# 38 activation_104
# 39 activation_105
# 40 mixed0
# 41 conv2d_109
# 42 batch_normalization_109
# 43 activation_109
# 44 conv2d_107
# 45 conv2d_110
# 46 batch_normalization_107
# 47 batch_normalization_110
# 48 activation_107
# 49 activation_110
# 50 average_pooling2d_10
# 51 conv2d_106
# 52 conv2d_108
# 53 conv2d_111
# 54 conv2d_112
# 55 batch_normalization_106
# 56 batch_normalization_108
# 57 batch_normalization_111
# 58 batch_normalization_112
# 59 activation_106
# 60 activation_108
# 61 activation_111
# 62 activation_112
# 63 mixed1
# 64 conv2d_116
# 65 batch_normalization_116
# 66 activation_116
# 67 conv2d_114
# 68 conv2d_117
# 69 batch_normalization_114
# 70 batch_normalization_117
# 71 activation_114
# 72 activation_117
# 73 average_pooling2d_11
# 74 conv2d_113
# 75 conv2d_115
# 76 conv2d_118
# 77 conv2d_119
# 78 batch_normalization_113
# 79 batch_normalization_115
# 80 batch_normalization_118
# 81 batch_normalization_119
# 82 activation_113
# 83 activation_115
# 84 activation_118
# 85 activation_119
# 86 mixed2
# 87 conv2d_121
# 88 batch_normalization_121
# 89 activation_121
# 90 conv2d_122
# 91 batch_normalization_122
# 92 activation_122
# 93 conv2d_120
# 94 conv2d_123
# 95 batch_normalization_120
# 96 batch_normalization_123
# 97 activation_120
# 98 activation_123
# 99 max_pooling2d_6
# 100 mixed3
# 101 conv2d_128
# 102 batch_normalization_128
# 103 activation_128
# 104 conv2d_129
# 105 batch_normalization_129
# 106 activation_129
# 107 conv2d_125
# 108 conv2d_130
# 109 batch_normalization_125
# 110 batch_normalization_130
# 111 activation_125
# 112 activation_130
# 113 conv2d_126
# 114 conv2d_131
# 115 batch_normalization_126
# 116 batch_normalization_131
# 117 activation_126
# 118 activation_131
# 119 average_pooling2d_12
# 120 conv2d_124
# 121 conv2d_127
# 122 conv2d_132
# 123 conv2d_133
# 124 batch_normalization_124
# 125 batch_normalization_127
# 126 batch_normalization_132
# 127 batch_normalization_133
# 128 activation_124
# 129 activation_127
# 130 activation_132
# 131 activation_133
# 132 mixed4
# 133 conv2d_138
# 134 batch_normalization_138
# 135 activation_138
# 136 conv2d_139
# 137 batch_normalization_139
# 138 activation_139
# 139 conv2d_135
# 140 conv2d_140
# 141 batch_normalization_135
# 142 batch_normalization_140
# 143 activation_135
# 144 activation_140
# 145 conv2d_136
# 146 conv2d_141
# 147 batch_normalization_136
# 148 batch_normalization_141
# 149 activation_136
# 150 activation_141
# 151 average_pooling2d_13
# 152 conv2d_134
# 153 conv2d_137
# 154 conv2d_142
# 155 conv2d_143
# 156 batch_normalization_134
# 157 batch_normalization_137
# 158 batch_normalization_142
# 159 batch_normalization_143
# 160 activation_134
# 161 activation_137
# 162 activation_142
# 163 activation_143
# 164 mixed5
# 165 conv2d_148
# 166 batch_normalization_148
# 167 activation_148
# 168 conv2d_149
# 169 batch_normalization_149
# 170 activation_149
# 171 conv2d_145
# 172 conv2d_150
# 173 batch_normalization_145
# 174 batch_normalization_150
# 175 activation_145
# 176 activation_150
# 177 conv2d_146
# 178 conv2d_151
# 179 batch_normalization_146
# 180 batch_normalization_151
# 181 activation_146
# 182 activation_151
# 183 average_pooling2d_14
# 184 conv2d_144
# 185 conv2d_147
# 186 conv2d_152
# 187 conv2d_153
# 188 batch_normalization_144
# 189 batch_normalization_147
# 190 batch_normalization_152
# 191 batch_normalization_153
# 192 activation_144
# 193 activation_147
# 194 activation_152
# 195 activation_153
# 196 mixed6
# 197 conv2d_158
# 198 batch_normalization_158
# 199 activation_158
# 200 conv2d_159
# 201 batch_normalization_159
# 202 activation_159
# 203 conv2d_155
# 204 conv2d_160
# 205 batch_normalization_155
# 206 batch_normalization_160
# 207 activation_155
# 208 activation_160
# 209 conv2d_156
# 210 conv2d_161
# 211 batch_normalization_156
# 212 batch_normalization_161
# 213 activation_156
# 214 activation_161
# 215 average_pooling2d_15
# 216 conv2d_154
# 217 conv2d_157
# 218 conv2d_162
# 219 conv2d_163
# 220 batch_normalization_154
# 221 batch_normalization_157
# 222 batch_normalization_162
# 223 batch_normalization_163
# 224 activation_154
# 225 activation_157
# 226 activation_162
# 227 activation_163
# 228 mixed7
# 229 conv2d_166
# 230 batch_normalization_166
# 231 activation_166
# 232 conv2d_167
# 233 batch_normalization_167
# 234 activation_167
# 235 conv2d_164
# 236 conv2d_168
# 237 batch_normalization_164
# 238 batch_normalization_168
# 239 activation_164
# 240 activation_168
# 241 conv2d_165
# 242 conv2d_169
# 243 batch_normalization_165
# 244 batch_normalization_169
# 245 activation_165
# 246 activation_169
# 247 max_pooling2d_7
# 248 mixed8
# 249 conv2d_174
# 250 batch_normalization_174
# 251 activation_174
# 252 conv2d_171
# 253 conv2d_175
# 254 batch_normalization_171
# 255 batch_normalization_175
# 256 activation_171
# 257 activation_175
# 258 conv2d_172
# 259 conv2d_173
# 260 conv2d_176
# 261 conv2d_177
# 262 average_pooling2d_16
# 263 conv2d_170
# 264 batch_normalization_172
# 265 batch_normalization_173
# 266 batch_normalization_176
# 267 batch_normalization_177
# 268 conv2d_178
# 269 batch_normalization_170
# 270 activation_172
# 271 activation_173
# 272 activation_176
# 273 activation_177
# 274 batch_normalization_178
# 275 activation_170
# 276 mixed9_0
# 277 concatenate_2
# 278 activation_178
# 279 mixed9
# 280 conv2d_183
# 281 batch_normalization_183
# 282 activation_183
# 283 conv2d_180
# 284 conv2d_184
# 285 batch_normalization_180
# 286 batch_normalization_184
# 287 activation_180
# 288 activation_184
# 289 conv2d_181
# 290 conv2d_182
# 291 conv2d_185
# 292 conv2d_186
# 293 average_pooling2d_17
# 294 conv2d_179
# 295 batch_normalization_181
# 296 batch_normalization_182
# 297 batch_normalization_185
# 298 batch_normalization_186
# 299 conv2d_187
# 300 batch_normalization_179
# 301 activation_181
# 302 activation_182
# 303 activation_185
# 304 activation_186
# 305 batch_normalization_187
# 306 activation_179
# 307 mixed9_1
# 308 concatenate_3
# 309 activation_187
# 310 mixed10
# 311 global_average_pooling2d_1
# 312 dense_layer
# 313 output_fc
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/10000
#     882/Unknown - 472s 536ms/step - loss: 0.8836 - acc: 0.7935 - precision: 0.9169 - recall: 0.7236 - auc: 0.9809
# Epoch 00001: val_loss improved from inf to 0.65008, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000001-0.650082-0.883613.hdf5
# 882/882 [==============================] - 594s 674ms/step - loss: 0.8836 - acc: 0.7935 - precision: 0.9169 - recall: 0.7236 - auc: 0.9809 - val_loss: 0.6501 - val_acc: 0.8418 - val_precision: 0.9092 - val_recall: 0.8059 - val_auc: 0.9849
# Epoch 2/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.2825 - acc: 0.9246 - precision: 0.9589 - recall: 0.9015 - auc: 0.9961
# Epoch 00002: val_loss did not improve from 0.65008
# 882/882 [==============================] - 596s 675ms/step - loss: 0.2827 - acc: 0.9246 - precision: 0.9589 - recall: 0.9015 - auc: 0.9961 - val_loss: 0.9341 - val_acc: 0.8048 - val_precision: 0.8455 - val_recall: 0.7845 - val_auc: 0.9700
# Epoch 3/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1881 - acc: 0.9477 - precision: 0.9691 - recall: 0.9325 - auc: 0.9979
# Epoch 00003: val_loss improved from 0.65008 to 0.64635, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000003-0.646346-0.188377.hdf5
# 882/882 [==============================] - 594s 673ms/step - loss: 0.1884 - acc: 0.9477 - precision: 0.9691 - recall: 0.9325 - auc: 0.9979 - val_loss: 0.6463 - val_acc: 0.8538 - val_precision: 0.8924 - val_recall: 0.8376 - val_auc: 0.9809
# Epoch 4/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1376 - acc: 0.9618 - precision: 0.9751 - recall: 0.9501 - auc: 0.9986
# Epoch 00004: val_loss improved from 0.64635 to 0.44660, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000004-0.446601-0.137791.hdf5
# 882/882 [==============================] - 592s 671ms/step - loss: 0.1378 - acc: 0.9617 - precision: 0.9751 - recall: 0.9501 - auc: 0.9986 - val_loss: 0.4466 - val_acc: 0.8976 - val_precision: 0.9252 - val_recall: 0.8850 - val_auc: 0.9872
# Epoch 5/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1144 - acc: 0.9671 - precision: 0.9771 - recall: 0.9593 - auc: 0.9988
# Epoch 00005: val_loss improved from 0.44660 to 0.44079, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000005-0.440787-0.114563.hdf5
# 882/882 [==============================] - 596s 675ms/step - loss: 0.1146 - acc: 0.9671 - precision: 0.9771 - recall: 0.9593 - auc: 0.9988 - val_loss: 0.4408 - val_acc: 0.9005 - val_precision: 0.9226 - val_recall: 0.8911 - val_auc: 0.9870
# Epoch 6/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1044 - acc: 0.9703 - precision: 0.9787 - recall: 0.9637 - auc: 0.9988
# Epoch 00006: val_loss improved from 0.44079 to 0.40116, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000006-0.401163-0.104523.hdf5
# 882/882 [==============================] - 596s 676ms/step - loss: 0.1045 - acc: 0.9703 - precision: 0.9787 - recall: 0.9637 - auc: 0.9988 - val_loss: 0.4012 - val_acc: 0.9192 - val_precision: 0.9380 - val_recall: 0.9116 - val_auc: 0.9875
# Epoch 7/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0670 - acc: 0.9814 - precision: 0.9856 - recall: 0.9778 - auc: 0.9992
# Epoch 00007: val_loss did not improve from 0.40116
# 882/882 [==============================] - 593s 672ms/step - loss: 0.0672 - acc: 0.9814 - precision: 0.9856 - recall: 0.9778 - auc: 0.9992 - val_loss: 0.4126 - val_acc: 0.9135 - val_precision: 0.9334 - val_recall: 0.9057 - val_auc: 0.9876
# Epoch 8/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0827 - acc: 0.9759 - precision: 0.9813 - recall: 0.9717 - auc: 0.9988
# Epoch 00008: val_loss improved from 0.40116 to 0.39750, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000008-0.397496-0.083142.hdf5
# 882/882 [==============================] - 594s 674ms/step - loss: 0.0831 - acc: 0.9759 - precision: 0.9813 - recall: 0.9717 - auc: 0.9988 - val_loss: 0.3975 - val_acc: 0.9183 - val_precision: 0.9358 - val_recall: 0.9120 - val_auc: 0.9876
# Epoch 9/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0675 - acc: 0.9796 - precision: 0.9843 - recall: 0.9758 - auc: 0.9994
# Epoch 00009: val_loss improved from 0.39750 to 0.37730, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000009-0.377303-0.067768.hdf5
# 882/882 [==============================] - 594s 674ms/step - loss: 0.0678 - acc: 0.9796 - precision: 0.9843 - recall: 0.9758 - auc: 0.9994 - val_loss: 0.3773 - val_acc: 0.9258 - val_precision: 0.9413 - val_recall: 0.9197 - val_auc: 0.9883
# Epoch 10/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0572 - acc: 0.9827 - precision: 0.9857 - recall: 0.9801 - auc: 0.9994
# Epoch 00010: val_loss improved from 0.37730 to 0.37382, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000010-0.373824-0.057264.hdf5
# 882/882 [==============================] - 595s 674ms/step - loss: 0.0573 - acc: 0.9827 - precision: 0.9857 - recall: 0.9801 - auc: 0.9994 - val_loss: 0.3738 - val_acc: 0.9233 - val_precision: 0.9385 - val_recall: 0.9176 - val_auc: 0.9881
# Epoch 11/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0468 - acc: 0.9861 - precision: 0.9880 - recall: 0.9845 - auc: 0.9993
# Epoch 00011: val_loss improved from 0.37382 to 0.37045, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000011-0.370451-0.046975.hdf5
# 882/882 [==============================] - 594s 674ms/step - loss: 0.0470 - acc: 0.9861 - precision: 0.9880 - recall: 0.9845 - auc: 0.9993 - val_loss: 0.3705 - val_acc: 0.9357 - val_precision: 0.9467 - val_recall: 0.9316 - val_auc: 0.9877
# Epoch 12/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0490 - acc: 0.9863 - precision: 0.9884 - recall: 0.9847 - auc: 0.9993
# Epoch 00012: val_loss did not improve from 0.37045
# 882/882 [==============================] - 595s 674ms/step - loss: 0.0492 - acc: 0.9863 - precision: 0.9884 - recall: 0.9847 - auc: 0.9993 - val_loss: 0.3883 - val_acc: 0.9297 - val_precision: 0.9427 - val_recall: 0.9261 - val_auc: 0.9870
# Epoch 13/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0487 - acc: 0.9859 - precision: 0.9878 - recall: 0.9846 - auc: 0.9993
# Epoch 00013: val_loss improved from 0.37045 to 0.36930, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000013-0.369297-0.048830.hdf5
# 882/882 [==============================] - 592s 672ms/step - loss: 0.0488 - acc: 0.9859 - precision: 0.9878 - recall: 0.9846 - auc: 0.9993 - val_loss: 0.3693 - val_acc: 0.9329 - val_precision: 0.9454 - val_recall: 0.9297 - val_auc: 0.9879
# Epoch 14/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0526 - acc: 0.9845 - precision: 0.9866 - recall: 0.9827 - auc: 0.9991
# Epoch 00014: val_loss did not improve from 0.36930
# 882/882 [==============================] - 593s 672ms/step - loss: 0.0528 - acc: 0.9845 - precision: 0.9866 - recall: 0.9827 - auc: 0.9991 - val_loss: 0.4114 - val_acc: 0.9230 - val_precision: 0.9368 - val_recall: 0.9182 - val_auc: 0.9863
# Epoch 15/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0446 - acc: 0.9869 - precision: 0.9886 - recall: 0.9854 - auc: 0.9994
# Epoch 00015: val_loss did not improve from 0.36930
# 882/882 [==============================] - 593s 672ms/step - loss: 0.0449 - acc: 0.9869 - precision: 0.9886 - recall: 0.9853 - auc: 0.9994 - val_loss: 0.3814 - val_acc: 0.9329 - val_precision: 0.9440 - val_recall: 0.9287 - val_auc: 0.9872
# Epoch 16/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0413 - acc: 0.9881 - precision: 0.9895 - recall: 0.9870 - auc: 0.9994
# Epoch 00016: val_loss did not improve from 0.36930
# 882/882 [==============================] - 592s 671ms/step - loss: 0.0414 - acc: 0.9881 - precision: 0.9895 - recall: 0.9870 - auc: 0.9994 - val_loss: 0.4101 - val_acc: 0.9318 - val_precision: 0.9419 - val_recall: 0.9287 - val_auc: 0.9864
# Epoch 17/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0354 - acc: 0.9899 - precision: 0.9910 - recall: 0.9891 - auc: 0.9994
# Epoch 00017: val_loss improved from 0.36930 to 0.36298, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000017-0.362975-0.035629.hdf5
# 882/882 [==============================] - 615s 697ms/step - loss: 0.0356 - acc: 0.9899 - precision: 0.9910 - recall: 0.9891 - auc: 0.9994 - val_loss: 0.3630 - val_acc: 0.9377 - val_precision: 0.9483 - val_recall: 0.9350 - val_auc: 0.9878
# Epoch 18/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0374 - acc: 0.9890 - precision: 0.9905 - recall: 0.9881 - auc: 0.9994
# Epoch 00018: val_loss did not improve from 0.36298
# 882/882 [==============================] - 593s 673ms/step - loss: 0.0375 - acc: 0.9890 - precision: 0.9905 - recall: 0.9881 - auc: 0.9994 - val_loss: 0.3678 - val_acc: 0.9374 - val_precision: 0.9475 - val_recall: 0.9344 - val_auc: 0.9878
# Epoch 19/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0352 - acc: 0.9899 - precision: 0.9909 - recall: 0.9890 - auc: 0.9994
# Epoch 00019: val_loss did not improve from 0.36298
# 882/882 [==============================] - 596s 676ms/step - loss: 0.0354 - acc: 0.9899 - precision: 0.9909 - recall: 0.9890 - auc: 0.9994 - val_loss: 0.4209 - val_acc: 0.9303 - val_precision: 0.9389 - val_recall: 0.9275 - val_auc: 0.9857
# Epoch 20/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0336 - acc: 0.9903 - precision: 0.9915 - recall: 0.9892 - auc: 0.9994
# Epoch 00020: val_loss improved from 0.36298 to 0.35548, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000020-0.355481-0.033797.hdf5
# 882/882 [==============================] - 597s 677ms/step - loss: 0.0338 - acc: 0.9903 - precision: 0.9915 - recall: 0.9891 - auc: 0.9994 - val_loss: 0.3555 - val_acc: 0.9401 - val_precision: 0.9491 - val_recall: 0.9373 - val_auc: 0.9878
# Epoch 21/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0332 - acc: 0.9904 - precision: 0.9918 - recall: 0.9894 - auc: 0.9995
# Epoch 00021: val_loss improved from 0.35548 to 0.34535, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000021-0.345351-0.033354.hdf5
# 882/882 [==============================] - 593s 672ms/step - loss: 0.0334 - acc: 0.9904 - precision: 0.9917 - recall: 0.9894 - auc: 0.9995 - val_loss: 0.3454 - val_acc: 0.9422 - val_precision: 0.9502 - val_recall: 0.9389 - val_auc: 0.9889
# Epoch 22/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0316 - acc: 0.9905 - precision: 0.9913 - recall: 0.9898 - auc: 0.9995
# Epoch 00022: val_loss did not improve from 0.34535
# 882/882 [==============================] - 592s 672ms/step - loss: 0.0318 - acc: 0.9905 - precision: 0.9913 - recall: 0.9897 - auc: 0.9995 - val_loss: 0.3937 - val_acc: 0.9350 - val_precision: 0.9440 - val_recall: 0.9322 - val_auc: 0.9863
# Epoch 23/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0304 - acc: 0.9913 - precision: 0.9923 - recall: 0.9906 - auc: 0.9994
# Epoch 00023: val_loss did not improve from 0.34535
# 882/882 [==============================] - 613s 694ms/step - loss: 0.0307 - acc: 0.9913 - precision: 0.9923 - recall: 0.9906 - auc: 0.9994 - val_loss: 0.3738 - val_acc: 0.9434 - val_precision: 0.9506 - val_recall: 0.9411 - val_auc: 0.9870
# Epoch 24/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0255 - acc: 0.9923 - precision: 0.9930 - recall: 0.9917 - auc: 0.9996
# Epoch 00024: val_loss did not improve from 0.34535
# 882/882 [==============================] - 593s 673ms/step - loss: 0.0257 - acc: 0.9923 - precision: 0.9930 - recall: 0.9917 - auc: 0.9996 - val_loss: 0.3731 - val_acc: 0.9422 - val_precision: 0.9493 - val_recall: 0.9396 - val_auc: 0.9876
# Epoch 25/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0236 - acc: 0.9929 - precision: 0.9937 - recall: 0.9925 - auc: 0.9996
# Epoch 00025: val_loss did not improve from 0.34535
# 882/882 [==============================] - 597s 677ms/step - loss: 0.0237 - acc: 0.9929 - precision: 0.9937 - recall: 0.9925 - auc: 0.9996 - val_loss: 0.3737 - val_acc: 0.9418 - val_precision: 0.9501 - val_recall: 0.9392 - val_auc: 0.9874
# Epoch 26/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0266 - acc: 0.9922 - precision: 0.9929 - recall: 0.9917 - auc: 0.9995
# Epoch 00026: val_loss did not improve from 0.34535
# 882/882 [==============================] - 595s 674ms/step - loss: 0.0268 - acc: 0.9922 - precision: 0.9929 - recall: 0.9917 - auc: 0.9995 - val_loss: 0.3673 - val_acc: 0.9419 - val_precision: 0.9506 - val_recall: 0.9403 - val_auc: 0.9873
# Epoch 27/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0256 - acc: 0.9924 - precision: 0.9930 - recall: 0.9920 - auc: 0.9995
# Epoch 00027: val_loss improved from 0.34535 to 0.34247, saving model to data/public/checkpoint/InceptionV2-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000027-0.342473-0.025745.hdf5
# 882/882 [==============================] - 594s 673ms/step - loss: 0.0257 - acc: 0.9924 - precision: 0.9930 - recall: 0.9920 - auc: 0.9995 - val_loss: 0.3425 - val_acc: 0.9459 - val_precision: 0.9543 - val_recall: 0.9440 - val_auc: 0.9882
# Epoch 28/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0244 - acc: 0.9932 - precision: 0.9939 - recall: 0.9928 - auc: 0.9996
# Epoch 00028: val_loss did not improve from 0.34247
# 882/882 [==============================] - 595s 674ms/step - loss: 0.0247 - acc: 0.9932 - precision: 0.9939 - recall: 0.9928 - auc: 0.9996 - val_loss: 0.3471 - val_acc: 0.9449 - val_precision: 0.9531 - val_recall: 0.9427 - val_auc: 0.9882
# Epoch 29/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0226 - acc: 0.9933 - precision: 0.9938 - recall: 0.9928 - auc: 0.9996
# Epoch 00029: val_loss did not improve from 0.34247
# 882/882 [==============================] - 594s 674ms/step - loss: 0.0229 - acc: 0.9933 - precision: 0.9937 - recall: 0.9928 - auc: 0.9996 - val_loss: 0.3720 - val_acc: 0.9412 - val_precision: 0.9498 - val_recall: 0.9391 - val_auc: 0.9872
# Epoch 30/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0216 - acc: 0.9934 - precision: 0.9939 - recall: 0.9931 - auc: 0.9997
# Epoch 00030: val_loss did not improve from 0.34247
# 882/882 [==============================] - 595s 674ms/step - loss: 0.0218 - acc: 0.9934 - precision: 0.9939 - recall: 0.9931 - auc: 0.9997 - val_loss: 0.3953 - val_acc: 0.9426 - val_precision: 0.9487 - val_recall: 0.9408 - val_auc: 0.9865
# Epoch 31/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0275 - acc: 0.9923 - precision: 0.9928 - recall: 0.9919 - auc: 0.9995
# Epoch 00031: val_loss did not improve from 0.34247
# 882/882 [==============================] - 593s 672ms/step - loss: 0.0275 - acc: 0.9923 - precision: 0.9928 - recall: 0.9918 - auc: 0.9995 - val_loss: 0.3904 - val_acc: 0.9455 - val_precision: 0.9515 - val_recall: 0.9434 - val_auc: 0.9867
# Epoch 32/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0193 - acc: 0.9945 - precision: 0.9950 - recall: 0.9943 - auc: 0.9997
# Epoch 00032: val_loss did not improve from 0.34247
# 882/882 [==============================] - 593s 673ms/step - loss: 0.0196 - acc: 0.9945 - precision: 0.9950 - recall: 0.9943 - auc: 0.9997 - val_loss: 0.4443 - val_acc: 0.9402 - val_precision: 0.9471 - val_recall: 0.9387 - val_auc: 0.9855
# Epoch 33/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0253 - acc: 0.9929 - precision: 0.9936 - recall: 0.9926 - auc: 0.9995
# Epoch 00033: val_loss did not improve from 0.34247
# 882/882 [==============================] - 615s 698ms/step - loss: 0.0255 - acc: 0.9929 - precision: 0.9936 - recall: 0.9926 - auc: 0.9995 - val_loss: 0.3762 - val_acc: 0.9462 - val_precision: 0.9525 - val_recall: 0.9445 - val_auc: 0.9871
# Epoch 34/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0182 - acc: 0.9944 - precision: 0.9947 - recall: 0.9941 - auc: 0.9997
# Epoch 00034: val_loss did not improve from 0.34247
# 882/882 [==============================] - 596s 675ms/step - loss: 0.0183 - acc: 0.9944 - precision: 0.9946 - recall: 0.9941 - auc: 0.9997 - val_loss: 0.4157 - val_acc: 0.9447 - val_precision: 0.9506 - val_recall: 0.9427 - val_auc: 0.9859
# Epoch 35/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0239 - acc: 0.9937 - precision: 0.9941 - recall: 0.9934 - auc: 0.9995
# Epoch 00035: val_loss did not improve from 0.34247
# 882/882 [==============================] - 597s 677ms/step - loss: 0.0240 - acc: 0.9937 - precision: 0.9941 - recall: 0.9934 - auc: 0.9995 - val_loss: 0.3769 - val_acc: 0.9463 - val_precision: 0.9521 - val_recall: 0.9444 - val_auc: 0.9876
# Epoch 36/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0194 - acc: 0.9944 - precision: 0.9948 - recall: 0.9942 - auc: 0.9997
# Epoch 00036: val_loss did not improve from 0.34247
# 882/882 [==============================] - 597s 677ms/step - loss: 0.0196 - acc: 0.9944 - precision: 0.9948 - recall: 0.9941 - auc: 0.9996 - val_loss: 0.4075 - val_acc: 0.9458 - val_precision: 0.9514 - val_recall: 0.9441 - val_auc: 0.9859
# Epoch 37/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0250 - acc: 0.9936 - precision: 0.9939 - recall: 0.9932 - auc: 0.9995
# Epoch 00037: val_loss did not improve from 0.34247
# 882/882 [==============================] - 594s 674ms/step - loss: 0.0253 - acc: 0.9935 - precision: 0.9939 - recall: 0.9932 - auc: 0.9995 - val_loss: 0.4035 - val_acc: 0.9451 - val_precision: 0.9504 - val_recall: 0.9433 - val_auc: 0.9864
# Epoch 00037: early stopping

# %% [markdown]
# ### Inference

# %%
image_feature_description_for_test = {
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    # 'randmark_id': tf.io.FixedLenFeature([], tf.int64),
    # 'id': tf.io.FixedLenFeature([], tf.string),
}

def _parse_image_function_for_test(example_proto):
    return tf.io.parse_single_example(example_proto, image_feature_description_for_test)

def map_func_for_test(target_record):
    img = target_record['image_raw']
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.dtypes.cast(img, tf.float32)
    return img

def resize_and_crop_func_for_test(image):
    result_image = tf.image.resize(image, config['aug']['resize'])
    # result_image = tf.image.random_crop(image, size=config['input_shape'], seed=7777)
    return result_image

def post_process_func_for_test(image):
    # result_image = result_image / 255
    result_image = my_model_base.preprocess_input(image)
    return result_image

# %%
submission_base_path = pth.join(data_base_path, 'submission')
os.makedirs(submission_base_path, exist_ok=True)

# %%
for conv_comb, activation, base_channel, \
    between_type, fc_num, batch_size \
        in itertools.product(conv_comb_list, activation_list,
                              base_channel_list, between_type_list, fc_list,
                              batch_size_list):
    config['conv']['conv_num'] = conv_comb
    config['conv']['base_channel'] = base_channel
    config['activation'] = activation
    config['between_type'] = between_type
    config['fc']['fc_num'] = fc_num
    config['batch_size'] = batch_size

    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])

    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print(model_name)

    ### Define dataset
    test_dataset = tf.data.TFRecordDataset(test_tfrecord_path, compression_type='GZIP')
    test_dataset = test_dataset.map(_parse_image_function_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(map_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(resize_and_crop_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.batch(config['batch_size'])
    test_dataset = test_dataset.map(post_process_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
    model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
    initial_epoch = 0

    model_chk_name = sorted(os.listdir(model_path))[-1]
    initial_epoch = int(model_chk_name.split('-')[0])
    model.load_weights(pth.join(model_path, model_chk_name))

    preds = model.predict(test_dataset, verbose=1)
    pred_labels = np.argmax(preds, axis=1)
    pred_probs = np.array([pred[indice] for pred, indice in zip(preds, pred_labels)])

    submission_csv_path = pth.join(data_base_path, submission_csv_name)
    submission_df = pd.read_csv(submission_csv_path)

    submission_df['landmark_id'] = pred_labels
    submission_df['conf'] = pred_probs

    today_str = datetime.date.today().strftime('%Y%m%d')
    result_filename = '{}.csv'.format(model_name)
    submission_csv_fileaname = pth.join(submission_base_path, '_'.join([today_str, result_filename]))
    submission_df.to_csv(submission_csv_fileaname, index=False)
# Out:
# InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
#       1/Unknown - 0s 143us/stepWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0169s vs `on_predict_batch_end` time: 0.3548s). Check your callbacks.
# 475/475 [==============================] - 258s 543ms/step
