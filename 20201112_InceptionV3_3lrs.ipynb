# %%
import os
import os.path as pth
import json
import shutil
import numpy as np
import pandas as pd
from tqdm import tqdm
import tensorflow as tf
import tensorflow.keras as keras

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
BASE_MODEL_NAME = 'InceptionV3-for-upload'
my_model_base = keras.applications.inception_v3
my_model = my_model_base.InceptionV3

config = {
    'is_zscore':True,
    
    # 'input_shape': (540, 960, 3),
    'aug': {
        'resize': (270, 480),
        #'resize': (297, 528),
    },
    # 'input_shape': (224, 360, 3),
    #'input_shape': (270, 480, 3),
    'input_shape': (270, 480, 3),

    'output_activation': 'softmax',
    'num_class': 1049,
    'output_size': 1049,
    
    'conv':{
        'conv_num': (0,), # (3,5,3),
        'base_channel': 0, # 4,
        'kernel_size': 0, # 3,
        'padding':'same',
        'stride':'X'
    },
    'pool':{
        'type':'X',
        'size':'X',
        'stride':'X',
        'padding':'same'
    },
    'fc':{
        'fc_num': 0,
     },
    
    'activation':'relu',
    
    'between_type': 'avg',
    
    'is_batchnorm': True,
    'is_dropout': False,
    'dropout_rate': 0.5,
    
    'batch_size': 80,
    'buffer_size': 256,
    'loss': 'CategoricalCrossentropy',
    
    'num_epoch': 10000,
    'learning_rate': 1e-3,
    
    'random_state': 7777
}

# %%
image_feature_description = {
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    'randmark_id': tf.io.FixedLenFeature([], tf.int64),
    # 'id': tf.io.FixedLenFeature([], tf.string),
}

def _parse_image_function(example_proto):
    return tf.io.parse_single_example(example_proto, image_feature_description)

def map_func(target_record):
    img = target_record['image_raw']
    label = target_record['randmark_id']
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.dtypes.cast(img, tf.float32)
    return img, label

def resize_and_crop_func(image, label):
    result_image = tf.image.resize(image, config['aug']['resize'])
    #result_image = tf.image.random_crop(image, size=config['input_shape'], seed=7777)  # crop revived.
    return result_image, label

def image_aug_func(image, label):
    pass
    return image, label

def post_process_func(image, label):
    # result_image = result_image / 255
    result_image = my_model_base.preprocess_input(image)
    onehot_label = tf.one_hot(label, depth=config['num_class'])
    return result_image, onehot_label

# %%
data_base_path = pth.join('data', 'public') 
os.makedirs(data_base_path, exist_ok=True)

# %%
category_csv_name = 'category.csv'
category_json_name = 'category.json'
submission_csv_name = 'sample_submisstion.csv'
train_csv_name = 'train.csv'

# train_zip_name = 'train.zip'
train_tfrecord_name = 'all_train.tfrecords'
train_tfrecord_path = pth.join(data_base_path, train_tfrecord_name)
val_tfrecord_name = 'all_val.tfrecords'
val_tfrecord_path = pth.join(data_base_path, val_tfrecord_name)
# test_zip_name = 'test.zip'
test_tfrecord_name = 'test.tfrecords'
test_tfrecord_path = pth.join(data_base_path, test_tfrecord_name)

# %%
train_csv_path = pth.join(data_base_path, train_csv_name)
train_df = pd.read_csv(train_csv_path)
train_dict = {k:v for k, v in train_df.values}

submission_csv_path = pth.join(data_base_path, submission_csv_name)
submission_df = pd.read_csv(submission_csv_path)
# submission_df.head()

category_csv_path = pth.join(data_base_path, category_csv_name)
category_df = pd.read_csv(category_csv_path)
category_dict = {k:v for k, v in category_df.values}
# category_df.head()

# %%
train_tfrecord_path
# Out:
# 'data/public/all_train.tfrecords'

# %% [markdown]
# ### Model

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import cv2

import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split, KFold, RepeatedKFold, GroupKFold, RepeatedStratifiedKFold
from sklearn.utils import shuffle

import numpy as np
import pandas as pd
import os
import os.path as pth
import shutil
import time
from tqdm import tqdm

import itertools
from itertools import product, combinations

import numpy as np
from PIL import Image

from IPython.display import clear_output

from multiprocessing import Process, Queue
import datetime

import tensorflow.keras as keras

from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras.layers import Input, Dense, Activation, BatchNormalization, \
                                    Flatten, Conv3D, AveragePooling3D, MaxPooling3D, Dropout, \
                                    Concatenate, GlobalMaxPool3D, GlobalAvgPool3D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint,LearningRateScheduler, \
                                        EarlyStopping
from tensorflow.keras.losses import mean_squared_error, mean_absolute_error
from tensorflow.keras import backend as K
from tensorflow.keras.constraints import max_norm

# %%
def build_cnn(config):
    input_layer = Input(shape=config['input_shape'], name='input_layer')
    pret_model = my_model(
        input_tensor=input_layer, include_top=False, weights='imagenet', 
        input_shape=config['input_shape'], pooling=config['between_type'], 
        classes=config['output_size']
    )

    pret_model.trainable = False
    
    x = pret_model.output
    
    if config['between_type'] == None:
        x = Flatten(name='flatten_layer')(x)
        
    if config['is_dropout']:
        x = Dropout(config['dropout_rate'], name='output_dropout')(x)    
            
    x = Dense(config['output_size'], activation=config['output_activation'], 
          name='output_fc')(x)
#     x = Activation(activation=config['output_activation'], name='output_activation')(x)
    model = Model(inputs=input_layer, outputs=x, name='{}'.format(BASE_MODEL_NAME))

    return model

# %%
model = build_cnn(config)
model.summary(line_length=150)
del model
# Out:
# Model: "InceptionV3-for-upload"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_layer (InputLayer)                         [(None, 270, 480, 3)]            0
# ______________________________________________________________________________________________________________________________________________________
# conv2d (Conv2D)                                  (None, 134, 239, 32)             864               input_layer[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization (BatchNormalization)         (None, 134, 239, 32)             96                conv2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation (Activation)                          (None, 134, 239, 32)             0                 batch_normalization[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_1 (Conv2D)                                (None, 132, 237, 32)             9216              activation[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_1 (BatchNormalization)       (None, 132, 237, 32)             96                conv2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_1 (Activation)                        (None, 132, 237, 32)             0                 batch_normalization_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_2 (Conv2D)                                (None, 132, 237, 64)             18432             activation_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_2 (BatchNormalization)       (None, 132, 237, 64)             192               conv2d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_2 (Activation)                        (None, 132, 237, 64)             0                 batch_normalization_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)                     (None, 65, 118, 64)              0                 activation_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_3 (Conv2D)                                (None, 65, 118, 80)              5120              max_pooling2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_3 (BatchNormalization)       (None, 65, 118, 80)              240               conv2d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_3 (Activation)                        (None, 65, 118, 80)              0                 batch_normalization_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_4 (Conv2D)                                (None, 63, 116, 192)             138240            activation_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_4 (BatchNormalization)       (None, 63, 116, 192)             576               conv2d_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_4 (Activation)                        (None, 63, 116, 192)             0                 batch_normalization_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)                   (None, 31, 57, 192)              0                 activation_4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_8 (Conv2D)                                (None, 31, 57, 64)               12288             max_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_8 (BatchNormalization)       (None, 31, 57, 64)               192               conv2d_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_8 (Activation)                        (None, 31, 57, 64)               0                 batch_normalization_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_6 (Conv2D)                                (None, 31, 57, 48)               9216              max_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_9 (Conv2D)                                (None, 31, 57, 96)               55296             activation_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_6 (BatchNormalization)       (None, 31, 57, 48)               144               conv2d_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_9 (BatchNormalization)       (None, 31, 57, 96)               288               conv2d_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_6 (Activation)                        (None, 31, 57, 48)               0                 batch_normalization_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_9 (Activation)                        (None, 31, 57, 96)               0                 batch_normalization_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d (AveragePooling2D)             (None, 31, 57, 192)              0                 max_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_5 (Conv2D)                                (None, 31, 57, 64)               12288             max_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_7 (Conv2D)                                (None, 31, 57, 64)               76800             activation_6[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_10 (Conv2D)                               (None, 31, 57, 96)               82944             activation_9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_11 (Conv2D)                               (None, 31, 57, 32)               6144              average_pooling2d[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_5 (BatchNormalization)       (None, 31, 57, 64)               192               conv2d_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_7 (BatchNormalization)       (None, 31, 57, 64)               192               conv2d_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_10 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_11 (BatchNormalization)      (None, 31, 57, 32)               96                conv2d_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_5 (Activation)                        (None, 31, 57, 64)               0                 batch_normalization_5[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_7 (Activation)                        (None, 31, 57, 64)               0                 batch_normalization_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_10 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_11 (Activation)                       (None, 31, 57, 32)               0                 batch_normalization_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed0 (Concatenate)                             (None, 31, 57, 256)              0                 activation_5[0][0]
#                                                                                                     activation_7[0][0]
#                                                                                                     activation_10[0][0]
#                                                                                                     activation_11[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_15 (Conv2D)                               (None, 31, 57, 64)               16384             mixed0[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_15 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_15 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_13 (Conv2D)                               (None, 31, 57, 48)               12288             mixed0[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_16 (Conv2D)                               (None, 31, 57, 96)               55296             activation_15[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_13 (BatchNormalization)      (None, 31, 57, 48)               144               conv2d_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_16 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_13 (Activation)                       (None, 31, 57, 48)               0                 batch_normalization_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_16 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d_1 (AveragePooling2D)           (None, 31, 57, 256)              0                 mixed0[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_12 (Conv2D)                               (None, 31, 57, 64)               16384             mixed0[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_14 (Conv2D)                               (None, 31, 57, 64)               76800             activation_13[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_17 (Conv2D)                               (None, 31, 57, 96)               82944             activation_16[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_18 (Conv2D)                               (None, 31, 57, 64)               16384             average_pooling2d_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_12 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_14 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_17 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_18 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_12 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_12[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_14 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_14[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_17 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_17[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_18 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed1 (Concatenate)                             (None, 31, 57, 288)              0                 activation_12[0][0]
#                                                                                                     activation_14[0][0]
#                                                                                                     activation_17[0][0]
#                                                                                                     activation_18[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_22 (Conv2D)                               (None, 31, 57, 64)               18432             mixed1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_22 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_22 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_20 (Conv2D)                               (None, 31, 57, 48)               13824             mixed1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_23 (Conv2D)                               (None, 31, 57, 96)               55296             activation_22[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_20 (BatchNormalization)      (None, 31, 57, 48)               144               conv2d_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_23 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_20 (Activation)                       (None, 31, 57, 48)               0                 batch_normalization_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_23 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d_2 (AveragePooling2D)           (None, 31, 57, 288)              0                 mixed1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_19 (Conv2D)                               (None, 31, 57, 64)               18432             mixed1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_21 (Conv2D)                               (None, 31, 57, 64)               76800             activation_20[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_24 (Conv2D)                               (None, 31, 57, 96)               82944             activation_23[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_25 (Conv2D)                               (None, 31, 57, 64)               18432             average_pooling2d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_19 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_21 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_24 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_25 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_19 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_19[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_21 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_21[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_24 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_24[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_25 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed2 (Concatenate)                             (None, 31, 57, 288)              0                 activation_19[0][0]
#                                                                                                     activation_21[0][0]
#                                                                                                     activation_24[0][0]
#                                                                                                     activation_25[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_27 (Conv2D)                               (None, 31, 57, 64)               18432             mixed2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_27 (BatchNormalization)      (None, 31, 57, 64)               192               conv2d_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_27 (Activation)                       (None, 31, 57, 64)               0                 batch_normalization_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_28 (Conv2D)                               (None, 31, 57, 96)               55296             activation_27[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_28 (BatchNormalization)      (None, 31, 57, 96)               288               conv2d_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_28 (Activation)                       (None, 31, 57, 96)               0                 batch_normalization_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_26 (Conv2D)                               (None, 15, 28, 384)              995328            mixed2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_29 (Conv2D)                               (None, 15, 28, 96)               82944             activation_28[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_26 (BatchNormalization)      (None, 15, 28, 384)              1152              conv2d_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_29 (BatchNormalization)      (None, 15, 28, 96)               288               conv2d_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_26 (Activation)                       (None, 15, 28, 384)              0                 batch_normalization_26[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_29 (Activation)                       (None, 15, 28, 96)               0                 batch_normalization_29[0][0]
# ______________________________________________________________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)                   (None, 15, 28, 288)              0                 mixed2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed3 (Concatenate)                             (None, 15, 28, 768)              0                 activation_26[0][0]
#                                                                                                     activation_29[0][0]
#                                                                                                     max_pooling2d_2[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_34 (Conv2D)                               (None, 15, 28, 128)              98304             mixed3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_34 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_34[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_34 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_34[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_35 (Conv2D)                               (None, 15, 28, 128)              114688            activation_34[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_35 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_35[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_35 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_35[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_31 (Conv2D)                               (None, 15, 28, 128)              98304             mixed3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_36 (Conv2D)                               (None, 15, 28, 128)              114688            activation_35[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_31 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_31[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_36 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_36[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_31 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_31[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_36 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_36[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_32 (Conv2D)                               (None, 15, 28, 128)              114688            activation_31[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_37 (Conv2D)                               (None, 15, 28, 128)              114688            activation_36[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_32 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_32[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_37 (BatchNormalization)      (None, 15, 28, 128)              384               conv2d_37[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_32 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_32[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_37 (Activation)                       (None, 15, 28, 128)              0                 batch_normalization_37[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d_3 (AveragePooling2D)           (None, 15, 28, 768)              0                 mixed3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_30 (Conv2D)                               (None, 15, 28, 192)              147456            mixed3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_33 (Conv2D)                               (None, 15, 28, 192)              172032            activation_32[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_38 (Conv2D)                               (None, 15, 28, 192)              172032            activation_37[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_39 (Conv2D)                               (None, 15, 28, 192)              147456            average_pooling2d_3[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_30 (BatchNormalization)      (None, 15, 28, 192)              576               conv2d_30[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_33 (BatchNormalization)      (None, 15, 28, 192)              576               conv2d_33[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_38 (BatchNormalization)      (None, 15, 28, 192)              576               conv2d_38[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_39 (BatchNormalization)      (None, 15, 28, 192)              576               conv2d_39[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_30 (Activation)                       (None, 15, 28, 192)              0                 batch_normalization_30[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_33 (Activation)                       (None, 15, 28, 192)              0                 batch_normalization_33[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_38 (Activation)                       (None, 15, 28, 192)              0                 batch_normalization_38[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_39 (Activation)                       (None, 15, 28, 192)              0                 batch_normalization_39[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed4 (Concatenate)                             (None, 15, 28, 768)              0                 activation_30[0][0]
#                                                                                                     activation_33[0][0]
#                                                                                                     activation_38[0][0]
#                                                                                                     activation_39[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_44 (Conv2D)                               (None, 15, 28, 160)              122880            mixed4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_44 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_44[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_44 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_44[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_45 (Conv2D)                               (None, 15, 28, 160)              179200            activation_44[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_45 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_45[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_45 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_45[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_41 (Conv2D)                               (None, 15, 28, 160)              122880            mixed4[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_46 (Conv2D)                               (None, 15, 28, 160)              179200            activation_45[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_41 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_41[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_46 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_46[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_41 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_41[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_46 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_46[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_42 (Conv2D)                               (None, 15, 28, 160)              179200            activation_41[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_47 (Conv2D)                               (None, 15, 28, 160)              179200            activation_46[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_42 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_42[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_47 (BatchNormalization)      (None, 15, 28, 160)              480               conv2d_47[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_42 (Activation)                       (None, 15, 28, 160)              0                 batch_normalization_42[0][0]
# ______________________________________________________________________________________________________________________________________________________
# ...
# batch_normalization_82 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_82[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_83 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_83[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_84 (Conv2D)                               (None, 7, 13, 192)               245760            average_pooling2d_7[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_76 (BatchNormalization)      (None, 7, 13, 320)               960               conv2d_76[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_78 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_78[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_79 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_79[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_82 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_82[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_83 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_83[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_84 (BatchNormalization)      (None, 7, 13, 192)               576               conv2d_84[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_76 (Activation)                       (None, 7, 13, 320)               0                 batch_normalization_76[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed9_0 (Concatenate)                           (None, 7, 13, 768)               0                 activation_78[0][0]
#                                                                                                     activation_79[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate (Concatenate)                        (None, 7, 13, 768)               0                 activation_82[0][0]
#                                                                                                     activation_83[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_84 (Activation)                       (None, 7, 13, 192)               0                 batch_normalization_84[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed9 (Concatenate)                             (None, 7, 13, 2048)              0                 activation_76[0][0]
#                                                                                                     mixed9_0[0][0]
#                                                                                                     concatenate[0][0]
#                                                                                                     activation_84[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_89 (Conv2D)                               (None, 7, 13, 448)               917504            mixed9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_89 (BatchNormalization)      (None, 7, 13, 448)               1344              conv2d_89[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_89 (Activation)                       (None, 7, 13, 448)               0                 batch_normalization_89[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_86 (Conv2D)                               (None, 7, 13, 384)               786432            mixed9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_90 (Conv2D)                               (None, 7, 13, 384)               1548288           activation_89[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_86 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_86[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_90 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_90[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_86 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_86[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_90 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_90[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_87 (Conv2D)                               (None, 7, 13, 384)               442368            activation_86[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_88 (Conv2D)                               (None, 7, 13, 384)               442368            activation_86[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_91 (Conv2D)                               (None, 7, 13, 384)               442368            activation_90[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_92 (Conv2D)                               (None, 7, 13, 384)               442368            activation_90[0][0]
# ______________________________________________________________________________________________________________________________________________________
# average_pooling2d_8 (AveragePooling2D)           (None, 7, 13, 2048)              0                 mixed9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_85 (Conv2D)                               (None, 7, 13, 320)               655360            mixed9[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_87 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_87[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_88 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_88[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_91 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_91[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_92 (BatchNormalization)      (None, 7, 13, 384)               1152              conv2d_92[0][0]
# ______________________________________________________________________________________________________________________________________________________
# conv2d_93 (Conv2D)                               (None, 7, 13, 192)               393216            average_pooling2d_8[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_85 (BatchNormalization)      (None, 7, 13, 320)               960               conv2d_85[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_87 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_87[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_88 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_88[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_91 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_91[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_92 (Activation)                       (None, 7, 13, 384)               0                 batch_normalization_92[0][0]
# ______________________________________________________________________________________________________________________________________________________
# batch_normalization_93 (BatchNormalization)      (None, 7, 13, 192)               576               conv2d_93[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_85 (Activation)                       (None, 7, 13, 320)               0                 batch_normalization_85[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed9_1 (Concatenate)                           (None, 7, 13, 768)               0                 activation_87[0][0]
#                                                                                                     activation_88[0][0]
# ______________________________________________________________________________________________________________________________________________________
# concatenate_1 (Concatenate)                      (None, 7, 13, 768)               0                 activation_91[0][0]
#                                                                                                     activation_92[0][0]
# ______________________________________________________________________________________________________________________________________________________
# activation_93 (Activation)                       (None, 7, 13, 192)               0                 batch_normalization_93[0][0]
# ______________________________________________________________________________________________________________________________________________________
# mixed10 (Concatenate)                            (None, 7, 13, 2048)              0                 activation_85[0][0]
#                                                                                                     mixed9_1[0][0]
#                                                                                                     concatenate_1[0][0]
#                                                                                                     activation_93[0][0]
# ______________________________________________________________________________________________________________________________________________________
# global_average_pooling2d (GlobalAveragePooling2D (None, 2048)                     0                 mixed10[0][0]
# ______________________________________________________________________________________________________________________________________________________
# output_fc (Dense)                                (None, 1049)                     2149401           global_average_pooling2d[0][0]
# ======================================================================================================================================================
# Total params: 23,952,185
# Trainable params: 2,149,401
# Non-trainable params: 21,802,784
# ______________________________________________________________________________________________________________________________________________________

# %%
model_base_path = data_base_path
model_checkpoint_path = pth.join(model_base_path, 'checkpoint')

# %%
PATIENCE = 10
for LEARNING_RATE in [1e-3, 1e-4, 1e-5]:
#     conv_comb, activation, base_channel, between_type, fc_num, batch_size = (0,), 'relu', 0, 'avg', 0, 32
#     config['conv']['conv_num'] = conv_comb
#     config['conv']['base_channel'] = base_channel
#     config['activation'] = activation
#     config['between_type'] = between_type
#     config['fc']['fc_num'] = fc_num
#     config['batch_size'] = batch_size

    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])
    #base += '_input_{}'.format(config['input_shape'][0])
    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print('################', 'lr=', LEARNING_RATE, 'patience=', PATIENCE)
    print(model_name)

    ### Define dataset
    dataset = tf.data.TFRecordDataset(train_tfrecord_path, compression_type='GZIP')
    dataset = dataset.map(_parse_image_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # dataset = dataset.cache()
    dataset = dataset.map(map_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.map(resize_and_crop_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.map(image_aug_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(config['buffer_size'])
    dataset = dataset.batch(config['batch_size'])
    dataset = dataset.map(post_process_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    val_dataset = tf.data.TFRecordDataset(val_tfrecord_path, compression_type='GZIP')
    val_dataset = val_dataset.map(_parse_image_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    val_dataset = val_dataset.map(map_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    val_dataset = val_dataset.map(resize_and_crop_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.map(image_aug_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.shuffle(config['buffer_size'])
    val_dataset = val_dataset.batch(config['batch_size'])
    val_dataset = val_dataset.map(post_process_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.cache()
    val_dataset = val_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
#     model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
#                   metrics=['acc', 'Precision', 'Recall', 'AUC'])
    initial_epoch = 0

    if pth.isdir(model_path) and len([_ for _ in os.listdir(model_path) if _.endswith('hdf5')]) >= 1:
        model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])

        model_chk_name = sorted(os.listdir(model_path))[-1]
        initial_epoch = int(model_chk_name.split('-')[0])
        model.load_weights(pth.join(model_path, model_chk_name))
    else:
        model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
                     metrics=['acc', 'Precision', 'Recall', 'AUC'])
        
        PRE_TRAIN_EPOCH = 3
        model.fit(
            x=dataset, epochs=PRE_TRAIN_EPOCH, # train only top layers for just a few epochs.
            validation_data=val_dataset, shuffle=True,
            #callbacks = [checkpointer, es], #batch_size=config['batch_size']
            initial_epoch=initial_epoch,
            # steps_per_epoch=train_num_steps, validation_steps=val_num_steps,
            verbose=1)
        
        for i, layer in enumerate(model.layers):
            print(i, layer.name)
        
        for layer in model.layers[:229]:
            layer.trainable = False
        for layer in model.layers[229:]:
            layer.trainable = True
        
        model.compile(loss=config['loss'], optimizer=Adam(lr=LEARNING_RATE), #config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
        
        initial_epoch=PRE_TRAIN_EPOCH
            
    # ### Freeze first layer
    # conv_list = [layer for layer in model.layers if isinstance(layer, keras.layers.Conv2D)]
    # conv_list[0].trainable = False
    # # conv_list[1].trainable = False

    os.makedirs(model_path, exist_ok=True)
    model_filename = pth.join(model_path, '{epoch:06d}-{val_loss:0.6f}-{loss:0.6f}.hdf5')
    checkpointer = ModelCheckpoint(
        filepath=model_filename, verbose=1, 
        period=1, save_best_only=True, 
        monitor='val_loss'
    )
    es = EarlyStopping(monitor='val_loss', verbose=1, patience=PATIENCE)

    hist = model.fit(
        x=dataset, epochs=config['num_epoch'], 
        validation_data=val_dataset, shuffle=True,
        callbacks = [checkpointer, es], #batch_size=config['batch_size']
        initial_epoch=initial_epoch,
        # steps_per_epoch=train_num_steps, validation_steps=val_num_steps,
        verbose=1
    )

    model_analysis_path = model_path.replace('checkpoint', 'analysis')
    visualization_path = pth.join(model_analysis_path,'visualization')
    os.makedirs(visualization_path, exist_ok=True)
    
    print()
    # clear_output()        
    for each_label in ['loss', 'acc', 'precision', 'recall', 'auc']:
        fig, ax = plt.subplots()
        ax.plot(hist.history[each_label], 'g', label='train_{}'.format(each_label))
        ax.plot(hist.history['val_{}'.format(each_label)], 'r', label='val_{}'.format(each_label))
        ax.set_xlabel('epoch')
        ax.set_ylabel('loss')
        ax.legend(loc='upper left')
        if not each_label == 'loss':
            plt.ylim(0, 1)
        plt.show()
        filename = 'learning_curve_{}'.format(each_label)
#             fig.savefig(pth.join(visualization_path, filename), transparent=True)
        plt.cla()
        plt.clf()
        plt.close('all')

    np.savez_compressed(pth.join(visualization_path, 'learning_curve'), 
                        loss=hist.history['loss'], 
                        val_loss=hist.history['val_loss'],
                        acc=hist.history['acc'], 
                        val_acc=hist.history['val_acc'],
                        precision=hist.history['precision'], 
                        vaval_precisionl_mae=hist.history['val_precision'],  
                        recall=hist.history['recall'],
                        val_recall=hist.history['val_recall'],
                        auc=hist.history['auc'],
                        val_auc=hist.history['val_auc']
                        )

    model.save(pth.join(model_path, '000000_last.hdf5'))
    K.clear_session()
    del(model)
    
    model_analysis_base_path = pth.join(model_base_path, 'analysis', model_name) 
    with open(pth.join(model_analysis_base_path, 'config.json'), 'w') as f:
        json.dump(config, f)

    chk_name_list = sorted([name for name in os.listdir(model_path) if name != '000000_last.hdf5'])
    for chk_name in chk_name_list[:-5]:
        os.remove(pth.join(model_path, chk_name))
    # clear_output()
    
    PATIENCE -= 2
# Out:
# ################ lr= 0.001 patience= 10
# InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
# Epoch 1/3
# 882/882 [==============================] - 476s 539ms/step - loss: 2.9958 - acc: 0.5333 - precision: 0.9813 - recall: 0.2565 - auc: 0.8920 - val_loss: 1.3259 - val_acc: 0.7509 - val_precision: 0.9738 - val_recall: 0.5564 - val_auc: 0.9754
# Epoch 2/3
# 882/882 [==============================] - 476s 539ms/step - loss: 0.8601 - acc: 0.8305 - precision: 0.9721 - recall: 0.7010 - auc: 0.9862 - val_loss: 0.8802 - val_acc: 0.8173 - val_precision: 0.9559 - val_recall: 0.7190 - val_auc: 0.9817
# Epoch 3/3
# 882/882 [==============================] - 475s 539ms/step - loss: 0.5342 - acc: 0.8853 - precision: 0.9683 - recall: 0.8185 - auc: 0.9912 - val_loss: 0.7357 - val_acc: 0.8384 - val_precision: 0.9481 - val_recall: 0.7750 - val_auc: 0.9841
# 0 input_layer
# 1 conv2d_188
# 2 batch_normalization_188
# 3 activation_188
# 4 conv2d_189
# 5 batch_normalization_189
# 6 activation_189
# 7 conv2d_190
# 8 batch_normalization_190
# 9 activation_190
# 10 max_pooling2d_8
# 11 conv2d_191
# 12 batch_normalization_191
# 13 activation_191
# 14 conv2d_192
# 15 batch_normalization_192
# 16 activation_192
# 17 max_pooling2d_9
# 18 conv2d_196
# 19 batch_normalization_196
# 20 activation_196
# 21 conv2d_194
# 22 conv2d_197
# 23 batch_normalization_194
# 24 batch_normalization_197
# 25 activation_194
# 26 activation_197
# 27 average_pooling2d_18
# 28 conv2d_193
# 29 conv2d_195
# 30 conv2d_198
# 31 conv2d_199
# 32 batch_normalization_193
# 33 batch_normalization_195
# 34 batch_normalization_198
# 35 batch_normalization_199
# 36 activation_193
# 37 activation_195
# 38 activation_198
# 39 activation_199
# 40 mixed0
# 41 conv2d_203
# 42 batch_normalization_203
# 43 activation_203
# 44 conv2d_201
# 45 conv2d_204
# 46 batch_normalization_201
# 47 batch_normalization_204
# 48 activation_201
# 49 activation_204
# 50 average_pooling2d_19
# 51 conv2d_200
# 52 conv2d_202
# 53 conv2d_205
# 54 conv2d_206
# 55 batch_normalization_200
# 56 batch_normalization_202
# 57 batch_normalization_205
# 58 batch_normalization_206
# 59 activation_200
# 60 activation_202
# 61 activation_205
# 62 activation_206
# 63 mixed1
# 64 conv2d_210
# 65 batch_normalization_210
# 66 activation_210
# 67 conv2d_208
# 68 conv2d_211
# 69 batch_normalization_208
# 70 batch_normalization_211
# 71 activation_208
# 72 activation_211
# 73 average_pooling2d_20
# 74 conv2d_207
# 75 conv2d_209
# 76 conv2d_212
# 77 conv2d_213
# 78 batch_normalization_207
# 79 batch_normalization_209
# 80 batch_normalization_212
# 81 batch_normalization_213
# 82 activation_207
# 83 activation_209
# 84 activation_212
# 85 activation_213
# 86 mixed2
# 87 conv2d_215
# 88 batch_normalization_215
# 89 activation_215
# 90 conv2d_216
# 91 batch_normalization_216
# 92 activation_216
# 93 conv2d_214
# 94 conv2d_217
# 95 batch_normalization_214
# 96 batch_normalization_217
# 97 activation_214
# 98 activation_217
# 99 max_pooling2d_10
# 100 mixed3
# 101 conv2d_222
# 102 batch_normalization_222
# 103 activation_222
# 104 conv2d_223
# 105 batch_normalization_223
# 106 activation_223
# 107 conv2d_219
# 108 conv2d_224
# 109 batch_normalization_219
# 110 batch_normalization_224
# 111 activation_219
# 112 activation_224
# 113 conv2d_220
# 114 conv2d_225
# 115 batch_normalization_220
# 116 batch_normalization_225
# 117 activation_220
# 118 activation_225
# 119 average_pooling2d_21
# 120 conv2d_218
# 121 conv2d_221
# 122 conv2d_226
# 123 conv2d_227
# 124 batch_normalization_218
# 125 batch_normalization_221
# 126 batch_normalization_226
# 127 batch_normalization_227
# 128 activation_218
# 129 activation_221
# 130 activation_226
# 131 activation_227
# 132 mixed4
# 133 conv2d_232
# 134 batch_normalization_232
# 135 activation_232
# 136 conv2d_233
# 137 batch_normalization_233
# 138 activation_233
# 139 conv2d_229
# 140 conv2d_234
# 141 batch_normalization_229
# 142 batch_normalization_234
# 143 activation_229
# 144 activation_234
# 145 conv2d_230
# 146 conv2d_235
# 147 batch_normalization_230
# 148 batch_normalization_235
# 149 activation_230
# 150 activation_235
# 151 average_pooling2d_22
# 152 conv2d_228
# 153 conv2d_231
# 154 conv2d_236
# 155 conv2d_237
# 156 batch_normalization_228
# 157 batch_normalization_231
# 158 batch_normalization_236
# 159 batch_normalization_237
# 160 activation_228
# 161 activation_231
# 162 activation_236
# 163 activation_237
# 164 mixed5
# 165 conv2d_242
# 166 batch_normalization_242
# 167 activation_242
# 168 conv2d_243
# 169 batch_normalization_243
# 170 activation_243
# 171 conv2d_239
# 172 conv2d_244
# 173 batch_normalization_239
# 174 batch_normalization_244
# 175 activation_239
# 176 activation_244
# 177 conv2d_240
# 178 conv2d_245
# 179 batch_normalization_240
# 180 batch_normalization_245
# 181 activation_240
# 182 activation_245
# 183 average_pooling2d_23
# 184 conv2d_238
# 185 conv2d_241
# 186 conv2d_246
# 187 conv2d_247
# 188 batch_normalization_238
# 189 batch_normalization_241
# 190 batch_normalization_246
# 191 batch_normalization_247
# 192 activation_238
# 193 activation_241
# 194 activation_246
# 195 activation_247
# 196 mixed6
# 197 conv2d_252
# 198 batch_normalization_252
# 199 activation_252
# 200 conv2d_253
# 201 batch_normalization_253
# 202 activation_253
# 203 conv2d_249
# 204 conv2d_254
# 205 batch_normalization_249
# 206 batch_normalization_254
# 207 activation_249
# 208 activation_254
# 209 conv2d_250
# 210 conv2d_255
# 211 batch_normalization_250
# 212 batch_normalization_255
# 213 activation_250
# 214 activation_255
# 215 average_pooling2d_24
# 216 conv2d_248
# 217 conv2d_251
# 218 conv2d_256
# 219 conv2d_257
# 220 batch_normalization_248
# 221 batch_normalization_251
# 222 batch_normalization_256
# 223 batch_normalization_257
# 224 activation_248
# 225 activation_251
# 226 activation_256
# 227 activation_257
# 228 mixed7
# 229 conv2d_260
# 230 batch_normalization_260
# 231 activation_260
# 232 conv2d_261
# 233 batch_normalization_261
# 234 activation_261
# 235 conv2d_258
# 236 conv2d_262
# 237 batch_normalization_258
# 238 batch_normalization_262
# 239 activation_258
# 240 activation_262
# 241 conv2d_259
# 242 conv2d_263
# 243 batch_normalization_259
# 244 batch_normalization_263
# 245 activation_259
# 246 activation_263
# 247 max_pooling2d_11
# 248 mixed8
# 249 conv2d_268
# 250 batch_normalization_268
# 251 activation_268
# 252 conv2d_265
# 253 conv2d_269
# 254 batch_normalization_265
# 255 batch_normalization_269
# 256 activation_265
# 257 activation_269
# 258 conv2d_266
# 259 conv2d_267
# 260 conv2d_270
# 261 conv2d_271
# 262 average_pooling2d_25
# 263 conv2d_264
# 264 batch_normalization_266
# 265 batch_normalization_267
# 266 batch_normalization_270
# 267 batch_normalization_271
# 268 conv2d_272
# 269 batch_normalization_264
# 270 activation_266
# 271 activation_267
# 272 activation_270
# 273 activation_271
# 274 batch_normalization_272
# 275 activation_264
# 276 mixed9_0
# 277 concatenate_4
# 278 activation_272
# 279 mixed9
# 280 conv2d_277
# 281 batch_normalization_277
# 282 activation_277
# 283 conv2d_274
# 284 conv2d_278
# 285 batch_normalization_274
# 286 batch_normalization_278
# 287 activation_274
# 288 activation_278
# 289 conv2d_275
# 290 conv2d_276
# 291 conv2d_279
# 292 conv2d_280
# 293 average_pooling2d_26
# 294 conv2d_273
# 295 batch_normalization_275
# 296 batch_normalization_276
# 297 batch_normalization_279
# 298 batch_normalization_280
# 299 conv2d_281
# 300 batch_normalization_273
# 301 activation_275
# 302 activation_276
# 303 activation_279
# 304 activation_280
# 305 batch_normalization_281
# 306 activation_273
# 307 mixed9_1
# 308 concatenate_5
# 309 activation_281
# 310 mixed10
# 311 global_average_pooling2d_2
# 312 output_fc
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 4/10000
#     882/Unknown - 510s 578ms/step - loss: 0.4877 - acc: 0.8834 - precision: 0.9507 - recall: 0.8404 - auc: 0.9910
# Epoch 00004: val_loss improved from inf to 0.34085, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000004-0.340855-0.487708.hdf5
# 882/882 [==============================] - 602s 682ms/step - loss: 0.4877 - acc: 0.8834 - precision: 0.9507 - recall: 0.8404 - auc: 0.9910 - val_loss: 0.3409 - val_acc: 0.9158 - val_precision: 0.9531 - val_recall: 0.8934 - val_auc: 0.9931
# Epoch 5/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1080 - acc: 0.9722 - precision: 0.9851 - recall: 0.9614 - auc: 0.9991
# Epoch 00005: val_loss improved from 0.34085 to 0.32345, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000005-0.323446-0.108130.hdf5
# 882/882 [==============================] - 602s 682ms/step - loss: 0.1081 - acc: 0.9722 - precision: 0.9851 - recall: 0.9614 - auc: 0.9991 - val_loss: 0.3234 - val_acc: 0.9241 - val_precision: 0.9523 - val_recall: 0.9103 - val_auc: 0.9921
# Epoch 6/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0710 - acc: 0.9820 - precision: 0.9878 - recall: 0.9750 - auc: 0.9995
# Epoch 00006: val_loss improved from 0.32345 to 0.29135, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000006-0.291351-0.071143.hdf5
# 882/882 [==============================] - 601s 681ms/step - loss: 0.0711 - acc: 0.9820 - precision: 0.9878 - recall: 0.9750 - auc: 0.9995 - val_loss: 0.2914 - val_acc: 0.9292 - val_precision: 0.9524 - val_recall: 0.9161 - val_auc: 0.9929
# Epoch 7/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0610 - acc: 0.9836 - precision: 0.9886 - recall: 0.9786 - auc: 0.9996
# Epoch 00007: val_loss improved from 0.29135 to 0.28699, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000007-0.286990-0.061211.hdf5
# 882/882 [==============================] - 600s 681ms/step - loss: 0.0612 - acc: 0.9836 - precision: 0.9886 - recall: 0.9786 - auc: 0.9996 - val_loss: 0.2870 - val_acc: 0.9345 - val_precision: 0.9537 - val_recall: 0.9254 - val_auc: 0.9923
# Epoch 8/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0556 - acc: 0.9852 - precision: 0.9898 - recall: 0.9808 - auc: 0.9996
# Epoch 00008: val_loss improved from 0.28699 to 0.28612, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000008-0.286115-0.055679.hdf5
# 882/882 [==============================] - 602s 683ms/step - loss: 0.0557 - acc: 0.9851 - precision: 0.9898 - recall: 0.9808 - auc: 0.9996 - val_loss: 0.2861 - val_acc: 0.9369 - val_precision: 0.9531 - val_recall: 0.9292 - val_auc: 0.9919
# Epoch 9/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0435 - acc: 0.9882 - precision: 0.9913 - recall: 0.9854 - auc: 0.9997
# Epoch 00009: val_loss improved from 0.28612 to 0.22213, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000009-0.222126-0.043650.hdf5
# 882/882 [==============================] - 602s 682ms/step - loss: 0.0437 - acc: 0.9882 - precision: 0.9912 - recall: 0.9853 - auc: 0.9997 - val_loss: 0.2221 - val_acc: 0.9486 - val_precision: 0.9663 - val_recall: 0.9402 - val_auc: 0.9943
# Epoch 10/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0318 - acc: 0.9915 - precision: 0.9938 - recall: 0.9899 - auc: 0.9997
# Epoch 00010: val_loss did not improve from 0.22213
# 882/882 [==============================] - 601s 681ms/step - loss: 0.0318 - acc: 0.9915 - precision: 0.9938 - recall: 0.9899 - auc: 0.9997 - val_loss: 0.2400 - val_acc: 0.9490 - val_precision: 0.9637 - val_recall: 0.9428 - val_auc: 0.9929
# Epoch 11/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0331 - acc: 0.9914 - precision: 0.9931 - recall: 0.9896 - auc: 0.9996
# Epoch 00011: val_loss did not improve from 0.22213
# 882/882 [==============================] - 601s 682ms/step - loss: 0.0333 - acc: 0.9914 - precision: 0.9931 - recall: 0.9896 - auc: 0.9996 - val_loss: 0.2693 - val_acc: 0.9435 - val_precision: 0.9598 - val_recall: 0.9369 - val_auc: 0.9920
# Epoch 12/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0340 - acc: 0.9907 - precision: 0.9926 - recall: 0.9890 - auc: 0.9996
# Epoch 00012: val_loss did not improve from 0.22213
# 882/882 [==============================] - 601s 682ms/step - loss: 0.0341 - acc: 0.9907 - precision: 0.9926 - recall: 0.9890 - auc: 0.9996 - val_loss: 0.2231 - val_acc: 0.9506 - val_precision: 0.9653 - val_recall: 0.9450 - val_auc: 0.9936
# Epoch 13/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0263 - acc: 0.9933 - precision: 0.9945 - recall: 0.9921 - auc: 0.9997
# Epoch 00013: val_loss improved from 0.22213 to 0.20184, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000013-0.201837-0.026598.hdf5
# 882/882 [==============================] - 602s 683ms/step - loss: 0.0266 - acc: 0.9933 - precision: 0.9945 - recall: 0.9920 - auc: 0.9997 - val_loss: 0.2018 - val_acc: 0.9549 - val_precision: 0.9678 - val_recall: 0.9492 - val_auc: 0.9942
# Epoch 14/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0188 - acc: 0.9956 - precision: 0.9964 - recall: 0.9945 - auc: 0.9998
# Epoch 00014: val_loss did not improve from 0.20184
# 882/882 [==============================] - 603s 684ms/step - loss: 0.0189 - acc: 0.9955 - precision: 0.9964 - recall: 0.9945 - auc: 0.9998 - val_loss: 0.2216 - val_acc: 0.9521 - val_precision: 0.9665 - val_recall: 0.9470 - val_auc: 0.9932
# Epoch 15/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0263 - acc: 0.9932 - precision: 0.9942 - recall: 0.9918 - auc: 0.9997
# Epoch 00015: val_loss did not improve from 0.20184
# 882/882 [==============================] - 602s 682ms/step - loss: 0.0266 - acc: 0.9932 - precision: 0.9941 - recall: 0.9917 - auc: 0.9997 - val_loss: 0.2224 - val_acc: 0.9541 - val_precision: 0.9661 - val_recall: 0.9489 - val_auc: 0.9931
# Epoch 16/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0164 - acc: 0.9955 - precision: 0.9963 - recall: 0.9946 - auc: 0.9999
# Epoch 00016: val_loss improved from 0.20184 to 0.20176, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000016-0.201759-0.016568.hdf5
# 882/882 [==============================] - 604s 685ms/step - loss: 0.0166 - acc: 0.9955 - precision: 0.9963 - recall: 0.9946 - auc: 0.9998 - val_loss: 0.2018 - val_acc: 0.9588 - val_precision: 0.9701 - val_recall: 0.9544 - val_auc: 0.9937
# Epoch 17/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0185 - acc: 0.9951 - precision: 0.9959 - recall: 0.9943 - auc: 0.9998
# Epoch 00017: val_loss did not improve from 0.20176
# 882/882 [==============================] - 603s 684ms/step - loss: 0.0186 - acc: 0.9951 - precision: 0.9959 - recall: 0.9943 - auc: 0.9998 - val_loss: 0.2280 - val_acc: 0.9535 - val_precision: 0.9655 - val_recall: 0.9490 - val_auc: 0.9928
# Epoch 18/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0149 - acc: 0.9961 - precision: 0.9969 - recall: 0.9955 - auc: 0.9998
# Epoch 00018: val_loss did not improve from 0.20176
# 882/882 [==============================] - 602s 683ms/step - loss: 0.0152 - acc: 0.9961 - precision: 0.9969 - recall: 0.9954 - auc: 0.9998 - val_loss: 0.2144 - val_acc: 0.9573 - val_precision: 0.9677 - val_recall: 0.9535 - val_auc: 0.9931
# Epoch 19/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0118 - acc: 0.9970 - precision: 0.9975 - recall: 0.9966 - auc: 0.9999
# Epoch 00019: val_loss improved from 0.20176 to 0.17395, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000019-0.173951-0.012002.hdf5
# 882/882 [==============================] - 603s 684ms/step - loss: 0.0120 - acc: 0.9969 - precision: 0.9974 - recall: 0.9966 - auc: 0.9999 - val_loss: 0.1740 - val_acc: 0.9654 - val_precision: 0.9745 - val_recall: 0.9618 - val_auc: 0.9946
# Epoch 20/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0140 - acc: 0.9963 - precision: 0.9968 - recall: 0.9957 - auc: 0.9998
# Epoch 00020: val_loss did not improve from 0.17395
# 882/882 [==============================] - 601s 682ms/step - loss: 0.0142 - acc: 0.9963 - precision: 0.9968 - recall: 0.9957 - auc: 0.9998 - val_loss: 0.2310 - val_acc: 0.9524 - val_precision: 0.9655 - val_recall: 0.9486 - val_auc: 0.9929
# Epoch 21/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0128 - acc: 0.9968 - precision: 0.9972 - recall: 0.9963 - auc: 0.9999
# Epoch 00021: val_loss did not improve from 0.17395
# 882/882 [==============================] - 602s 682ms/step - loss: 0.0130 - acc: 0.9968 - precision: 0.9972 - recall: 0.9963 - auc: 0.9999 - val_loss: 0.1903 - val_acc: 0.9640 - val_precision: 0.9721 - val_recall: 0.9603 - val_auc: 0.9938
# Epoch 22/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0094 - acc: 0.9976 - precision: 0.9979 - recall: 0.9972 - auc: 0.9999
# Epoch 00022: val_loss did not improve from 0.17395
# 882/882 [==============================] - 600s 681ms/step - loss: 0.0097 - acc: 0.9976 - precision: 0.9979 - recall: 0.9972 - auc: 0.9999 - val_loss: 0.2113 - val_acc: 0.9600 - val_precision: 0.9696 - val_recall: 0.9571 - val_auc: 0.9931
# Epoch 23/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0115 - acc: 0.9968 - precision: 0.9973 - recall: 0.9964 - auc: 0.9999
# Epoch 00023: val_loss did not improve from 0.17395
# 882/882 [==============================] - 600s 681ms/step - loss: 0.0117 - acc: 0.9968 - precision: 0.9973 - recall: 0.9964 - auc: 0.9999 - val_loss: 0.1802 - val_acc: 0.9658 - val_precision: 0.9747 - val_recall: 0.9616 - val_auc: 0.9945
# Epoch 24/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0128 - acc: 0.9968 - precision: 0.9972 - recall: 0.9965 - auc: 0.9998
# Epoch 00024: val_loss improved from 0.17395 to 0.17393, saving model to data/public/checkpoint/InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000024-0.173930-0.012970.hdf5
# 882/882 [==============================] - 600s 680ms/step - loss: 0.0130 - acc: 0.9968 - precision: 0.9972 - recall: 0.9965 - auc: 0.9998 - val_loss: 0.1739 - val_acc: 0.9675 - val_precision: 0.9764 - val_recall: 0.9642 - val_auc: 0.9941
# Epoch 25/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0105 - acc: 0.9971 - precision: 0.9974 - recall: 0.9967 - auc: 0.9999
# Epoch 00025: val_loss did not improve from 0.17393
# 882/882 [==============================] - 599s 679ms/step - loss: 0.0107 - acc: 0.9971 - precision: 0.9974 - recall: 0.9967 - auc: 0.9999 - val_loss: 0.2222 - val_acc: 0.9579 - val_precision: 0.9682 - val_recall: 0.9551 - val_auc: 0.9927
# Epoch 26/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0087 - acc: 0.9977 - precision: 0.9980 - recall: 0.9973 - auc: 0.9999
# Epoch 00026: val_loss did not improve from 0.17393
# 882/882 [==============================] - 599s 679ms/step - loss: 0.0088 - acc: 0.9976 - precision: 0.9980 - recall: 0.9973 - auc: 0.9999 - val_loss: 0.1759 - val_acc: 0.9657 - val_precision: 0.9744 - val_recall: 0.9620 - val_auc: 0.9947
# Epoch 27/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0070 - acc: 0.9982 - precision: 0.9986 - recall: 0.9980 - auc: 0.9999
# Epoch 00027: val_loss did not improve from 0.17393
# 882/882 [==============================] - 599s 679ms/step - loss: 0.0072 - acc: 0.9982 - precision: 0.9986 - recall: 0.9980 - auc: 0.9999 - val_loss: 0.1890 - val_acc: 0.9646 - val_precision: 0.9733 - val_recall: 0.9614 - val_auc: 0.9937
# Epoch 28/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0102 - acc: 0.9972 - precision: 0.9975 - recall: 0.9969 - auc: 0.9999
# Epoch 00028: val_loss did not improve from 0.17393
# 882/882 [==============================] - 600s 680ms/step - loss: 0.0104 - acc: 0.9971 - precision: 0.9975 - recall: 0.9969 - auc: 0.9999 - val_loss: 0.1939 - val_acc: 0.9657 - val_precision: 0.9732 - val_recall: 0.9624 - val_auc: 0.9935
# Epoch 29/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0080 - acc: 0.9979 - precision: 0.9981 - recall: 0.9977 - auc: 0.9999
# Epoch 00029: val_loss did not improve from 0.17393
# 882/882 [==============================] - 598s 678ms/step - loss: 0.0081 - acc: 0.9979 - precision: 0.9981 - recall: 0.9977 - auc: 0.9999 - val_loss: 0.1882 - val_acc: 0.9634 - val_precision: 0.9725 - val_recall: 0.9588 - val_auc: 0.9941
# Epoch 30/10000
# 379/882 [===========>..................] - ETA: 4:49 - loss: 0.0092 - acc: 0.9977 - precision: 0.9980 - recall: 0.9973 - auc: 0.9999

# %% [markdown]
# ### Inference

# %%
image_feature_description_for_test = {
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    # 'randmark_id': tf.io.FixedLenFeature([], tf.int64),
    # 'id': tf.io.FixedLenFeature([], tf.string),
}

def _parse_image_function_for_test(example_proto):
    return tf.io.parse_single_example(example_proto, image_feature_description_for_test)

def map_func_for_test(target_record):
    img = target_record['image_raw']
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.dtypes.cast(img, tf.float32)
    return img

def resize_and_crop_func_for_test(image):
    result_image = tf.image.resize(image, config['aug']['resize'])
    #result_image = tf.image.random_crop(image, size=config['input_shape'], seed=7777)  # revive
    return result_image

def post_process_func_for_test(image):
    # result_image = result_image / 255
    result_image = my_model_base.preprocess_input(image)
    return result_image

# %%
submission_base_path = pth.join(data_base_path, 'submission')
os.makedirs(submission_base_path, exist_ok=True)

# %%
preds = []
# for conv_comb, activation, base_channel, \
#     between_type, fc_num, batch_size \
#         in itertools.product(conv_comb_list, activation_list,
#                               base_channel_list, between_type_list, fc_list,
#                               batch_size_list):
#     config['conv']['conv_num'] = conv_comb
#     config['conv']['base_channel'] = base_channel
#     config['activation'] = activation
#     config['between_type'] = between_type
#     config['fc']['fc_num'] = fc_num
#     config['batch_size'] = batch_size

for LEARNING_RATE in [1e-3]: #, 1e-4, 1e-5]: # just once
    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])
    #base += '_input_{}'.format(config['input_shape'][0])
    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print(model_name)

    ### Define dataset
    test_dataset = tf.data.TFRecordDataset(test_tfrecord_path, compression_type='GZIP')
    test_dataset = test_dataset.map(_parse_image_function_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(map_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(resize_and_crop_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.batch(config['batch_size'])
    test_dataset = test_dataset.map(post_process_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
    model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
    initial_epoch = 0

    model_chk_name = sorted(os.listdir(model_path))[-1]
    initial_epoch = int(model_chk_name.split('-')[0])
    model.load_weights(pth.join(model_path, model_chk_name))

    preds = model.predict(test_dataset, verbose=1)
    
    #pred_labels = np.argmax(preds, axis=1)
    #pred_probs = np.array([pred[indice] for pred, indice in zip(preds, pred_labels)])
    
    # argmax --> top3
    pred_labels = np.argsort(-preds)
    
    submission_csv_path = pth.join(data_base_path, submission_csv_name)
    submission_df = pd.read_csv(submission_csv_path)
    
    merged_df = []
    
    RANK_TO_SAVE = 5
    for i in range(RANK_TO_SAVE):
        tmp_df = submission_df.copy()
        
        tmp_labels = pred_labels[:, i]
        tmp_df['landmark_id'] = tmp_labels
        tmp_df['conf'] = np.array([pred[indice] for pred, indice in zip(preds, tmp_labels)])
        merged_df.append(tmp_df)
    
    submission_df = pd.concat(merged_df)
    
    #submission_df['landmark_id'] = pred_labels
    #submission_df['conf'] = pred_probs

    today_str = datetime.date.today().strftime('%Y%m%d')
    result_filename = '{}.csv'.format(model_name)
    submission_csv_fileaname = pth.join(submission_base_path, '_'.join([today_str, result_filename]))
    submission_df.to_csv(submission_csv_fileaname, index=False)
# Out:
# InceptionV3-for-upload_resize_270_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
#       1/Unknown - 0s 78us/stepWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0187s vs `on_predict_batch_end` time: 0.3491s). Check your callbacks.
# 475/475 [==============================] - 188s 395ms/step

# %%
# TEST
lr_start   = 0.000001*10*0.5
lr_max     = 0.0000005 * config['batch_size'] * 10*0.5
lr_min     = 0.000001 * 10*0.5
lr_ramp_ep = 5
lr_sus_ep  = 0
lr_decay   = 0.8

def lrfn(epoch):
    if epoch < lr_ramp_ep:
        lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start   
    elif epoch < lr_ramp_ep + lr_sus_ep:
        lr = lr_max    
    else:
        lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min    
    return lr

# %%
for i in list(range(1,25)):
    print(i, lrfn(i))
# Out:
# 1 1.9999999999999998e-05
# 2 3.5e-05
# 3 4.9999999999999996e-05
# 4 6.5e-05
# 5 7.999999999999999e-05
# 6 6.5e-05
# 7 5.300000000000001e-05
# 8 4.3400000000000005e-05
# 9 3.5720000000000004e-05
# 10 2.9576000000000003e-05
# 11 2.4660800000000006e-05
# 12 2.0728640000000003e-05
# 13 1.7582912000000004e-05
# 14 1.5066329600000004e-05
# 15 1.3053063680000003e-05
# 16 1.1442450944000003e-05
# 17 1.0153960755200002e-05
# 18 9.123168604160002e-06
# 19 8.298534883328002e-06
# 20 7.638827906662402e-06
# 21 7.111062325329921e-06
# 22 6.688849860263937e-06
# 23 6.351079888211149e-06
# 24 6.080863910568919e-06
