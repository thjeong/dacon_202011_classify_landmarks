# %%
import os
import os.path as pth
import json
import shutil
import pandas as pd
from tqdm import tqdm
import tensorflow as tf
import tensorflow.keras as keras

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpus[0], True)

# %%
np.array([540, 960]) * 9/12
# Out:
# array([405., 720.])

# %%
BASE_MODEL_NAME = 'MobileNetV2-for-upload'
my_model_base = keras.applications.mobilenet_v2
my_model = my_model_base.MobileNetV2

config = {
    'is_zscore':True,
    
    # 'input_shape': (540, 960, 3),
    'aug': {
        #'resize': (270, 480),
        'resize': (405, 720),
    },
    # 'input_shape': (224, 360, 3),
    #'input_shape': (270, 480, 3),
    'input_shape': (405, 405, 3),

    'output_activation': 'softmax',
    'num_class': 1049,
    'output_size': 1049,
    
    'conv':{
        'conv_num': (0), # (3,5,3),
        'base_channel': 0, # 4,
        'kernel_size': 0, # 3,
        'padding':'same',
        'stride':'X'
    },
    'pool':{
        'type':'X',
        'size':'X',
        'stride':'X',
        'padding':'same'
    },
    'fc':{
        'fc_num': 0,
     },
    
    'activation':'relu',
    
    'between_type': 'avg',
    
    'is_batchnorm': True,
    'is_dropout': False,
    'dropout_rate': 0.5,
    
    'batch_size': 64,
    'buffer_size': 256,
    'loss': 'CategoricalCrossentropy',
    
    'num_epoch': 10000,
    'learning_rate': 1e-3,
    
    'random_state': 7777
}

# %%
image_feature_description = {
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    'randmark_id': tf.io.FixedLenFeature([], tf.int64),
    # 'id': tf.io.FixedLenFeature([], tf.string),
}

def _parse_image_function(example_proto):
    return tf.io.parse_single_example(example_proto, image_feature_description)

def map_func(target_record):
    img = target_record['image_raw']
    label = target_record['randmark_id']
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.dtypes.cast(img, tf.float32)
    return img, label

def resize_and_crop_func(image, label):
    result_image = tf.image.resize(image, config['aug']['resize'])
    result_image = tf.image.random_crop(image, size=config['input_shape'], seed=7777)  # crop revived.
    return result_image, label

def image_aug_func(image, label):
    pass
    return image, label

def post_process_func(image, label):
    # result_image = result_image / 255
    result_image = my_model_base.preprocess_input(image)
    onehot_label = tf.one_hot(label, depth=config['num_class'])
    return result_image, onehot_label

# %%
data_base_path = pth.join('data', 'public') 
os.makedirs(data_base_path, exist_ok=True)

# %%
category_csv_name = 'category.csv'
category_json_name = 'category.json'
submission_csv_name = 'sample_submisstion.csv'
train_csv_name = 'train.csv'

# train_zip_name = 'train.zip'
train_tfrecord_name = 'all_train.tfrecords'
train_tfrecord_path = pth.join(data_base_path, train_tfrecord_name)
val_tfrecord_name = 'all_val.tfrecords'
val_tfrecord_path = pth.join(data_base_path, val_tfrecord_name)
# test_zip_name = 'test.zip'
test_tfrecord_name = 'test.tfrecords'
test_tfrecord_path = pth.join(data_base_path, test_tfrecord_name)

# %%
train_csv_path = pth.join(data_base_path, train_csv_name)
train_df = pd.read_csv(train_csv_path)
train_dict = {k:v for k, v in train_df.values}

submission_csv_path = pth.join(data_base_path, submission_csv_name)
submission_df = pd.read_csv(submission_csv_path)
# submission_df.head()

category_csv_path = pth.join(data_base_path, category_csv_name)
category_df = pd.read_csv(category_csv_path)
category_dict = {k:v for k, v in category_df.values}
# category_df.head()

# %%
train_tfrecord_path
# Out:
# 'data/public/all_train.tfrecords'

# %% [markdown]
# ### Model

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import cv2

import matplotlib.pyplot as plt
from PIL import Image

from sklearn.model_selection import train_test_split, KFold, RepeatedKFold, GroupKFold, RepeatedStratifiedKFold
from sklearn.utils import shuffle

import numpy as np
import pandas as pd
import os
import os.path as pth
import shutil
import time
from tqdm import tqdm

import itertools
from itertools import product, combinations

import numpy as np
from PIL import Image

from IPython.display import clear_output

from multiprocessing import Process, Queue
import datetime

import tensorflow.keras as keras

from tensorflow.keras.utils import to_categorical, Sequence
from tensorflow.keras.layers import Input, Dense, Activation, BatchNormalization, \
                                    Flatten, Conv3D, AveragePooling3D, MaxPooling3D, Dropout, \
                                    Concatenate, GlobalMaxPool3D, GlobalAvgPool3D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.callbacks import ModelCheckpoint,LearningRateScheduler, \
                                        EarlyStopping
from tensorflow.keras.losses import mean_squared_error, mean_absolute_error
from tensorflow.keras import backend as K
from tensorflow.keras.constraints import max_norm

# %%
conv_comb_list = []
conv_comb_list += [(0,)]

base_channel_list = [0]

fc_list = [0] # 128, 0

# between_type_list = [None, 'avg', 'max']
between_type_list = ['avg']

batch_size_list = [80]

activation_list = ['relu']

# len(conv_comb_list), conv_comb_list

# %%
def build_cnn(config):
    input_layer = Input(shape=config['input_shape'], name='input_layer')
    pret_model = my_model(
        input_tensor=input_layer, include_top=False, weights='imagenet', 
        input_shape=config['input_shape'], pooling=config['between_type'], 
        classes=config['output_size']
    )

    pret_model.trainable = False
    
    x = pret_model.output
    
    if config['between_type'] == None:
        x = Flatten(name='flatten_layer')(x)
        
    if config['is_dropout']:
        x = Dropout(config['dropout_rate'], name='output_dropout')(x)    
            
    x = Dense(config['output_size'], activation=config['output_activation'], 
          name='output_fc')(x)
#     x = Activation(activation=config['output_activation'], name='output_activation')(x)
    model = Model(inputs=input_layer, outputs=x, name='{}'.format(BASE_MODEL_NAME))

    return model

# %%
model = build_cnn(config)
model.summary(line_length=150)
del model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "MobileNetV2-for-upload"
# ______________________________________________________________________________________________________________________________________________________
# Layer (type)                                     Output Shape                     Param #           Connected to
# ======================================================================================================================================================
# input_layer (InputLayer)                         [(None, 405, 405, 3)]            0
# ______________________________________________________________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)                        (None, 407, 407, 3)              0                 input_layer[0][0]
# ______________________________________________________________________________________________________________________________________________________
# Conv1 (Conv2D)                                   (None, 203, 203, 32)             864               Conv1_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)                    (None, 203, 203, 32)             128               Conv1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# Conv1_relu (ReLU)                                (None, 203, 203, 32)             0                 bn_Conv1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_depthwise (DepthwiseConv2D)        (None, 203, 203, 32)             288               Conv1_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_depthwise_BN (BatchNormalization)  (None, 203, 203, 32)             128               expanded_conv_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_depthwise_relu (ReLU)              (None, 203, 203, 32)             0                 expanded_conv_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_project (Conv2D)                   (None, 203, 203, 16)             512               expanded_conv_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# expanded_conv_project_BN (BatchNormalization)    (None, 203, 203, 16)             64                expanded_conv_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_expand (Conv2D)                          (None, 203, 203, 96)             1536              expanded_conv_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_expand_BN (BatchNormalization)           (None, 203, 203, 96)             384               block_1_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_expand_relu (ReLU)                       (None, 203, 203, 96)             0                 block_1_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)                      (None, 205, 205, 96)             0                 block_1_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_depthwise (DepthwiseConv2D)              (None, 102, 102, 96)             864               block_1_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNormalization)        (None, 102, 102, 96)             384               block_1_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)                    (None, 102, 102, 96)             0                 block_1_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_project (Conv2D)                         (None, 102, 102, 24)             2304              block_1_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_1_project_BN (BatchNormalization)          (None, 102, 102, 24)             96                block_1_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_expand (Conv2D)                          (None, 102, 102, 144)            3456              block_1_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_expand_BN (BatchNormalization)           (None, 102, 102, 144)            576               block_2_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_expand_relu (ReLU)                       (None, 102, 102, 144)            0                 block_2_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_depthwise (DepthwiseConv2D)              (None, 102, 102, 144)            1296              block_2_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNormalization)        (None, 102, 102, 144)            576               block_2_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)                    (None, 102, 102, 144)            0                 block_2_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_project (Conv2D)                         (None, 102, 102, 24)             3456              block_2_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_project_BN (BatchNormalization)          (None, 102, 102, 24)             96                block_2_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_2_add (Add)                                (None, 102, 102, 24)             0                 block_1_project_BN[0][0]
#                                                                                                     block_2_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_expand (Conv2D)                          (None, 102, 102, 144)            3456              block_2_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_expand_BN (BatchNormalization)           (None, 102, 102, 144)            576               block_3_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_expand_relu (ReLU)                       (None, 102, 102, 144)            0                 block_3_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)                      (None, 103, 103, 144)            0                 block_3_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_depthwise (DepthwiseConv2D)              (None, 51, 51, 144)              1296              block_3_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNormalization)        (None, 51, 51, 144)              576               block_3_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)                    (None, 51, 51, 144)              0                 block_3_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_project (Conv2D)                         (None, 51, 51, 32)               4608              block_3_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_3_project_BN (BatchNormalization)          (None, 51, 51, 32)               128               block_3_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_expand (Conv2D)                          (None, 51, 51, 192)              6144              block_3_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_expand_BN (BatchNormalization)           (None, 51, 51, 192)              768               block_4_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_expand_relu (ReLU)                       (None, 51, 51, 192)              0                 block_4_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_depthwise (DepthwiseConv2D)              (None, 51, 51, 192)              1728              block_4_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNormalization)        (None, 51, 51, 192)              768               block_4_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)                    (None, 51, 51, 192)              0                 block_4_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_project (Conv2D)                         (None, 51, 51, 32)               6144              block_4_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_project_BN (BatchNormalization)          (None, 51, 51, 32)               128               block_4_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_4_add (Add)                                (None, 51, 51, 32)               0                 block_3_project_BN[0][0]
#                                                                                                     block_4_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_expand (Conv2D)                          (None, 51, 51, 192)              6144              block_4_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_expand_BN (BatchNormalization)           (None, 51, 51, 192)              768               block_5_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_expand_relu (ReLU)                       (None, 51, 51, 192)              0                 block_5_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_depthwise (DepthwiseConv2D)              (None, 51, 51, 192)              1728              block_5_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNormalization)        (None, 51, 51, 192)              768               block_5_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)                    (None, 51, 51, 192)              0                 block_5_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_project (Conv2D)                         (None, 51, 51, 32)               6144              block_5_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_project_BN (BatchNormalization)          (None, 51, 51, 32)               128               block_5_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_5_add (Add)                                (None, 51, 51, 32)               0                 block_4_add[0][0]
#                                                                                                     block_5_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_expand (Conv2D)                          (None, 51, 51, 192)              6144              block_5_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_expand_BN (BatchNormalization)           (None, 51, 51, 192)              768               block_6_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_expand_relu (ReLU)                       (None, 51, 51, 192)              0                 block_6_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)                      (None, 53, 53, 192)              0                 block_6_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_depthwise (DepthwiseConv2D)              (None, 26, 26, 192)              1728              block_6_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNormalization)        (None, 26, 26, 192)              768               block_6_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)                    (None, 26, 26, 192)              0                 block_6_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_project (Conv2D)                         (None, 26, 26, 64)               12288             block_6_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_6_project_BN (BatchNormalization)          (None, 26, 26, 64)               256               block_6_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_expand (Conv2D)                          (None, 26, 26, 384)              24576             block_6_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_expand_BN (BatchNormalization)           (None, 26, 26, 384)              1536              block_7_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_expand_relu (ReLU)                       (None, 26, 26, 384)              0                 block_7_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_depthwise (DepthwiseConv2D)              (None, 26, 26, 384)              3456              block_7_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNormalization)        (None, 26, 26, 384)              1536              block_7_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)                    (None, 26, 26, 384)              0                 block_7_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_project (Conv2D)                         (None, 26, 26, 64)               24576             block_7_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_project_BN (BatchNormalization)          (None, 26, 26, 64)               256               block_7_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_7_add (Add)                                (None, 26, 26, 64)               0                 block_6_project_BN[0][0]
#                                                                                                     block_7_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_expand (Conv2D)                          (None, 26, 26, 384)              24576             block_7_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_expand_BN (BatchNormalization)           (None, 26, 26, 384)              1536              block_8_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_expand_relu (ReLU)                       (None, 26, 26, 384)              0                 block_8_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_depthwise (DepthwiseConv2D)              (None, 26, 26, 384)              3456              block_8_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNormalization)        (None, 26, 26, 384)              1536              block_8_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)                    (None, 26, 26, 384)              0                 block_8_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_project (Conv2D)                         (None, 26, 26, 64)               24576             block_8_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_project_BN (BatchNormalization)          (None, 26, 26, 64)               256               block_8_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_8_add (Add)                                (None, 26, 26, 64)               0                 block_7_add[0][0]
#                                                                                                     block_8_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_expand (Conv2D)                          (None, 26, 26, 384)              24576             block_8_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_expand_BN (BatchNormalization)           (None, 26, 26, 384)              1536              block_9_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_expand_relu (ReLU)                       (None, 26, 26, 384)              0                 block_9_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_depthwise (DepthwiseConv2D)              (None, 26, 26, 384)              3456              block_9_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNormalization)        (None, 26, 26, 384)              1536              block_9_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)                    (None, 26, 26, 384)              0                 block_9_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_project (Conv2D)                         (None, 26, 26, 64)               24576             block_9_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_project_BN (BatchNormalization)          (None, 26, 26, 64)               256               block_9_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_9_add (Add)                                (None, 26, 26, 64)               0                 block_8_add[0][0]
#                                                                                                     block_9_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_expand (Conv2D)                         (None, 26, 26, 384)              24576             block_9_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_expand_BN (BatchNormalization)          (None, 26, 26, 384)              1536              block_10_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_expand_relu (ReLU)                      (None, 26, 26, 384)              0                 block_10_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_depthwise (DepthwiseConv2D)             (None, 26, 26, 384)              3456              block_10_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNormalization)       (None, 26, 26, 384)              1536              block_10_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)                   (None, 26, 26, 384)              0                 block_10_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_project (Conv2D)                        (None, 26, 26, 96)               36864             block_10_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_10_project_BN (BatchNormalization)         (None, 26, 26, 96)               384               block_10_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_expand (Conv2D)                         (None, 26, 26, 576)              55296             block_10_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_expand_BN (BatchNormalization)          (None, 26, 26, 576)              2304              block_11_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_expand_relu (ReLU)                      (None, 26, 26, 576)              0                 block_11_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_depthwise (DepthwiseConv2D)             (None, 26, 26, 576)              5184              block_11_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNormalization)       (None, 26, 26, 576)              2304              block_11_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)                   (None, 26, 26, 576)              0                 block_11_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_project (Conv2D)                        (None, 26, 26, 96)               55296             block_11_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_project_BN (BatchNormalization)         (None, 26, 26, 96)               384               block_11_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_11_add (Add)                               (None, 26, 26, 96)               0                 block_10_project_BN[0][0]
#                                                                                                     block_11_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_expand (Conv2D)                         (None, 26, 26, 576)              55296             block_11_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_expand_BN (BatchNormalization)          (None, 26, 26, 576)              2304              block_12_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_expand_relu (ReLU)                      (None, 26, 26, 576)              0                 block_12_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_depthwise (DepthwiseConv2D)             (None, 26, 26, 576)              5184              block_12_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNormalization)       (None, 26, 26, 576)              2304              block_12_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)                   (None, 26, 26, 576)              0                 block_12_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_project (Conv2D)                        (None, 26, 26, 96)               55296             block_12_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_project_BN (BatchNormalization)         (None, 26, 26, 96)               384               block_12_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_12_add (Add)                               (None, 26, 26, 96)               0                 block_11_add[0][0]
#                                                                                                     block_12_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_expand (Conv2D)                         (None, 26, 26, 576)              55296             block_12_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_expand_BN (BatchNormalization)          (None, 26, 26, 576)              2304              block_13_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_expand_relu (ReLU)                      (None, 26, 26, 576)              0                 block_13_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)                     (None, 27, 27, 576)              0                 block_13_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_depthwise (DepthwiseConv2D)             (None, 13, 13, 576)              5184              block_13_pad[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNormalization)       (None, 13, 13, 576)              2304              block_13_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)                   (None, 13, 13, 576)              0                 block_13_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_project (Conv2D)                        (None, 13, 13, 160)              92160             block_13_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_13_project_BN (BatchNormalization)         (None, 13, 13, 160)              640               block_13_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_expand (Conv2D)                         (None, 13, 13, 960)              153600            block_13_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_expand_BN (BatchNormalization)          (None, 13, 13, 960)              3840              block_14_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_expand_relu (ReLU)                      (None, 13, 13, 960)              0                 block_14_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_depthwise (DepthwiseConv2D)             (None, 13, 13, 960)              8640              block_14_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNormalization)       (None, 13, 13, 960)              3840              block_14_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)                   (None, 13, 13, 960)              0                 block_14_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_project (Conv2D)                        (None, 13, 13, 160)              153600            block_14_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_project_BN (BatchNormalization)         (None, 13, 13, 160)              640               block_14_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_14_add (Add)                               (None, 13, 13, 160)              0                 block_13_project_BN[0][0]
#                                                                                                     block_14_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_expand (Conv2D)                         (None, 13, 13, 960)              153600            block_14_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_expand_BN (BatchNormalization)          (None, 13, 13, 960)              3840              block_15_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_expand_relu (ReLU)                      (None, 13, 13, 960)              0                 block_15_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_depthwise (DepthwiseConv2D)             (None, 13, 13, 960)              8640              block_15_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNormalization)       (None, 13, 13, 960)              3840              block_15_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)                   (None, 13, 13, 960)              0                 block_15_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_project (Conv2D)                        (None, 13, 13, 160)              153600            block_15_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_project_BN (BatchNormalization)         (None, 13, 13, 160)              640               block_15_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_15_add (Add)                               (None, 13, 13, 160)              0                 block_14_add[0][0]
#                                                                                                     block_15_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_expand (Conv2D)                         (None, 13, 13, 960)              153600            block_15_add[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_expand_BN (BatchNormalization)          (None, 13, 13, 960)              3840              block_16_expand[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_expand_relu (ReLU)                      (None, 13, 13, 960)              0                 block_16_expand_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_depthwise (DepthwiseConv2D)             (None, 13, 13, 960)              8640              block_16_expand_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNormalization)       (None, 13, 13, 960)              3840              block_16_depthwise[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)                   (None, 13, 13, 960)              0                 block_16_depthwise_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_project (Conv2D)                        (None, 13, 13, 320)              307200            block_16_depthwise_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# block_16_project_BN (BatchNormalization)         (None, 13, 13, 320)              1280              block_16_project[0][0]
# ______________________________________________________________________________________________________________________________________________________
# Conv_1 (Conv2D)                                  (None, 13, 13, 1280)             409600            block_16_project_BN[0][0]
# ______________________________________________________________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)                   (None, 13, 13, 1280)             5120              Conv_1[0][0]
# ______________________________________________________________________________________________________________________________________________________
# out_relu (ReLU)                                  (None, 13, 13, 1280)             0                 Conv_1_bn[0][0]
# ______________________________________________________________________________________________________________________________________________________
# global_average_pooling2d (GlobalAveragePooling2D (None, 1280)                     0                 out_relu[0][0]
# ______________________________________________________________________________________________________________________________________________________
# output_fc (Dense)                                (None, 1049)                     1343769           global_average_pooling2d[0][0]
# ======================================================================================================================================================
# Total params: 3,601,753
# Trainable params: 1,343,769
# Non-trainable params: 2,257,984
# ______________________________________________________________________________________________________________________________________________________

# %%
origin_train_len = len(train_df) / 5 * 4
origin_val_len = len(train_df) / 5 * 1

train_num_steps = int(np.ceil((origin_train_len)/config['batch_size']))
val_num_steps = int(np.ceil((origin_val_len)/config['batch_size']))

# %%
model_base_path = data_base_path
model_checkpoint_path = pth.join(model_base_path, 'checkpoint')

# %%
for conv_comb, activation, base_channel, \
    between_type, fc_num, batch_size \
        in itertools.product(conv_comb_list, activation_list,
                              base_channel_list, between_type_list, fc_list,
                              batch_size_list):
    config['conv']['conv_num'] = conv_comb
    config['conv']['base_channel'] = base_channel
    config['activation'] = activation
    config['between_type'] = between_type
    config['fc']['fc_num'] = fc_num
    config['batch_size'] = batch_size

    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])

    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print(model_name)

    ### Define dataset
    dataset = tf.data.TFRecordDataset(train_tfrecord_path, compression_type='GZIP')
    dataset = dataset.map(_parse_image_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # dataset = dataset.cache()
    dataset = dataset.map(map_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.map(resize_and_crop_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.map(image_aug_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.shuffle(config['buffer_size'])
    dataset = dataset.batch(config['batch_size'])
    dataset = dataset.map(post_process_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    val_dataset = tf.data.TFRecordDataset(val_tfrecord_path, compression_type='GZIP')
    val_dataset = val_dataset.map(_parse_image_function, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    val_dataset = val_dataset.map(map_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    val_dataset = val_dataset.map(resize_and_crop_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.map(image_aug_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.shuffle(config['buffer_size'])
    val_dataset = val_dataset.batch(config['batch_size'])
    val_dataset = val_dataset.map(post_process_func, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    # val_dataset = val_dataset.cache()
    val_dataset = val_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
#     model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
#                   metrics=['acc', 'Precision', 'Recall', 'AUC'])
    initial_epoch = 0

    if pth.isdir(model_path) and len([_ for _ in os.listdir(model_path) if _.endswith('hdf5')]) >= 1:
        model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])

        model_chk_name = sorted(os.listdir(model_path))[-1]
        initial_epoch = int(model_chk_name.split('-')[0])
        model.load_weights(pth.join(model_path, model_chk_name))
    else:
        model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
                     metrics=['acc', 'Precision', 'Recall', 'AUC'])
        
        model.fit(
            x=dataset, epochs=6, # train only top layers for just a few epochs.
            validation_data=val_dataset, shuffle=True,
            #callbacks = [checkpointer, es], #batch_size=config['batch_size']
            initial_epoch=initial_epoch,
            # steps_per_epoch=train_num_steps, validation_steps=val_num_steps,
            verbose=1)
        
        for i, layer in enumerate(model.layers):
            print(i, layer.name)
        
        for layer in model.layers[:135]:
            layer.trainable = False
        for layer in model.layers[135:]:
            layer.trainable = True
        
        model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
        
        initial_epoch=6
            
    # ### Freeze first layer
    # conv_list = [layer for layer in model.layers if isinstance(layer, keras.layers.Conv2D)]
    # conv_list[0].trainable = False
    # # conv_list[1].trainable = False

    os.makedirs(model_path, exist_ok=True)
    model_filename = pth.join(model_path, '{epoch:06d}-{val_loss:0.6f}-{loss:0.6f}.hdf5')
    checkpointer = ModelCheckpoint(
        filepath=model_filename, verbose=1, 
        period=1, save_best_only=True, 
        monitor='val_loss'
    )
    es = EarlyStopping(monitor='val_loss', verbose=1, patience=6)

    hist = model.fit(
        x=dataset, epochs=config['num_epoch'], 
        validation_data=val_dataset, shuffle=True,
        callbacks = [checkpointer, es], #batch_size=config['batch_size']
        initial_epoch=initial_epoch,
        # steps_per_epoch=train_num_steps, validation_steps=val_num_steps,
        verbose=1
    )

    model_analysis_path = model_path.replace('checkpoint', 'analysis')
    visualization_path = pth.join(model_analysis_path,'visualization')
    os.makedirs(visualization_path, exist_ok=True)
    
    print()
    # clear_output()        
    for each_label in ['loss', 'acc', 'precision', 'recall', 'auc']:
        fig, ax = plt.subplots()
        ax.plot(hist.history[each_label], 'g', label='train_{}'.format(each_label))
        ax.plot(hist.history['val_{}'.format(each_label)], 'r', label='val_{}'.format(each_label))
        ax.set_xlabel('epoch')
        ax.set_ylabel('loss')
        ax.legend(loc='upper left')
        if not each_label == 'loss':
            plt.ylim(0, 1)
        plt.show()
        filename = 'learning_curve_{}'.format(each_label)
#             fig.savefig(pth.join(visualization_path, filename), transparent=True)
        plt.cla()
        plt.clf()
        plt.close('all')

    np.savez_compressed(pth.join(visualization_path, 'learning_curve'), 
                        loss=hist.history['loss'], 
                        val_loss=hist.history['val_loss'],
                        acc=hist.history['acc'], 
                        val_acc=hist.history['val_acc'],
                        precision=hist.history['precision'], 
                        vaval_precisionl_mae=hist.history['val_precision'],  
                        recall=hist.history['recall'],
                        val_recall=hist.history['val_recall'],
                        auc=hist.history['auc'],
                        val_auc=hist.history['val_auc']
                        )

    model.save(pth.join(model_path, '000000_last.hdf5'))
    K.clear_session()
    del(model)
    
    model_analysis_base_path = pth.join(model_base_path, 'analysis', model_name) 
    with open(pth.join(model_analysis_base_path, 'config.json'), 'w') as f:
        json.dump(config, f)

    chk_name_list = sorted([name for name in os.listdir(model_path) if name != '000000_last.hdf5'])
    for chk_name in chk_name_list[:-2]:
        os.remove(pth.join(model_path, chk_name))
    # clear_output()
# Out:
# MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Epoch 1/16
# 882/882 [==============================] - 352s 399ms/step - loss: 3.0287 - acc: 0.5473 - precision: 0.9782 - recall: 0.2353 - auc: 0.8937 - val_loss: 1.3854 - val_acc: 0.7599 - val_precision: 0.9771 - val_recall: 0.5391 - val_auc: 0.9734
# Epoch 2/16
# 882/882 [==============================] - 346s 392ms/step - loss: 0.9537 - acc: 0.8187 - precision: 0.9685 - recall: 0.6772 - auc: 0.9833 - val_loss: 0.9487 - val_acc: 0.8105 - val_precision: 0.9590 - val_recall: 0.7081 - val_auc: 0.9791
# Epoch 3/16
# 882/882 [==============================] - 346s 393ms/step - loss: 0.6524 - acc: 0.8645 - precision: 0.9606 - recall: 0.7886 - auc: 0.9873 - val_loss: 0.8129 - val_acc: 0.8347 - val_precision: 0.9486 - val_recall: 0.7619 - val_auc: 0.9795
# Epoch 4/16
# 882/882 [==============================] - 351s 398ms/step - loss: 0.5272 - acc: 0.8862 - precision: 0.9563 - recall: 0.8364 - auc: 0.9890 - val_loss: 0.7517 - val_acc: 0.8439 - val_precision: 0.9398 - val_recall: 0.7891 - val_auc: 0.9807
# Epoch 5/16
# 882/882 [==============================] - 354s 401ms/step - loss: 0.4543 - acc: 0.8996 - precision: 0.9541 - recall: 0.8633 - auc: 0.9903 - val_loss: 0.7134 - val_acc: 0.8525 - val_precision: 0.9354 - val_recall: 0.8091 - val_auc: 0.9806
# Epoch 6/16
# 882/882 [==============================] - 354s 401ms/step - loss: 0.4125 - acc: 0.9075 - precision: 0.9529 - recall: 0.8796 - auc: 0.9906 - val_loss: 0.7089 - val_acc: 0.8536 - val_precision: 0.9306 - val_recall: 0.8174 - val_auc: 0.9798
# Epoch 7/16
# 882/882 [==============================] - 347s 393ms/step - loss: 0.3831 - acc: 0.9136 - precision: 0.9525 - recall: 0.8903 - auc: 0.9913 - val_loss: 0.6614 - val_acc: 0.8595 - val_precision: 0.9294 - val_recall: 0.8269 - val_auc: 0.9813
# Epoch 8/16
# 882/882 [==============================] - 355s 402ms/step - loss: 0.3553 - acc: 0.9193 - precision: 0.9528 - recall: 0.8994 - auc: 0.9916 - val_loss: 0.6765 - val_acc: 0.8621 - val_precision: 0.9249 - val_recall: 0.8339 - val_auc: 0.9802
# Epoch 9/16
# 882/882 [==============================] - 358s 406ms/step - loss: 0.3361 - acc: 0.9246 - precision: 0.9532 - recall: 0.9076 - auc: 0.9919 - val_loss: 0.6810 - val_acc: 0.8645 - val_precision: 0.9235 - val_recall: 0.8384 - val_auc: 0.9793
# Epoch 10/16
# 882/882 [==============================] - 353s 401ms/step - loss: 0.3211 - acc: 0.9276 - precision: 0.9528 - recall: 0.9129 - auc: 0.9917 - val_loss: 0.6617 - val_acc: 0.8678 - val_precision: 0.9235 - val_recall: 0.8452 - val_auc: 0.9794
# Epoch 11/16
# 882/882 [==============================] - 347s 393ms/step - loss: 0.3091 - acc: 0.9303 - precision: 0.9530 - recall: 0.9169 - auc: 0.9920 - val_loss: 0.6468 - val_acc: 0.8719 - val_precision: 0.9232 - val_recall: 0.8493 - val_auc: 0.9797
# Epoch 12/16
# 882/882 [==============================] - 346s 392ms/step - loss: 0.2992 - acc: 0.9330 - precision: 0.9527 - recall: 0.9212 - auc: 0.9922 - val_loss: 0.6536 - val_acc: 0.8708 - val_precision: 0.9209 - val_recall: 0.8498 - val_auc: 0.9794
# Epoch 13/16
# 882/882 [==============================] - 345s 392ms/step - loss: 0.2897 - acc: 0.9339 - precision: 0.9525 - recall: 0.9239 - auc: 0.9924 - val_loss: 0.6711 - val_acc: 0.8698 - val_precision: 0.9181 - val_recall: 0.8502 - val_auc: 0.9789
# Epoch 14/16
# 882/882 [==============================] - 346s 392ms/step - loss: 0.2851 - acc: 0.9366 - precision: 0.9538 - recall: 0.9270 - auc: 0.9923 - val_loss: 0.6530 - val_acc: 0.8751 - val_precision: 0.9201 - val_recall: 0.8564 - val_auc: 0.9799
# Epoch 15/16
# 882/882 [==============================] - 346s 393ms/step - loss: 0.2779 - acc: 0.9393 - precision: 0.9551 - recall: 0.9305 - auc: 0.9923 - val_loss: 0.6566 - val_acc: 0.8736 - val_precision: 0.9191 - val_recall: 0.8561 - val_auc: 0.9791
# Epoch 16/16
# 882/882 [==============================] - 345s 391ms/step - loss: 0.2665 - acc: 0.9418 - precision: 0.9557 - recall: 0.9340 - auc: 0.9928 - val_loss: 0.6340 - val_acc: 0.8788 - val_precision: 0.9197 - val_recall: 0.8619 - val_auc: 0.9797
# 0 input_layer
# 1 Conv1_pad
# 2 Conv1
# 3 bn_Conv1
# 4 Conv1_relu
# 5 expanded_conv_depthwise
# 6 expanded_conv_depthwise_BN
# 7 expanded_conv_depthwise_relu
# 8 expanded_conv_project
# 9 expanded_conv_project_BN
# 10 block_1_expand
# 11 block_1_expand_BN
# 12 block_1_expand_relu
# 13 block_1_pad
# 14 block_1_depthwise
# 15 block_1_depthwise_BN
# 16 block_1_depthwise_relu
# 17 block_1_project
# 18 block_1_project_BN
# 19 block_2_expand
# 20 block_2_expand_BN
# 21 block_2_expand_relu
# 22 block_2_depthwise
# 23 block_2_depthwise_BN
# 24 block_2_depthwise_relu
# 25 block_2_project
# 26 block_2_project_BN
# 27 block_2_add
# 28 block_3_expand
# 29 block_3_expand_BN
# 30 block_3_expand_relu
# 31 block_3_pad
# 32 block_3_depthwise
# 33 block_3_depthwise_BN
# 34 block_3_depthwise_relu
# 35 block_3_project
# 36 block_3_project_BN
# 37 block_4_expand
# 38 block_4_expand_BN
# 39 block_4_expand_relu
# 40 block_4_depthwise
# 41 block_4_depthwise_BN
# 42 block_4_depthwise_relu
# 43 block_4_project
# 44 block_4_project_BN
# 45 block_4_add
# 46 block_5_expand
# 47 block_5_expand_BN
# 48 block_5_expand_relu
# 49 block_5_depthwise
# 50 block_5_depthwise_BN
# 51 block_5_depthwise_relu
# 52 block_5_project
# 53 block_5_project_BN
# 54 block_5_add
# 55 block_6_expand
# 56 block_6_expand_BN
# 57 block_6_expand_relu
# 58 block_6_pad
# 59 block_6_depthwise
# 60 block_6_depthwise_BN
# 61 block_6_depthwise_relu
# 62 block_6_project
# 63 block_6_project_BN
# 64 block_7_expand
# 65 block_7_expand_BN
# 66 block_7_expand_relu
# 67 block_7_depthwise
# 68 block_7_depthwise_BN
# 69 block_7_depthwise_relu
# 70 block_7_project
# 71 block_7_project_BN
# 72 block_7_add
# 73 block_8_expand
# 74 block_8_expand_BN
# 75 block_8_expand_relu
# 76 block_8_depthwise
# 77 block_8_depthwise_BN
# 78 block_8_depthwise_relu
# 79 block_8_project
# 80 block_8_project_BN
# 81 block_8_add
# 82 block_9_expand
# 83 block_9_expand_BN
# 84 block_9_expand_relu
# 85 block_9_depthwise
# 86 block_9_depthwise_BN
# 87 block_9_depthwise_relu
# 88 block_9_project
# 89 block_9_project_BN
# 90 block_9_add
# 91 block_10_expand
# 92 block_10_expand_BN
# 93 block_10_expand_relu
# 94 block_10_depthwise
# 95 block_10_depthwise_BN
# 96 block_10_depthwise_relu
# 97 block_10_project
# 98 block_10_project_BN
# 99 block_11_expand
# 100 block_11_expand_BN
# 101 block_11_expand_relu
# 102 block_11_depthwise
# 103 block_11_depthwise_BN
# 104 block_11_depthwise_relu
# 105 block_11_project
# 106 block_11_project_BN
# 107 block_11_add
# 108 block_12_expand
# 109 block_12_expand_BN
# 110 block_12_expand_relu
# 111 block_12_depthwise
# 112 block_12_depthwise_BN
# 113 block_12_depthwise_relu
# 114 block_12_project
# 115 block_12_project_BN
# 116 block_12_add
# 117 block_13_expand
# 118 block_13_expand_BN
# 119 block_13_expand_relu
# 120 block_13_pad
# 121 block_13_depthwise
# 122 block_13_depthwise_BN
# 123 block_13_depthwise_relu
# 124 block_13_project
# 125 block_13_project_BN
# 126 block_14_expand
# 127 block_14_expand_BN
# 128 block_14_expand_relu
# 129 block_14_depthwise
# 130 block_14_depthwise_BN
# 131 block_14_depthwise_relu
# 132 block_14_project
# 133 block_14_project_BN
# 134 block_14_add
# 135 block_15_expand
# 136 block_15_expand_BN
# 137 block_15_expand_relu
# 138 block_15_depthwise
# 139 block_15_depthwise_BN
# 140 block_15_depthwise_relu
# 141 block_15_project
# 142 block_15_project_BN
# 143 block_15_add
# 144 block_16_expand
# 145 block_16_expand_BN
# 146 block_16_expand_relu
# 147 block_16_depthwise
# 148 block_16_depthwise_BN
# 149 block_16_depthwise_relu
# 150 block_16_project
# 151 block_16_project_BN
# 152 Conv_1
# 153 Conv_1_bn
# 154 out_relu
# 155 global_average_pooling2d_1
# 156 output_fc
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/10000
#     882/Unknown - 328s 372ms/step - loss: 0.5633 - acc: 0.8685 - precision: 0.9186 - recall: 0.8418 - auc: 0.9857
# Epoch 00001: val_loss improved from inf to 28.97301, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000001-28.973013-0.563319.hdf5
# 882/882 [==============================] - 394s 447ms/step - loss: 0.5633 - acc: 0.8685 - precision: 0.9186 - recall: 0.8418 - auc: 0.9857 - val_loss: 28.9730 - val_acc: 0.1095 - val_precision: 0.1122 - val_recall: 0.1082 - val_auc: 0.5800
# Epoch 2/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.2822 - acc: 0.9261 - precision: 0.9534 - recall: 0.9116 - auc: 0.9943
# Epoch 00002: val_loss improved from 28.97301 to 9.93198, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000002-9.931985-0.282350.hdf5
# 882/882 [==============================] - 393s 446ms/step - loss: 0.2824 - acc: 0.9261 - precision: 0.9534 - recall: 0.9116 - auc: 0.9943 - val_loss: 9.9320 - val_acc: 0.3455 - val_precision: 0.3614 - val_recall: 0.3417 - val_auc: 0.7368
# Epoch 3/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.2030 - acc: 0.9448 - precision: 0.9636 - recall: 0.9326 - auc: 0.9965
# Epoch 00003: val_loss improved from 9.93198 to 5.77565, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000003-5.775655-0.203083.hdf5
# 882/882 [==============================] - 394s 447ms/step - loss: 0.2031 - acc: 0.9448 - precision: 0.9636 - recall: 0.9325 - auc: 0.9965 - val_loss: 5.7757 - val_acc: 0.4727 - val_precision: 0.4912 - val_recall: 0.4646 - val_auc: 0.8136
# Epoch 4/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1580 - acc: 0.9567 - precision: 0.9706 - recall: 0.9470 - auc: 0.9974
# Epoch 00004: val_loss improved from 5.77565 to 3.62893, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000004-3.628934-0.158178.hdf5
# 882/882 [==============================] - 394s 447ms/step - loss: 0.1582 - acc: 0.9567 - precision: 0.9706 - recall: 0.9470 - auc: 0.9974 - val_loss: 3.6289 - val_acc: 0.5836 - val_precision: 0.6081 - val_recall: 0.5744 - val_auc: 0.8732
# Epoch 5/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1470 - acc: 0.9585 - precision: 0.9715 - recall: 0.9494 - auc: 0.9979
# Epoch 00005: val_loss did not improve from 3.62893
# 882/882 [==============================] - 393s 445ms/step - loss: 0.1472 - acc: 0.9585 - precision: 0.9715 - recall: 0.9494 - auc: 0.9979 - val_loss: 3.9461 - val_acc: 0.5746 - val_precision: 0.5969 - val_recall: 0.5664 - val_auc: 0.8673
# Epoch 6/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1360 - acc: 0.9622 - precision: 0.9732 - recall: 0.9544 - auc: 0.9980
# Epoch 00006: val_loss did not improve from 3.62893
# 882/882 [==============================] - 393s 445ms/step - loss: 0.1361 - acc: 0.9621 - precision: 0.9732 - recall: 0.9544 - auc: 0.9980 - val_loss: 3.7974 - val_acc: 0.5617 - val_precision: 0.5867 - val_recall: 0.5507 - val_auc: 0.8671
# Epoch 7/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.1115 - acc: 0.9685 - precision: 0.9770 - recall: 0.9618 - auc: 0.9984
# Epoch 00007: val_loss improved from 3.62893 to 1.23883, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000007-1.238825-0.111609.hdf5
# 882/882 [==============================] - 394s 446ms/step - loss: 0.1116 - acc: 0.9685 - precision: 0.9770 - recall: 0.9618 - auc: 0.9984 - val_loss: 1.2388 - val_acc: 0.7984 - val_precision: 0.8239 - val_recall: 0.7893 - val_auc: 0.9563
# Epoch 8/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0986 - acc: 0.9721 - precision: 0.9798 - recall: 0.9667 - auc: 0.9987
# Epoch 00008: val_loss did not improve from 1.23883
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0989 - acc: 0.9721 - precision: 0.9798 - recall: 0.9666 - auc: 0.9987 - val_loss: 2.0474 - val_acc: 0.7175 - val_precision: 0.7412 - val_recall: 0.7088 - val_auc: 0.9268
# Epoch 9/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0842 - acc: 0.9766 - precision: 0.9831 - recall: 0.9713 - auc: 0.9989
# Epoch 00009: val_loss did not improve from 1.23883
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0844 - acc: 0.9766 - precision: 0.9831 - recall: 0.9713 - auc: 0.9989 - val_loss: 1.6983 - val_acc: 0.7430 - val_precision: 0.7689 - val_recall: 0.7317 - val_auc: 0.9399
# Epoch 10/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0823 - acc: 0.9769 - precision: 0.9830 - recall: 0.9723 - auc: 0.9989
# Epoch 00010: val_loss improved from 1.23883 to 1.01557, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000010-1.015568-0.082428.hdf5
# 882/882 [==============================] - 394s 446ms/step - loss: 0.0824 - acc: 0.9769 - precision: 0.9829 - recall: 0.9723 - auc: 0.9989 - val_loss: 1.0156 - val_acc: 0.8238 - val_precision: 0.8477 - val_recall: 0.8154 - val_auc: 0.9646
# Epoch 11/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0711 - acc: 0.9795 - precision: 0.9850 - recall: 0.9755 - auc: 0.9992
# Epoch 00011: val_loss improved from 1.01557 to 0.79350, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000011-0.793499-0.071285.hdf5
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0713 - acc: 0.9794 - precision: 0.9850 - recall: 0.9755 - auc: 0.9992 - val_loss: 0.7935 - val_acc: 0.8671 - val_precision: 0.8877 - val_recall: 0.8608 - val_auc: 0.9728
# Epoch 12/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0747 - acc: 0.9786 - precision: 0.9841 - recall: 0.9747 - auc: 0.9990
# Epoch 00012: val_loss did not improve from 0.79350
# 882/882 [==============================] - 392s 445ms/step - loss: 0.0749 - acc: 0.9786 - precision: 0.9841 - recall: 0.9747 - auc: 0.9990 - val_loss: 1.0021 - val_acc: 0.8320 - val_precision: 0.8568 - val_recall: 0.8240 - val_auc: 0.9657
# Epoch 13/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0633 - acc: 0.9820 - precision: 0.9866 - recall: 0.9780 - auc: 0.9992
# Epoch 00013: val_loss improved from 0.79350 to 0.67407, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000013-0.674073-0.063446.hdf5
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0634 - acc: 0.9820 - precision: 0.9866 - recall: 0.9780 - auc: 0.9992 - val_loss: 0.6741 - val_acc: 0.8746 - val_precision: 0.8955 - val_recall: 0.8664 - val_auc: 0.9782
# Epoch 14/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0575 - acc: 0.9833 - precision: 0.9874 - recall: 0.9802 - auc: 0.9993
# Epoch 00014: val_loss improved from 0.67407 to 0.56055, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000014-0.560552-0.057659.hdf5
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0577 - acc: 0.9833 - precision: 0.9874 - recall: 0.9802 - auc: 0.9993 - val_loss: 0.5606 - val_acc: 0.9022 - val_precision: 0.9177 - val_recall: 0.8961 - val_auc: 0.9813
# Epoch 15/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0526 - acc: 0.9848 - precision: 0.9884 - recall: 0.9820 - auc: 0.9994
# Epoch 00015: val_loss improved from 0.56055 to 0.55959, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000015-0.559590-0.052912.hdf5
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0529 - acc: 0.9848 - precision: 0.9884 - recall: 0.9820 - auc: 0.9994 - val_loss: 0.5596 - val_acc: 0.9046 - val_precision: 0.9196 - val_recall: 0.8997 - val_auc: 0.9818
# Epoch 16/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0522 - acc: 0.9848 - precision: 0.9886 - recall: 0.9824 - auc: 0.9994
# Epoch 00016: val_loss did not improve from 0.55959
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0524 - acc: 0.9848 - precision: 0.9886 - recall: 0.9824 - auc: 0.9994 - val_loss: 0.6378 - val_acc: 0.9009 - val_precision: 0.9153 - val_recall: 0.8960 - val_auc: 0.9787
# Epoch 17/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0491 - acc: 0.9864 - precision: 0.9895 - recall: 0.9840 - auc: 0.9993
# Epoch 00017: val_loss did not improve from 0.55959
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0493 - acc: 0.9864 - precision: 0.9895 - recall: 0.9840 - auc: 0.9993 - val_loss: 0.6161 - val_acc: 0.8914 - val_precision: 0.9063 - val_recall: 0.8851 - val_auc: 0.9788
# Epoch 18/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0461 - acc: 0.9866 - precision: 0.9896 - recall: 0.9842 - auc: 0.9996
# Epoch 00018: val_loss improved from 0.55959 to 0.54439, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000018-0.544389-0.046297.hdf5
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0463 - acc: 0.9866 - precision: 0.9896 - recall: 0.9842 - auc: 0.9995 - val_loss: 0.5444 - val_acc: 0.9065 - val_precision: 0.9215 - val_recall: 0.9017 - val_auc: 0.9813
# Epoch 19/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0468 - acc: 0.9866 - precision: 0.9900 - recall: 0.9839 - auc: 0.9995
# Epoch 00019: val_loss did not improve from 0.54439
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0469 - acc: 0.9866 - precision: 0.9900 - recall: 0.9839 - auc: 0.9995 - val_loss: 0.6918 - val_acc: 0.8801 - val_precision: 0.8967 - val_recall: 0.8746 - val_auc: 0.9763
# Epoch 20/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0390 - acc: 0.9887 - precision: 0.9911 - recall: 0.9868 - auc: 0.9995
# Epoch 00020: val_loss improved from 0.54439 to 0.44234, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000020-0.442337-0.039019.hdf5
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0390 - acc: 0.9887 - precision: 0.9911 - recall: 0.9868 - auc: 0.9995 - val_loss: 0.4423 - val_acc: 0.9196 - val_precision: 0.9342 - val_recall: 0.9131 - val_auc: 0.9855
# Epoch 21/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0317 - acc: 0.9913 - precision: 0.9930 - recall: 0.9898 - auc: 0.9996
# Epoch 00021: val_loss did not improve from 0.44234
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0319 - acc: 0.9913 - precision: 0.9930 - recall: 0.9898 - auc: 0.9996 - val_loss: 0.5270 - val_acc: 0.9044 - val_precision: 0.9207 - val_recall: 0.8995 - val_auc: 0.9830
# Epoch 22/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0421 - acc: 0.9882 - precision: 0.9908 - recall: 0.9864 - auc: 0.9994
# Epoch 00022: val_loss did not improve from 0.44234
# 882/882 [==============================] - 394s 446ms/step - loss: 0.0423 - acc: 0.9882 - precision: 0.9908 - recall: 0.9864 - auc: 0.9994 - val_loss: 0.5153 - val_acc: 0.9064 - val_precision: 0.9219 - val_recall: 0.9013 - val_auc: 0.9832
# Epoch 23/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0405 - acc: 0.9882 - precision: 0.9907 - recall: 0.9863 - auc: 0.9995
# Epoch 00023: val_loss did not improve from 0.44234
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0406 - acc: 0.9882 - precision: 0.9906 - recall: 0.9863 - auc: 0.9994 - val_loss: 0.4782 - val_acc: 0.9126 - val_precision: 0.9288 - val_recall: 0.9070 - val_auc: 0.9845
# Epoch 24/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0316 - acc: 0.9907 - precision: 0.9926 - recall: 0.9889 - auc: 0.9997
# Epoch 00024: val_loss improved from 0.44234 to 0.35028, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000024-0.350282-0.031820.hdf5
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0318 - acc: 0.9906 - precision: 0.9926 - recall: 0.9889 - auc: 0.9997 - val_loss: 0.3503 - val_acc: 0.9389 - val_precision: 0.9504 - val_recall: 0.9349 - val_auc: 0.9886
# Epoch 25/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0324 - acc: 0.9906 - precision: 0.9925 - recall: 0.9893 - auc: 0.9996
# Epoch 00025: val_loss did not improve from 0.35028
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0325 - acc: 0.9906 - precision: 0.9925 - recall: 0.9893 - auc: 0.9996 - val_loss: 0.4656 - val_acc: 0.9134 - val_precision: 0.9301 - val_recall: 0.9081 - val_auc: 0.9851
# Epoch 26/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0390 - acc: 0.9893 - precision: 0.9911 - recall: 0.9877 - auc: 0.9993
# Epoch 00026: val_loss did not improve from 0.35028
# 882/882 [==============================] - 394s 447ms/step - loss: 0.0390 - acc: 0.9893 - precision: 0.9911 - recall: 0.9877 - auc: 0.9993 - val_loss: 0.3685 - val_acc: 0.9338 - val_precision: 0.9454 - val_recall: 0.9297 - val_auc: 0.9880
# Epoch 27/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0219 - acc: 0.9935 - precision: 0.9948 - recall: 0.9926 - auc: 0.9997
# Epoch 00027: val_loss did not improve from 0.35028
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0220 - acc: 0.9935 - precision: 0.9948 - recall: 0.9925 - auc: 0.9997 - val_loss: 0.3607 - val_acc: 0.9359 - val_precision: 0.9466 - val_recall: 0.9324 - val_auc: 0.9885
# Epoch 28/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0329 - acc: 0.9903 - precision: 0.9923 - recall: 0.9890 - auc: 0.9996
# Epoch 00028: val_loss did not improve from 0.35028
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0331 - acc: 0.9903 - precision: 0.9923 - recall: 0.9890 - auc: 0.9995 - val_loss: 0.5392 - val_acc: 0.9131 - val_precision: 0.9241 - val_recall: 0.9093 - val_auc: 0.9818
# Epoch 29/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0278 - acc: 0.9916 - precision: 0.9932 - recall: 0.9904 - auc: 0.9997
# Epoch 00029: val_loss did not improve from 0.35028
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0279 - acc: 0.9916 - precision: 0.9932 - recall: 0.9904 - auc: 0.9997 - val_loss: 0.4118 - val_acc: 0.9266 - val_precision: 0.9396 - val_recall: 0.9215 - val_auc: 0.9862
# Epoch 30/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0259 - acc: 0.9925 - precision: 0.9938 - recall: 0.9914 - auc: 0.9997
# Epoch 00030: val_loss improved from 0.35028 to 0.28461, saving model to data/public/checkpoint/MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O/000030-0.284613-0.025919.hdf5
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0259 - acc: 0.9925 - precision: 0.9938 - recall: 0.9914 - auc: 0.9997 - val_loss: 0.2846 - val_acc: 0.9444 - val_precision: 0.9560 - val_recall: 0.9392 - val_auc: 0.9910
# Epoch 31/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0285 - acc: 0.9920 - precision: 0.9936 - recall: 0.9908 - auc: 0.9996
# Epoch 00031: val_loss did not improve from 0.28461
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0287 - acc: 0.9920 - precision: 0.9936 - recall: 0.9908 - auc: 0.9996 - val_loss: 0.3810 - val_acc: 0.9349 - val_precision: 0.9462 - val_recall: 0.9313 - val_auc: 0.9876
# Epoch 32/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0268 - acc: 0.9924 - precision: 0.9938 - recall: 0.9912 - auc: 0.9996
# Epoch 00032: val_loss did not improve from 0.28461
# 882/882 [==============================] - 392s 445ms/step - loss: 0.0269 - acc: 0.9923 - precision: 0.9937 - recall: 0.9912 - auc: 0.9996 - val_loss: 0.4366 - val_acc: 0.9300 - val_precision: 0.9384 - val_recall: 0.9271 - val_auc: 0.9854
# Epoch 33/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0232 - acc: 0.9932 - precision: 0.9944 - recall: 0.9921 - auc: 0.9997
# Epoch 00033: val_loss did not improve from 0.28461
# 882/882 [==============================] - 392s 445ms/step - loss: 0.0234 - acc: 0.9931 - precision: 0.9944 - recall: 0.9921 - auc: 0.9997 - val_loss: 0.3322 - val_acc: 0.9401 - val_precision: 0.9521 - val_recall: 0.9363 - val_auc: 0.9891
# Epoch 34/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0223 - acc: 0.9936 - precision: 0.9949 - recall: 0.9927 - auc: 0.9998
# Epoch 00034: val_loss did not improve from 0.28461
# 882/882 [==============================] - 393s 446ms/step - loss: 0.0224 - acc: 0.9935 - precision: 0.9949 - recall: 0.9927 - auc: 0.9998 - val_loss: 0.3080 - val_acc: 0.9407 - val_precision: 0.9541 - val_recall: 0.9365 - val_auc: 0.9905
# Epoch 35/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0217 - acc: 0.9942 - precision: 0.9953 - recall: 0.9931 - auc: 0.9997
# Epoch 00035: val_loss did not improve from 0.28461
# 882/882 [==============================] - 392s 444ms/step - loss: 0.0219 - acc: 0.9942 - precision: 0.9953 - recall: 0.9931 - auc: 0.9997 - val_loss: 0.2949 - val_acc: 0.9443 - val_precision: 0.9554 - val_recall: 0.9402 - val_auc: 0.9907
# Epoch 36/10000
# 881/882 [============================>.] - ETA: 0s - loss: 0.0199 - acc: 0.9942 - precision: 0.9955 - recall: 0.9934 - auc: 0.9998
# Epoch 00036: val_loss did not improve from 0.28461
# 882/882 [==============================] - 393s 445ms/step - loss: 0.0200 - acc: 0.9942 - precision: 0.9955 - recall: 0.9934 - auc: 0.9998 - val_loss: 0.2947 - val_acc: 0.9442 - val_precision: 0.9554 - val_recall: 0.9399 - val_auc: 0.9907
# Epoch 00036: early stopping

# %% [markdown]
# ### Inference

# %%
image_feature_description_for_test = {
    'image_raw': tf.io.FixedLenFeature([], tf.string),
    # 'randmark_id': tf.io.FixedLenFeature([], tf.int64),
    # 'id': tf.io.FixedLenFeature([], tf.string),
}

def _parse_image_function_for_test(example_proto):
    return tf.io.parse_single_example(example_proto, image_feature_description_for_test)

def map_func_for_test(target_record):
    img = target_record['image_raw']
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.dtypes.cast(img, tf.float32)
    return img

def resize_and_crop_func_for_test(image):
    result_image = tf.image.resize(image, config['aug']['resize'])
    result_image = tf.image.random_crop(image, size=config['input_shape'], seed=7777)  # revive
    return result_image

def post_process_func_for_test(image):
    # result_image = result_image / 255
    result_image = my_model_base.preprocess_input(image)
    return result_image

# %%
submission_base_path = pth.join(data_base_path, 'submission')
os.makedirs(submission_base_path, exist_ok=True)

# %%
for conv_comb, activation, base_channel, \
    between_type, fc_num, batch_size \
        in itertools.product(conv_comb_list, activation_list,
                              base_channel_list, between_type_list, fc_list,
                              batch_size_list):
    config['conv']['conv_num'] = conv_comb
    config['conv']['base_channel'] = base_channel
    config['activation'] = activation
    config['between_type'] = between_type
    config['fc']['fc_num'] = fc_num
    config['batch_size'] = batch_size

    base = BASE_MODEL_NAME

    base += '_resize_{}'.format(config['aug']['resize'][0])

    base += '_conv_{}'.format('-'.join(map(lambda x:str(x),config['conv']['conv_num'])))
    base += '_basech_{}'.format(config['conv']['base_channel'])
    base += '_act_{}'.format(config['activation'])
    base += '_pool_{}'.format(config['pool']['type'])
    base += '_betw_{}'.format(config['between_type'])
    base += '_fc_{}'.format(config['fc']['fc_num'])
    base += '_zscore_{}'.format(config['is_zscore'])
    base += '_batch_{}'.format(config['batch_size'])
    if config['is_dropout']:
        base += '_DO_'+str(config['dropout_rate']).replace('.', '')
    if config['is_batchnorm']:
        base += '_BN'+'_O'
    else:
        base += '_BN'+'_X'

    model_name = base
    print(model_name)

    ### Define dataset
    test_dataset = tf.data.TFRecordDataset(test_tfrecord_path, compression_type='GZIP')
    test_dataset = test_dataset.map(_parse_image_function_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(map_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.map(resize_and_crop_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.batch(config['batch_size'])
    test_dataset = test_dataset.map(post_process_func_for_test, num_parallel_calls=tf.data.experimental.AUTOTUNE)
    test_dataset = test_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    model_path = pth.join(
        model_checkpoint_path, model_name, 
    )
    model = build_cnn(config)
    #         model.summary()
    model.compile(loss=config['loss'], optimizer=Adam(lr=config['learning_rate']),
                  metrics=['acc', 'Precision', 'Recall', 'AUC'])
    initial_epoch = 0

    model_chk_name = sorted(os.listdir(model_path))[-1]
    initial_epoch = int(model_chk_name.split('-')[0])
    model.load_weights(pth.join(model_path, model_chk_name))

    preds = model.predict(test_dataset, verbose=1)
    pred_labels = np.argmax(preds, axis=1)
    pred_probs = np.array([pred[indice] for pred, indice in zip(preds, pred_labels)])

    submission_csv_path = pth.join(data_base_path, submission_csv_name)
    submission_df = pd.read_csv(submission_csv_path)

    submission_df['landmark_id'] = pred_labels
    submission_df['conf'] = pred_probs

    today_str = datetime.date.today().strftime('%Y%m%d')
    result_filename = '{}.csv'.format(model_name)
    submission_csv_fileaname = pth.join(submission_base_path, '_'.join([today_str, result_filename]))
    submission_df.to_csv(submission_csv_fileaname, index=False)
# Out:
# MobileNetV2-for-upload_resize_405_conv_0_basech_0_act_relu_pool_X_betw_avg_fc_0_zscore_True_batch_80_BN_O
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-16-2bcf259240ac> in <module>
#      55     model.load_weights(pth.join(model_path, model_chk_name))
#      56
# ---> 57     preds = model.predict(test_dataset, verbose=1)
#      58     pred_labels = np.argmax(preds, axis=1)
#      59     pred_probs = np.array([pred[indice] for pred, indice in zip(preds, pred_labels)])
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1597           for step in data_handler.steps():
#    1598             callbacks.on_predict_batch_begin(step)
# -> 1599             tmp_batch_outputs = predict_function(iterator)
#    1600             if data_handler.should_sync:
#    1601               context.async_wait()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     844               *args, **kwds)
#     845       # If we did not create any variables the trace we have is good enough.
# --> 846       return self._concrete_stateful_fn._filtered_call(canon_args, canon_kwds)  # pylint: disable=protected-access
#     847
#     848     def fn_with_cond(*inner_args, **inner_kwds):
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# ~/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# UnknownError:  Failed to get convolution algorithm. This is probably because cuDNN failed to initialize, so try looking to see if a warning log message was printed above.
# 	 [[node MobileNetV2-for-upload/Conv1/Conv2D (defined at <ipython-input-16-2bcf259240ac>:57) ]] [Op:__inference_predict_function_11190]
#
# Function call stack:
# predict_function
